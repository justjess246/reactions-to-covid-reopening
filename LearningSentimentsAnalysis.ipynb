# %%
#https://www.geeksforgeeks.org/python-lemmatization-with-nltk/#:~:text=Using%20PCA%20Implementation-,Python%20%7C%20Lemmatization%20with%20NLTK,similar%20meaning%20to%20one%20word.
#https://arxiv.org/pdf/2006.00804.pdf
#https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/
#https://www.datacamp.com/community/tutorials/machine-learning-models-api-python
#https://www.jitsejan.com/python-and-javascript-in-flask.html


import nltk
#nltk.download('twitter_samples')
from nltk.corpus import twitter_samples
#nltk.download('wordnet')
#nltk.download('averaged_perceptron_tagger')
#parts of speech
from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk import FreqDist
from nltk import classify
from nltk import NaiveBayesClassifier
from nltk.tokenize import word_tokenize

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD

import re, string
import random

import pickle

from textblob import TextBlob

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
text = twitter_samples.strings('tweets.20150430-223406.json')

# %%
positive_tweets
# Out:
# ['#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)',
#  '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!',
#  '@DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!',
#  '@97sides CONGRATS :)',
#  'yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days',
#  '@BhaktisBanter @PallaviRuhail This one is irresistible :)\n#FlipkartFashionFriday http://t.co/EbZ0L2VENM',
#  "We don't like to keep our lovely customers waiting for long! We hope you enjoy! Happy Friday! - LWWF :) https://t.co/smyYriipxI",
#  '@Impatientraider On second thought, there’s just not enough time for a DD :) But new shorts entering system. Sheep must be buying.',
#  'Jgh , but we have to go to Bayan :D bye',
#  'As an act of mischievousness, am calling the ETL layer of our in-house warehousing app Katamari.\n\nWell… as the name implies :p.',
#  '#FollowFriday @wncer1 @Defense_gouv for being top influencers in my community this week :)',
#  "Who Wouldn't Love These Big....Juicy....Selfies :) - http://t.co/QVzjgd1uFo http://t.co/oWBL11eQRY",
#  '@Mish23615351  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  "@jjulieredburn Perfect, so you already know what's waiting for you :)",
#  'Great new opportunity for junior triathletes aged 12 and 13 at the Gatorade series! Get your entries in :) http://t.co/of3DyOzML0',
#  'Laying out a greetings card range for print today - love my job :-)',
#  "Friend's lunch... yummmm :)\n#Nostalgia #TBS #KU.",
#  "@RookieSenpai @arcadester it is the id conflict thanks for the help :D here's the screenshot of it working",
#  '@oohdawg_ Hi liv :))',
#  'Hello I need to know something can u fm me on Twitter?? — sure thing :) dm me x http://t.co/W6Dy130BV7',
#  '#FollowFriday @MBandScott_ @Eric_FLE @pointsolutions3 for being top new followers in my community this week :)',
#  "@rossbreadmore I've heard the Four Seasons is pretty dope. Penthouse, obvs #Gobigorgohome\nHave fun y'all :)",
#  '@gculloty87 Yeah I suppose she was lol! Chat in a bit just off out x :))',
#  'Hello :) Get Youth Job Opportunities follow &gt;&gt; @tolajobjobs @maphisa301',
#  "💅🏽💋 - :)))) haven't seen you in years",
#  '@Bosslogic @amellywood @CW_Arrow @ARROWwriters Thank you! :-)',
#  '@johngutierrez1 hope the rest of your night goes by quickly... I am off to bed... got my music fix and now it is time to dream  :)',
#  'Spiritual Ritual Festival (Népal)\nBeginning of Line-up :)\nIt is left for the line-up (y)\nSee more at:... http://t.co/QMNz62OEuc',
#  "@ke7zum Hey Sarah! Send us an email at bitsy@bitdefender.com and we'll help you asap :)",
#  '@izzkamilhalda lols. :D',
#  'MY kik - hatessuce32429 #kik #kikme #lgbt #tinder #nsfw #akua #cumshot :) http://t.co/TnHJD36yzf',
#  '@KalinWhite come to my house :)))))',
#  '#nsn_supplements, Effective press release distribution with results! :) [link removed] #PressRelease #NewsDistribution',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x46',
#  'everyone watch the documentary Earthlings on YouTube :-)',
#  '@jamiefigsxx  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '#FollowFriday @MichelBauza @InvataOnline for being top supports in my community this week :)',
#  'buuuuuuuut oh well :-)',
#  '@leisuremarkltd @NoshandQuaff @aktarislam @keanebrands @HeritageSilver I am looking forward to visiting next week #letsgetmessy Jo :-)',
#  '@sehunshinedaily if it makes u feel better i never have nor will see anyone in kpop in the flesh :D',
#  '@Joyster2012 @CathStaincliffe Good for you, girl!! Best wishes :-)',
#  '@_Kimimi A great enough reason to listen to one epic soundtrack. :D',
#  '@AquaDesignGroup Thank you for the shout out. Have a great Friday :)',
#  'I added a video to a @YouTube playlist http://t.co/yzpfsMxUq0 im back on twitch and today it going to be league :) - 1 / 4',
#  'Would love to see you dear in #Jordan :) waiting you! @FIRDOZ  :) @VisitJordan @dannyprol',
#  '@ABNORMAL_ANA92 oh, okay :D thanks!',
#  '@sssniperwolf like how to fake gameplays ;) haha Im kidding, im kidding. You do good stuff :).',
#  '@dennislami @Dicle_Aygur, yeah exactly :)',
#  'Our new product line is in our #etsy shop now! Check it out :) http://t.co/h8exCTLQxg #boxroomcrafts',
#  '@PeakYourMind I hope your vacation is going great! :D',
#  '@groovinshawn they are rechargeable and it normally comes with a charger when u buy it :)',
#  '#FollowFriday @France_Espana @reglisse_menthe @CCI_inter for being top engaged members in my community this week :)',
#  "Well she's asleep and I have no one to talk to sooo someone text me :)",
#  "@brynybrath @smallcappy Yes, I suppose. I bet he'll have a blue fit after hearing her speech today. Pity :-)",
#  'Green gardens, midnight sun, beautiful canals dasvidaniya till next visit.:)',
#  '@KeithRParsons are you scouting SG for a future WLAN pros conference here in Asia? :)',
#  '@Cecilie_Hell @420evilangel @wazimotometal @durooooooo @spigranty Good for u, better change it to lollipop 🍭 :).',
#  'We &lt;3 u Nez :) #AGNEZMO https://t.co/cGViMHSINz',
#  '@LittleMix Follow me Please :)  This is my Big Dream :)',
#  '@Elemaaan  oley be :D',
#  '"@CowokAddict: Mama is the only reason why I stand stronger up to now! :)"',
#  '@MacatangayApril  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@tk_kjk_kndr @boukendreamer OH MY GOD MISTY, MY BABY IS SO CUTE!!! :D',
#  '@BhaktisBanter \n\nI love blue :)\n#FlipkartFashionFriday http://t.co/HnbinH35ES',
#  "@CarcassDrop Woohoo! Can't wait :) Have you signed up yet, or still thinking about it? MKa",
#  'i have liam access now :))',
#  '@SyuhxdxTengku most welcome :)',
#  'Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/p6K6SiH58a.',
#  "@sluttywife2 you shouldn't be surprised...you have an amazing figure :)",
#  '#FollowFriday @murtishaw @aqui_fr @FRTechStartups for being top influencers in my community this week :)',
#  '#HappyBirthdayEmilyBett @emilybett :) Wishing you all the best you beautiful,sweet,talented,amazing… https://t.co/humtC1tr3I',
#  '2 plans for the day down the drain great :):',
#  '@x123456789tine @5SOS_FAHUpdates gotta love timezones :p',
#  'are your parents proud of you — lol, not in the least :D maybe sometimes they get happy because of my grades, al... http://t.co/bJjeGIOOGU',
#  'Grande :)  https://t.co/gsaaxNpR8u',
#  'Manila_bro has chosen to follow me on Twitter! http://t.co/lKXZWXN1fb. Thanks for the follow :)',
#  "@syazwanzainal sure let me know when you're around..at this side of the world #eh u too take care :-)",
#  '#FollowFriday @michae1green @superninjaalan @Doug_Laney for being top new followers in my community this week :)',
#  'finally the fucking weekend :)',
#  'REAL :)',
#  '@LoLEsportspedia thanks :D',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x45',
#  'YES! I Joined #HushedCallWithFraydoe for a call &amp; gift from @_Fraydoe &lt;3 Gotta Get @HushedApp :D http://t.co/VaLVe8omdT',
#  '@YasLarry yeahhh :)',
#  'can I DM you &amp; make your night better :)))',
#  'just joined the #HushedPinWithSammy Event :D Might get to Text with @SammyWilk for a day! Luv U @HushedApp http://t.co/kGfgawdHy9',
#  'Would really appreciate it if you share this video around :) https://t.co/MhK3B3wOpQ',
#  'Hello :) Get Youth Job Opportunities follow &gt;&gt; @tolajobjobs @xhebenkewu_9920',
#  '@TomParker oh wow!! That is beautiful tom :)',
#  'Love You @darlingIXHAI22 @SyreenAnne :)) https://t.co/wx7yRrE7sV',
#  'I added a video to a @YouTube playlist http://t.co/HVVPhSYakA im back on twitch and today it going to be league :) - 1 / 3',
#  '#FollowFriday @AmericanOGrain @PecomeP @APaulicand for being top supports in my community this week :)',
#  '@ZaynZaynmalik30  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  "Gym Monday can't wait :). Likes",
#  "@HarNiLiZaLouis Hey, here's your invite to join Scope as an influencer :)  http://t.co/rZgZtQ2fJT",
#  'Those friends know themselves :)',
#  'waiting for nudes :-)',
#  '@JacobWhitesides go sleep u ! :)))))))))',
#  'Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/RB8pMNgMEo.',
#  'My birthday is a week today! :D',
#  "@metalgear_jp @Kojima_Hideo I want you're T-shirts ! They are so cool ! :D",
#  '@AxeRade haw phela if am not looking like Mom obviously am looking like him :)',
#  '@zaynmalik prince charming on stage :) x https://t.co/OnVFhzt5fZ',
#  'i have really good luck :)',
#  'Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/XzsOGaC4zK.',
#  '#FollowFriday @straz_das @DCarsonCPA @GH813600 for being top engaged members in my community this week :)',
#  '@twentyonepilots @fujirock_jp tylers hipster glasses :D',
#  '@MartyRafenstein \n\nHey Marty !! Glad to see on Twitter. :)',
#  '@UKBusinessLunch Hi we will be joining you again today :)',
#  '@LAfitnessUKhelp done thanks :-)',
#  'Its already afternoon, lets read Al Kahfi before the day finish :)',
#  'OhmyG! yaya dub @mainedcm im done doing to stalk your ig accnt.. GONDOOO MOO TOLOGOOO :) HAHA',
#  "@rozbabes Here's your invite to become a Scope influencer :) Details here: http://t.co/ipJ2yOiGet",
#  '#FollowFriday @NGourd @Locita @D_Robert_Kelly for being top influencers in my community this week :)',
#  '@kevinthewhippet @Cassie_Spaniel @Bracken_Nelson @BellisimoBella1 @SpanielHarry thanks :) zzz xx',
#  'Physiotherapy Friday is my hashtag for today. Custom! :-)',
#  '@Cjlopez21 you know I will 💪 Monica and I miss you to, yeah sounds good to me :)',
#  '"Good morning, beautiful :)" That\'s all it takes.',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x43',
#  '@MandaScapinello oh yeah?? I am definitely going to try it tonight then! :) we took your advice too! We are in Treviso now!',
#  '@morallosanthony  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  "@NIKKIERIOZZI Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)",
#  'Fine, \n...Have a gorgeous Friday, friend!!..; xo..-:)) https://t.co/JmpkZP2DaI',
#  'Oven roasted garlic in olive oil, sun dried tomatoes, some dried basil, and century tuna :) https://t.co/EsCc9QhLob',
#  '@HostMyOffice @NigelPWhittaker @lemezma @TWBC_Business @_TheBunkerJL Right back atchya!  Have a great day everyone :)',
#  "@TeamTall17 @FlashHayer  but doesn't even follow back :-)",
#  'The future is almost here then :) https://t.co/rolE3ZCL97',
#  '#FollowFriday @Michelploria @MyFrenchCity @jasoncreation for being top new followers in my community this week :)',
#  'No chance :)',
#  '@ChiAB2486 @MrCliveC @PCDKirkwood @DC_ARVSgt @COPS_President @EmWilliamsCCCU @LauraRGallagher @Hall11Kate @LaMinx541 @JohnTarbet71 cheers :)',
#  '@thatguycalledP go po for ice cream :))',
#  '@19strawberry66 I agree 100% :)',
#  '@SpazzyTsukihara hehehehe thats the point :p',
#  '@KalinWhite next time just stay home :)',
#  '@Gculloty87 thanks :)',
#  '#FollowFriday @digitalplace2be @intlboost @_lafontpresse for being top supports in my community this week :)',
#  '@stayfaboo it will be up soon, i promise :)',
#  'Web Whatsapp volta a funcionar com iPhone jailbroken. :-)',
#  '@crustyolddeen (I plan on watching it later) at 34 mins Leia appears as a hologram from R2D2 w a message for Obi Wan as he sits w Luke :)',
#  '@Mburu__ Inter 3 UCL, Arsenal... Small team, Right! :)',
#  'Just passing by :) 🚂 (@ Dewsbury Railway Station (DEW) - @nationalrailenq in Dewsbury, West Yorkshire) https://t.co/DvBssHbrfx',
#  '@ClearlyArticle :) its 430 am smh',
#  "@uptommosass it's 9:25 am here :) I live in Scotland :) it's strange to imagine what?- Megan xx",
#  '@bookmyshow \n\n !\n#MasaanToday\n#MasaanToday\n\nA4.... Shweta Tripathi  \n !\n#MasaanToday\n#MasaanToday\n\n-.:-) .-..,',
#  '@WforWoman 5. Over 20 W kurtas! And my Mom has about half the number I have :D #WSaleLove',
#  'Ah! Hello back Larry! @TransworldBooks :) https://t.co/8XhjJb4jtH',
#  'Anyway my Friday is looking kinda gooood :)',
#  '@jhun_hunyo  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  "Lol. Well. That's life :) thank God it enn you  https://t.co/GLoCEIjGQQ",
#  '@OJBJ @holmesjsamuel surely this could be your warmup this morning ??? Coming on 15th to Bath :) xx',
#  "Dum Dum Andar - Ram Sampath, Sona Mohapatra &amp; Samantha Edwards Mein Tulane to razi razi, Wah! That's Josh :) http://t.co/ul8MARDfhm",
#  '@justinbieber :) always smile',
#  '@darlakim_ picture. :)',
#  "@arsenalnewsasit Thanks again, your time 16.20 right? That's perfect timing for me here :).",
#  '#FollowFriday @IzywayLesExpats @na4innov @InXpressCoAzur for being top engaged members in my community this week :)',
#  '@Juleeyaanaa i know :))',
#  '#GiveItUp We have already given up our gas subsidy long back when this initiative was proposed.. Feeling so delighted having done that!! :)',
#  '@dayloladay I missed this yesterday!! :-)',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x42',
#  '@jaimeemelanie_ lmaoo! The best songs ever &lt;3 We shall have our own little throwback this week (y) :p',
#  '@Clazziebritchas then go to the outlying islands, such as Cheung Chau, Mui Wo....totally different :))',
#  "#KFCkitchentours Kitchen is so clean. I'm totally amazed :) @KFC_India",
#  '@cybelxxx  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@Jana7380 on the cusp of testing the waters, hope yours is rewarding :)',
#  '#FollowFriday @BroadcastBeat @InSunWeTrust @conseilsmkg for being top influencers in my community this week :)',
#  "arummzz: Let's go... I'll drive for you :p\n\n#traveling #traveler #yogyakarta #jeep #Indonesia #instamood… https://t.co/s7y4Ys5JeU",
#  'Anyone wanna skype me? :D',
#  '@agylyxa may i look so, bit i am a real nice friendly girl :-)',
#  'Im not like them. But i can pretend~ :)',
#  'watching where we are concert film :)',
#  "Congratulations @amisharanka95, you're the winner to our #CheesyDelights contest :)\nPlease DM us your address and contact number!",
#  ':) Have a great weekend guys! https://t.co/DLDKLpeTAb',
#  '#FollowFriday @CLARAROJASG @BF_P2C @MyBusiness_Plan for being top new followers in my community this week :)',
#  '@PuaMagasiva it was cool seeing you film today! :)',
#  "Check out Email Marketing 24/7:  http://t.co/O5fjR7oEqk you won't regret if you buy it :)",
#  '@vineshpomal LOL. Come join us ... See u in around 14 hours if u leave now, without delays. :)',
#  "Actually very easy doing like this, it must be a station I guess where the train 'wd take at least an hour for shifting its engine etc :-)",
#  'sunburn is peeling :-)',
#  '@Sexdate_gratis Visit my blog http://t.co/UzOAqroWKx thanks :D',
#  "@TikoSD Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)",
#  '@no1_razorstan then talk to me. I can help you :)',
#  '"@CassTheTrainer: A Huge &amp; Warm Welcome to @VodkaBlond :-))"\n\n☆ finally we complete the triangle ! ☆',
#  '@LucienneDiver I live in Northern Ireland. :) what sights have you seen?',
#  '@Mecastor01Mica  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '#FollowFriday @Z_Intl_Agency @Tivipro @compexly for being top supports in my community this week :)',
#  'Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/6prugvmOuC.',
#  '@imraina feeling smthng smthng fr u...lol...wanna hug u....XOXO...love uu jaann take care :* :)) &lt;3 :")',
#  'thanks mom :)',
#  'Thanks #TopNewFollowers @BestOfFicPad @MrCFluegel @JeanMarcPN Happy to connect :)',
#  "@MooseAllain @MeatBingo that is the just most wonderful thing, it's made me feel all fluffy inside. Great pirouette, Moose :D",
#  "@KristophCajon I have a trip to philly in December so after that :) I'd love to come out there dude.",
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x41',
#  "The question is flawed. Pain doesn't negate strength :)  https://t.co/77TbkS2Djw",
#  "@ReflectKnives You went solo because these moves weren't being made :D",
#  'hey my fav nirvana song is smells like teen spirit rip amy winehouse :-)))))',
#  '#FollowFriday @CCIdeLYON @CCI_95 @CPNERI_ESIGROUP for being top engaged members in my community this week :)',
#  "Let's go... I'll drive for you :p\n\n#traveling #traveler #yogyakarta #jeep #Indonesia #instamood… https://t.co/s7y4Ys5JeU",
#  'did we name the couple yet?? #TomHiddleston #ElizabethOlsen ?? #yaytheylookgreat :))',
#  'I love you all goodnight. Vid going up when I wake up you all with love this one :)',
#  'This weekend I am gonna shoot the lovely @NarakuBrock again &lt;3! Here a picture I made of her last time :D http://t.co/s3e2dmpt24',
#  'anyway :-)',
#  'Itty Bitty Teenie Bikini  :) http://t.co/A2oxW0ZI3g http://t.co/jn7KSfHwRc',
#  'I just joined the #HushedPinWithSammy Event :D Might get to Text with @SammyWilk for a day! Luv U @HushedApp http://t.co/czdow1i44W',
#  'Always so much fun when 4th hour gets together. :) \n\nEnding the night with ice cream and Xfiles. \n\nContent.',
#  '@aangelayap easy :D',
#  "@NTtownend yes, be surprised if we don't see a bit of rain today... :)",
#  '@ReyesFraulein  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  'To all @fatpunkstudio have a fabulous Friday and keep up the fantastic work!! :))',
#  "@justinbieber can you please follow me @caitecat1209 ♡♡♡♡ please jb follow me I love you always and forever. I'm a belieber ♡♡♡♡ :) I love u",
#  '#FollowFriday @DiploMix @CCI_entreprises @CCI_92 for being top influencers in my community this week :)',
#  'Morning all! :)',
#  '@FranchiSeedsUK good to hear :)',
#  "@LusciousLyndee1 Nighty night! Don't let the bed bugs bite :D",
#  '@Bonsplansblog Very beautiful this bracelet! good idea :)',
#  '@guywilliamsguy waiting for you at the foundry. Where you at?? :)',
#  '@KalinWhite I like that game :)',
#  "@suzannepanter @kevinbacon @katosman Ah! Now it makes sense... Didn't see the pic on my effing phone last night. Woot :) x",
#  '@Derek_GTA Hi Derek, you could try using ParkShare in Gloucestershire http://t.co/qIF9AyAlkc :)',
#  'Aaaahhh man, this track is a traffic stress reliever. :)',
#  '#FollowFriday @elevents2 @JoussotFrench_J @NYIBF for being top new followers in my community this week :)',
#  "@El1neW How're you today my dear? :)",
#  '@Jesutomisin I hear you guys want Arbeloa. :D',
#  '@ShawnMendes turning 17 in 15 days...omg. at least we have only 3 years difference :)',
#  '@matteomeacci Well, they say Europe is on the rise again, but I find that hard to believe :)',
#  '@WforWoman #WSaleLove uncountable coz we love unlimited :)',
#  'Yes, of course :) #TeamPositive https://t.co/SaIX1VpFJF',
#  'yes i love :-) #AlDub',
#  '@coffeebreak22 @LauRenArren @drparkave @JWKanyuira1969 @dheracing @RhoaChri @BarbaraBathurst @1cryingeye @willisteam :) ☕☕☕ Thank you Rita!',
#  "@mikerobb Hi there, could you please DM us further info and we'd be happy to help! :)",
#  '@24gooch on way my boy! :)',
#  '@graphure I hope you will get a lot of nice gifts :D',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x40',
#  '#FollowFriday @ACBM_SECEM @DCarsonCPA_NYC @PromosalonsInfo for being top supports in my community this week :)',
#  'So True!!  :)  https://t.co/N2ORwrOwhD',
#  'I added a video to a @YouTube playlist http://t.co/09GuSuMrNb im back on twitch and today it going to be league :) - 1 / 3',
#  '@ZarlashtFaisal @Tabinda_Samar Sethi was HIGH ??? :)',
#  '@IAm_Lennox exe skeem saam :)',
#  'These are the people who make me smile. :) @_pumpchkin_ @aka_pump @LilfrenchMsp @_Lishielou908_ http://t.co/iDdtACkA4K',
#  '@CoSchedule Thanks for the invite. :)',
#  '@SyedIHusain polite izzat :) \nwese does she trust him? khawateen k sath selfies say to mana kar deya :)',
#  "Thank you @MovieTubePW that's my Friday evening sorted :-)",
#  '@nova_caneeee you smart :)))',
#  '@vaalthepal :-) nice hair tbh',
#  '5 years :) https://t.co/hJEhDmxuu9',
#  'jacob will there be a m&amp;g upgrade??:-)',
#  '@heydonworks Nice tee man :)',
#  'Happy family vacation .. :D [pic] — https://t.co/HL0Fw8msf1',
#  'some sleep would be nice :-)',
#  "If you're reading this, you're beautiful. \nLike this if you just read this :)",
#  'Talking to One person .... Having Two Conversations :))))))))',
#  'skype was fun :-)',
#  '@SoggyStones should be online :)',
#  "...because it's Friday :D (y) http://t.co/6rA4ZlpjO9",
#  '#FollowFriday @CCIFCcanada @AdamEvnmnt @boxcalf1 for being top engaged members in my community this week :)',
#  'Something to get your #Friday off to a great start :) Have a great day all! #Mclaren #FridayFeeling #TGIF http://t.co/LshgwcXsSv',
#  '@AvinPera  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  'square enix bissmillah ya Allah :)',
#  "@SephtonMark we're training #SocEnt startups at @TobaccoDockLon this week w/ @HelpingB - we'd love to have you drop in if youre arnd town :)",
#  '@HGVWolfie Basically you piss in a cup and they test it :)))',
#  '@ellenRstewart where are you off to next? :)',
#  '@IonSwitz @notch also, Twitter is terrible for complicated discussions :)',
#  'Snapchat me : LynetteLowe #snapchat #kikmenow #snapme #hot #snapchat #amazon #kikmeguys :) http://t.co/kd54m2IAm6',
#  'I am not looking forward to a 12 hour shift today :))))))',
#  "@ely83_ely definately agree that it's a growing sport. Drop me an email with details and we can see what we can do :-)",
#  'My last rt is me :)',
#  '...and the Rakyat will keep visiting your blog and reading your writing :) https://t.co/IMRy2BXuzd',
#  "@ryan2390 ever since I mentioned fly fishing the other day I'm getting follows and promoted posts about it lol cyber stalked! :-)",
#  '@Gurmeetramrahim #OurDaughtersOurPride #mypapamypride Proud of You Papa Coach :)',
#  '@imarpita it was great talking to you :D',
#  '@awaismarwat2011 never see positive kha u could also mention atleast they are going :)',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x39',
#  "@_pigglywiggly @Omundson The mango lassi's from Monty's are marvellous :D. Though I suspect that's not what you meant....",
#  '#FollowFriday @StayfanChemin @CCI_75 @aandreup for being top influencers in my community this week :)',
#  '@Thakurain_ Haha. Yes. I have 24 hrs. The time has come to touch the Kepler 452b. Chalna hai ?? :D',
#  '@iyah_mohamad  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@allygrrdo thankyou pretty! :)',
#  '@PinkPeoniesBlog @helloprettysa definitely the Hazel Food Market in Brooklyn, Pta :) &gt;&gt; http://t.co/ySQkhNDo2B',
#  'still awake :))))',
#  '@joiredve okayy :D',
#  'Awww thank you :)  https://t.co/9tSQv2DWVm',
#  '@AR1961 ha! That does not surprise me in the least! Okay but will see doc this afternoon. Yorkshire is splendid though! :) xx',
#  '@JRTurnerPhoto @davidqueenan @jameslturnbull spam folder: WOW! I have won a huge amount of $ I just need to travel to Nigeria to claim it :)',
#  '@PERKSOFNIALLJH RTed! Good Luck :)',
#  'My legs hurt so bad :))))))))))))))))))',
#  '@johnny_lopez96 I get mine Saturday :-))))',
#  '@imafaithreyes thaaanks! December puhon. :))',
#  'happinessss~!! :))  https://t.co/slOn63OUeS',
#  '@VaibhavVj78 @PayUmoney True that. Can you change TnC without prior notification? I could have used them last night. :-)',
#  'https://t.co/gYx34VfmkK and I  probably only find this funny at 2:22 am :-)',
#  '@aliyaskates @yoshihikomkm Fat cos he probably ate Yuna :D :D :D',
#  '@emmajaneparsons @CuriousMindsNW Have fun in Tameside :))',
#  '@hydrcted what :-) did :-) i :-) do :-?',
#  '@CharmingJedward you´re welcome!! :)',
#  'My Google+ account. :) http://t.co/R8jyDxlQyo',
#  '@2SHYMC and they call scousers for everything! Hope you and Zoe are well mate :)',
#  "@RachelEvans_28 RIGHT!!!!!! I literally was like maybe u should get people who actually know what they're doing :-) @StudentTrip",
#  '|| Sameee~ \n\nRest well :) https://t.co/T6ZCo4NxDG',
#  '@EdgarsLame happy birthday Edgar! I hope you have a good one and keep updating your travel log :)',
#  'Hello :D\n@VikkFollows @Vikkstar123',
#  '@MarreyJewAna bring Abes :)',
#  'Stats for the day have arrived. 2 new followers and NO unfollowers :) via http://t.co/xxlXs6xYwe.',
#  'someone talk to me :))',
#  'i will never be the same if we ever meet again :D',
#  '@BBCSport come on man :D :D',
#  '@prettyden15  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x38',
#  "@LivelyKaty *sighs dreamily at that pout and those 'come to bath' eyes!* :-) #quacketyquack",
#  '@_sunshinehoran_ happy birthday love :)',
#  '@Brianscrooks @burwellitltd @manfrotto_tweet Cheers :-)',
#  'Funny how that happened when Phil was here too : )',
#  "@WMFireDogs I'd call 'em Del &amp; Rodders :) What else!",
#  '@ForkH Hi, may you like play my newest gamejam game, i would be very happy about it :) http://t.co/8J5voDDHcs',
#  'This is great! Irish literature is really inaccessible to most of us without Irish :)',
#  '@BhaktisBanter @PallaviRuhail yeah! This is fun :) #FlipkartFashionFriday',
#  'Nice music :) Check it out! http://t.co/PEjHsORGrk',
#  "@_xRiya Strange Kareena's Fans Not Knowing Kareena's Fans :)",
#  'Hello :) Get Youth Job Opportunities follow &gt;&gt; @tolajobjobs @e1d4c8e25ec844c',
#  'better :)',
#  '@ArtForCause Cool. Will look for you there. :)',
#  ':)) beautiful http://t.co/F8V3McI39e',
#  "I'm playing Brain Dots : ) #BrainDots\nhttp://t.co/cHl12JvuxN http://t.co/GGgU9PYEjI",
#  "@ScreamQueenLR That's fair enough :) I wouldn't rush back either.",
#  'Brandi 18 on my FB DROP A SELFIE :) was fun https://t.co/TRoroeS4FK',
#  '@kthrnbyln  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  'During a carnival men put masks over their masks. Xavier Forneret :-)',
#  '@jennnnifer29 Jennifer, Check my site if u wanna get FREE 50.000 8 Ball Pool Coins. Thank you :)',
#  '@trisha1234 Beautiful edit, Trish! :) Loved it! ♥',
#  "Gratefulness = Happiness :) Post three things you're grateful for today in the comments",
#  'Love to wakeup beside her &amp; have some real dirty,dirty sex :-)\n\nhttp://t.co/dPLYrlTjil',
#  "@literalwt LMAOOO SAME its so hot 😤😤 like louis :) he's so hot !!!!!!!!",
#  "@MariaGM350 Just gonna throw idea at you cause if they're bad it will inspire you to think of something much better.  :-)",
#  '#FF The Best Twoofs to follow have a GR8 wkend :)\n@allpawone\n@Hungry_Hounds\n@DDWalks\n@HealthyHounds4U\n@pawsforawalk\nhttp://t.co/fIYPR3t2Ai',
#  '@cinnamoniboni I wish I could! Maybe one year :)',
#  'hey guys! how are you ? :)',
#  'I think I need to go to bed kind of exhausted good night twitter :)',
#  '@renukaVyavahare Thank you so much.. So glad you liked it.. :-)',
#  'It will all get better in time. :)',
#  "@Chelt52 Kind words - thank you very much! It's @SueRyderLCH that does so much good in the #Cheltenham area :)",
#  'Hi beautiful follow me please? :) @iggyazalea @lanadelrey @megannicole @madisonellebeer @tiffanyalvord $9',
#  '@astro_lass They weren’t kale crisps :-) Why ruin a good thing?',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x37',
#  '@mykidsloveme2 Open Worldwide :)',
#  'get the fuck outta here :D https://t.co/neJd4AaQWZ',
#  "@StreetFighter Cool down guys. It's #SFVBeta, not release. They work on it. :)",
#  '@CrazyLeoNet @Woodslenny @MSportLtd @FordPerformance It really looks Vantastic :) @VBGIE @FordOwnersClub @autocultureirl',
#  'Today I finally have time to work on Xcylin again :D',
#  '@UPCIreland Thank you. So if its a bundle shows the internet price no phone than realisticly only paying for Net?:)',
#  '@PublicProtector :) True Education is the most powerful weapon which you can use to change the world,"Nelson Mandela',
#  '@agavrilychev2  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  "Most recent trip to J&amp;K; totally loved it :D\nAnd that's 'Chenab' there which flows into Pakistan.\n#incredibleindia http://t.co/1EHnC4mxZL",
#  'My #TeenChoice for #ChoiceInternationalArtist is #SuperJunior! :)',
#  'Caught my first salmon today :D',
#  '@annaelerihart - happy Friday! Just checking in to see if you enjoyed our Super-Blend? :)',
#  "@MrsManfyDiston Thanks for following! Do get in touch if you'd like any more info about our project: youth@bipolaruk.org.uk :)",
#  "Please go check out my awesome friend's stream at http://t.co/uVBD0iDwDW ! He's a fantastic artist. :)",
#  'My Alma Mater :) #HighSchoolDays #ClientVisit :) @ Faith Christian School https://t.co/OiWrwoFuY1',
#  'Good luck to #LizaMinnelli for her upcoming UK appearances :-) @GaryJHorrocks @ScottGorenstein http://t.co/r1ExrOTFBP',
#  "@messiholic_ Lol 😄😄really?  I can't believe a beautiful girl like you are single :p",
#  'I will never be listening to The Hills every again :-)',
#  '@dantoml why would you listen to Beats 1? What went wrong in your life? :)',
#  "@concertina226 Haha that's great :)",
#  'Getting everything ready for my Natural Pefumery Workshop at Neals Yard, Covent Garden - tomorrow :) http://t.co/WYEE7cbqOZ',
#  '@grannaHarmony fback :) indo harmos',
#  '@ewoksurewok just Americano :)',
#  'Why am I up :-))',
#  '@SquadKathNiels @bernardokath i LOVE the way you are :) &lt;3',
#  '@thevaas @Vasan_Bala ALWAYS Remember :)',
#  'Aww! Thank you. Beautiful pic :D  https://t.co/044Hfi99Rc',
#  '@Podolski10 heads up! :)',
#  '@jessicaswift_13 Hi! Saw who u follow and thought u might like "Dark" https://t.co/QSaoyO8CIk .Plz let us know what u think :)',
#  'Smart, handshome, cute juga :D https://t.co/7DC0LU3j9k',
#  '@LauraSummersNow @STWevents hurray! Looking forward to meeting you too :)',
#  '@tomokawaiix  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@liilss cause hate my course lol but I cant decide what I want to change to so Im just going to take some time off, save $$, maybe travel :)',
#  "@WoollyWormhead It's on my to do list if I'm still at the show :)",
#  '@realiseagency you too :)',
#  "@LoreTam Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)",
#  '@jojoaro0618 @danisnotonfire @AmazingPhil Oh awesome, thank you so much! :)',
#  "@CaityYoungblood you're perfect. :)",
#  '@lcfcset Hiya, if you email our web exec, Loryn.Good@lincs-chamber.co.uk, she will be able to help you. :)',
#  ':) enjoy photos from before/when my mom was a baby http://t.co/1wqZetbvQu',
#  'BIG thx @bikechainricci 4 the kind support @SHINEUKCharity @ShineBalloons. GOOD LUCK!! :-)',
#  '"Chinas actually a girl.\nThat or a homosexual."\n"But we will love him/her either way." \n:D\n#HyungBot',
#  '@Gamer1811 cause i likes him a Lot :)',
#  '@mattghouse give me some time fam, I got some things in mind :-)',
#  "Thanks God it's friday :) #jgh.",
#  '@ashtonparsonsuk @LypsylUK how lovely! :)',
#  '@heartsouthwest #timetunnel 1982?. Not quite sure if my radio is set at heart :)',
#  '@jackgilinsky Hiii Jack :) ily ✨✨✨',
#  '@smartcookiesam @Confarreo I played dominoes in a pub once. It all got quite heated! Enjoyed it though :D',
#  '@hostclubhowell no prob!:)',
#  '@danvpeterson Enjoy! And sorry about my hastily typed message! :)',
#  '#FF @dreamshakes @marketsmatter @MrsMarketUK @CheshireLadders @Streetzine @jewellery_bank @luvthenorth444 @BlueAppleHeroes thank you :-)',
#  'Can I just say a big thank you to the person who came up with the idea of screenshotting :-)',
#  '@AshrafUzma @RTAluvedAfridi \nWe are not true Pakistanis :p',
#  '@Raj_Poot_ :) ... mention not',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x36',
#  '3Points for #DreamTeam Gooo BAILEY! :) #PBB737Gold @PBBabscbn',
#  '@crisasingson07 Thank you :)',
#  '@addictionguy You drank because of it? :)',
#  '@ernezpjy its old pic :)',
#  '@sharleneyupasc1  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  "I haven't gotten any sleep and I have to be up in 3 1/2 hours :)))))))))))))))",
#  'Off to #Welsh #Wales today. Yippee! :-) http://t.co/BdaXV35FYE',
#  '@stalkerIDOL_ done :)',
#  '@fwmkian HAPPY BIRTHDAY BABY 💟💟 I MISS YOU SO MUCH AND LOVE YOU SO MUCH :))',
#  'thanks bro ! :D x',
#  'thats my lord :) http://t.co/7O5XaValPN',
#  'Sweet :) https://t.co/025WcVvnxe',
#  '@riprap1 We like you Michael :) Thanks for your kind words! Cheers, Em',
#  "@coxn8r Morning to you too? Not really :D U're already having fun cause its weekend right? :D ure in the future ;)) Have an amazing night",
#  'Waiting for the people to call him BIGOT :p  https://t.co/WGvM79ySv1',
#  '@yezzer It usually is :) Are you doing front or back squats?',
#  '@BeingSobtian1 it was so much fun really enjoyed it hope next contest will be coming soon :-) :-) :-)',
#  'Dobar dan :)\nThe Brand New Heavies #musicology2015 #day2 http://t.co/ejDalpfixn',
#  '@Chileeers looks like a great way to spend a Friday afternoon! Enjoy your marathon on iflix! :)',
#  '@itsAllieFx If you need someone to talk to, I am always here :) Keep your head up.',
#  'Officially Graduated :D http://t.co/B1jXLiL3Pi',
#  "I'm so glad! :D Did you cry? ;__; https://t.co/YbgI6MoxnE",
#  '@Afl2277 thanks. :)',
#  '@applewriter yep, you *are* an expert on bisexuality :) Good luck!',
#  '@jiarpi20 minal aidzin yo pi :D',
#  '@imlexapadilla  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@Riverford The plan is: read our brand new cook book and figure out what to make for dinner tonight! :)',
#  "@snxy lol it's a tough choice tbh i really do like every song, just some more than others :p",
#  '@JessopJill welcome... :-) :-)',
#  "chill at SMU oval :D\n'Coz I am a of basketball player now. Whahahaha!\n #SOAmazing https://t.co/Y3sDCZ6RMk",
#  "The moment I decide to log onto the account I haven't been on in years is the moment I saw the best thing ever :) http://t.co/pu6B5jodur",
#  '@WforWoman \nA5. If I was a Girl,\nMy Wardrobe would only and only have "W" in it :))\n#WSaleLove',
#  'new user! :-)',
#  '@umar_farouk7 Welcome back to #TeamRed :)',
#  "@emily_etc oh apparently I'm already a member ! Lol! Hopefully be able to come depends on the time !  :D",
#  '@Kayleigh_A all greatly appreciated! :)',
#  '@lnnamnd hi! we made some changes in our design, hope you like it :) https://t.co/EXt098Yq1b',
#  '@makotobio ahhh yes do that! :D',
#  '7th CinePambata Video Festival: Complete mechanics and official entry form may be downloaded from http://t.co/YaYzAbtHtX. Sali na! :D',
#  'Hello :) Get Youth Job Opportunities follow &gt;&gt; @tolajobjobs @NdumisoNkosi5',
#  '@WooDotaMel  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  'when ur moms getting u swishers and ur copping Monday :) http://t.co/qEdmlJLRNt',
#  'My Song of the Week is Ducktails - Surreal Exposure #SOTW https://t.co/BeXVWh7zIR Jingly jangly loveliness! :-)',
#  "It's the #Halesowen #BlackCountryFair tomorrow! Are any of our followers going? Come and say hello - our stand is on the High Street :-)",
#  'Good luck to @georgeeJgibsonn in the assessments today! :)  https://t.co/POpXUSh1ab',
#  '@etherealmind such mental strength! :D',
#  '@TsMagicCandy Looking beautiful. You have an amazing body. YOu just ooze sex appeal :) xx',
#  'HOME - AmassiveoverdoseofshipS - http://t.co/2q38loegUq\nlatest vid from up my way..enjoy and visit my site..:)',
#  '@TheEmblaze @cnni ISIS Chan!! :D',
#  '@SonyMAX T&amp; C noted :) #PKwalaSawaal',
#  'Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/uo3T40FtCQ.',
#  '@GemmaPriceUK Thanks for the follow Gemma, and enjoy New Orleans :)',
#  '@POTUS #fever finally caught up with me \\o/ \\o/ \\o/ .. #GESKenya \n#ObamaInKenya #MagicalKenya :-)\n#GreatKenya #AllGoodThingsKE',
#  'It is funny, that the next anime that had it, was Umaru :D',
#  '@sothcott @CaseyBatchelor @BondedByBlood2 great singer too :)',
#  '@xx_dayan  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@amiibofiguresuk looks like GAME ships to the US again! Got my order in :)',
#  "she takes over my room &amp; my car once I'm gone cool :) http://t.co/kQxSNy0xK2",
#  'going to be streaming soon :)',
#  '@icy_suan thanks :)',
#  "@valenaty_4ever Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)",
#  '@naqvisahab1 \n\nHahaha everyone has a fun story related to that song. We got labeled as the worst batch by the principal due to it :p',
#  '@jess_o_lover101 you will get the same stuff like in March. Release that one first before starting a new one :)',
#  '#FF TOP Twoofs have a Wooftastic Wkend Guys :) \n@MerlynTheCollie\n@BarksBunnies\n@JessPals \n@MollySniffs\n@WobblyCollie\nhttp://t.co/fIYPR3t2Ai',
#  '@DescentHypnosis Well received but not necessary. :) https://t.co/mRAJMGm0Nm',
#  '@ayushmannk long time no see :/ where have you been ? :p',
#  "I'll regret rn tomorrow morning but its whatever :)",
#  '@BadBoyBunny @Clawzskunk That hat :D',
#  '@bergsplace @RunJumpScrap @thatchamdad @simplybeingmum @loopyrach @Deardads1979 @mummyvsdaddy @harryshonestmum thank you :)',
#  'there will never love again in your life there is\nonly a success :)',
#  '@MikeyyGee_562 @thatdudegalvan_ abstinence :)',
#  '@samm_amberr Then there will be a few "Wtf this never happened?!!" moments that you may or may not like. But there\'s a surprise thrown in :D',
#  'Start middle and finished :) http://t.co/k715EtENT3',
#  'Im back Twitter.. :-)',
#  '@JackJackJohnson ended up happy. :)))',
#  '@marthasydenham @alexxdouglas @wordpressdotcom Lovely stuff. This needs to be repeated, relentlessly, for approximately the next 5 years. :)',
#  '@Smileformeacc  *hug* you have many :)',
#  '@RuneScape @OldSchoolRS on OldSchool Runescape :)',
#  '@ourseasidebaby @MrsRobinsonme Thanks for the shout out! Have a wonderful weekend :)',
#  'REST DAY!! :) https://t.co/yqaWKHap1i',
#  'LOVELY DAAAY! :D',
#  '#JUMMA_MUBARIK &lt;3 &lt;3 &lt;3 \nto aLL #FrNds  :* \n          #StaY_BlesseD :) :) :* — feeling blessed',
#  'I can sense it :)',
#  '@LittleMissLilia @EmInTrouble Awww, they are pussycats! :-) xx',
#  '@min0rthreat_ hope everything is going great!! :-) lol',
#  '@PinkPeoniesBlog @helloprettysa Market on Main just launched in Pretoria. :)',
#  "'Do I care??'\n'I care...'\nhttps://t.co/gL6rL6mR70\n#fahrinahmad #tengkuaaronshah #eksperimencinta :D",
#  'Tykkäsin @YouTube-videosta http://t.co/p5dAKaodMx 200sub special!! | 15e PaysafeCard Giveaway!! :) (LUE DESC!!!)',
#  '2 months waiting and I finally have my @Jack_Septic_Eye hoodie! :) eeeep! Yay! #SoHappyRightNow',
#  '@FilikIrisha mmmmmm can I c them lovely azz-sets babe :-)',
#  '@normabattle thx for the feedback. Glad you gained value from it. :)',
#  '@Michael5SOS good night lovely, I hope you have a peaceful nights rest, and feel refreshed when you wake up, sweet dreams :)',
#  "@OldManGamin72 I'll never get used to that, but thank you very much. :)",
#  '@thinkingdifrnt Thanks Manthan! Stay tuned with us :)',
#  '@blogadda Freshness is the beautiful smile of my mother &amp; the determination to make the most of my day :)\n\n#MaxFreshMove',
#  "I'm playing Brain Dots : ) #BrainDots\nhttp://t.co/MifDDs7CQS http://t.co/WtIWoeATPj",
#  '@JamesBourne PLEASE JAMES WHAT YOU THINK OF MY BEAUTIFUL GIRLS ARE THE LONELIEST TATTOO? You have changed my life. :) http://t.co/7ywV5U8sGU',
#  'Hi ! Girls :).wish you all a Happy #Friday.and a #magnificent #fantastic W/E.@LoriShemek @thebikinichef @AgingBackwards @pilatesbodynyc ♡♥♡♥',
#  '@rskdance2011 @southasianartuk @Keranjeet we achieved it together! Thank you Rashmi for your time, dedication and complete inspiration!! :)',
#  '#FF #HappyFriday @szekifer @phattony138 @djchiavistelli @DJ_CharlieD @Paul___Rayner the weekend is nearly here :-)',
#  '@Biblioticaa I only retweeted :)',
#  "@naturalsystah It will be updated soon I'm sure. If you sign in you can set up text alerts :) |DA",
#  'Something new :D http://t.co/3Ftb0woQhM',
#  'Dang that is some rad @AbzuGame #fanart! :D https://t.co/bI8k8tb9ht',
#  '@HardcoreGooners @tashagunners @kirstyburns3 @aprilburton21 @liztc2 @Miss_Boots1 @zannatur @NativeNoddy @NatG_22 @Ms_T_P CHEERS #TGIF :-)',
#  'Massive congrats to Niamh Fennell here :)  Journalism Graduate Lands Dream Job Copying &amp; Pasting Tweets http://t.co/3db8Bj5trk',
#  '@ice_crystal @Elbow @MeatBingo @govindajeggy Thank you! :)',
#  'Stats for the day have arrived. 5 new followers and NO unfollowers :) via http://t.co/KfqcXZSVOT.',
#  '@mrkennyt90 Yesss I am thank you :D',
#  'I have Ariana grande Selena Gomez Louis tomlinson Rita  Liam Payne \nCaradelevingne 🌷I trade solo dm :)',
#  '@DomSequitur tired. But fine :) you??',
#  '@ohvdqohcdjroc Nope you can definitely still apply for this year if you want to :D #iamCA',
#  '@ashleylynch @wetsprocket Ah, found it, thanks :)',
#  '@BOYFI_MW aftie :p',
#  'Goodmorning :)',
#  '@AnneMOrbs  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@bjoernknafla @s_whiteant that’s EXACTLY the look I’m going for :D',
#  '#ProKabaddi Koel Mallick @YourKoel recites the "National Anthem" for @StarSportsIndia On Day-6!!:) http://t.co/ORqau4PvVz',
#  '#YourNaturalLeaders and #YoungNaturalLeaders\nMon27July #Cumbria UK :) @yournaturallead \n\n&amp; #Flockstars Thur30July ITV\nhttp://t.co/lYxDIByo2o',
#  'For most of you it is #GoodMorning but for me it is #GoodNight...\n#sleeptight for me and #haveagoodday for you!  :)',
#  'Only one leg on September. So perhaps BB will promote the full album on September :D\nhttp://t.co/ZV1HdZB7Nm',
#  'I still fully intend to write as many game designs as possible while there. And an attack plan for the next 6 months. &gt;:D',
#  'To all the birds out there, come here and join us for a little fun :) #teamAdmicro http://t.co/35EZmlW16u',
#  '@theCIGirl @LeRoiHaptalon @stpierjane @HeadwayGsy @cheshiregsy #FridayDownpour - hope it clears for the wkend, have a good one :)',
#  'time for sleep :)',
#  "That's three words! But then again, that's what Rohit does to you :D https://t.co/YacazN2T0h",
#  '@XxGoodGoddessxX you are such a gorgeous queen.... my god :)',
#  'The long wait is over :)\n#OTWOLGrandTrailer',
#  "If you didn't get inspired by the sheer fact that Obama beat innumerable odds to become US President, ni shauri yako :-) #MemoToHaters",
#  'Everyone should go drop @Pwincessly a follow on her stream :D http://t.co/WMAZJqO51K',
#  '@nanavisitor  Happy Birthday for sunday! :) Hope you have a great day, lots of pampering and love!',
#  "@KingCo915 t'was great! thank you! :)",
#  "i'm going for the cabincrew interview in langkawi this 1st august :) please wish me luck @AirAsia @tonyfernandes http://t.co/EVJx7iu4W4",
#  '@buzylizzy1 @tlntweets @NutzAudio @LiPSMACKER_UK @instyle_UK @Jewellery4 @InterfloraUK @IcelandFoods @IloveHQ Thank you! You too :D',
#  'I will fulfil all your fantasies :) 👉 http://t.co/Bp1jrOakrB 👈💖 http://t.co/JtSNMUdpnF',
#  '@virtuallykaren cool - thanks for thinking of me - hope all is well :-)',
#  '@jet_cer  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@KrissyDClayton thank you so much babe :D',
#  '5 ex-twelebs this side please :)',
#  '@ohsexycyruz thanks bro ! :D x',
#  '@TomParker have a great day :D',
#  'Makes so much sense :D LOL',
#  '@BertolacciTweet .. we wait you :) against @Inter',
#  '#ff @JaggedEdge1 @MrsHHundal @Hutch_PR @higginsrecruit @KioskAtThePark Have a great weekend all :)',
#  '@UptownJavin @ChloeeElmoree @Eymvnique family &gt;&gt; friends :)',
#  'An apartment makeover? http://t.co/ctLa1jppdb great ideas for factory living :)',
#  '@OrchardTeaRoom @madsenjewellery thanks &amp; you are very welcome, hope it all goes brilliantly.  :)',
#  '@EmilyBett Happyyyyyy Birthdaaaaayyyy! :-)',
#  '@momoismail9 come kill it for me :)',
#  '@ZaloraID hi, im so interested about your internship program. But sadly, I cant access the Career Page. Can u help me with this issue? :)',
#  '@dischanmedia Its sad to hear about this, thank you so much for the overwhelmingly beautiful games, thank you for your hard work. :)',
#  '@Murrayyyyyyyy aha yesss! Who are you most looking forward to seeing?:)',
#  'Happy Friday you beauts! :) ♬ #FF @sophieintsticks @catecawley @Jon_Clifton78  @jasmoonbutterfl  @andreasson_ http://t.co/a794A3H7LV',
#  '@halfwaytohemmo We do love to help! http://t.co/X31Iw7dile :) /E',
#  '@BionsenBeauty would love to win this deo is faaaaaabulous! :D #FreebieFriday #aluminiumfree #stayfresh xx',
#  '@MrLythgoe @MeatBingo Yes, and John :)',
#  "@ithloopwithcoco Thanks!   No worries, I'll navigate to your blog and check it out. :)",
#  '@zara_arsalan thnks progrmr :-)',
#  "@lewisssrg92 bet you do! Well I won't be getting any sleep it's a 9pm shift until 9am so it's quit hard work! But thank you :) xx",
#  '@arabicaah figures :-)',
#  '@andreaholzner hardly surprising that roses inspire so much emotive poetry :)',
#  '@R0CKMYDNA followed :)',
#  '@iFLYflat I joined the @VirginAustralia #FrequentFlyer program :)',
#  "I always end up breaking down and apologizing when I shouldn't have to. fuck me for being too nice :-))))))))",
#  '@tonywhittaker Fabulous! Well we hope you all have a great day :-) ^KB',
#  "@MusicTubenl Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)",
#  "@ignitionphoto You're very welcome. :)",
#  '@HUNCOY Visit my blog http://t.co/UzOAqroWKx thanks :D',
#  '@kunal8966 @Uber_Mumbai Did you enjoy the #LondonDairy #Icecream? Share with us the experience. :)',
#  '@LeahCarla11  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@Playacreep I luv urs too :-)',
#  '@craftbeercoll I have in the past. A hoodie covers a lot of sins. :)',
#  "@AstonMerrygold bet your excited :) :')  xxxxxxx good luck hope it get to number one",
#  "@MSLJim You're welcome Jim! Made me chuckle on the train this morning :-) Happy Friday to you too!",
#  '@KageYashsa Shopping for a bit :p',
#  '@JadeTheMong agreed haha :p',
#  "@BakingBar Happy Birthday! We're positive it will be full of cake :)",
#  '@Nobicate Doh! 500+ Subscribers are needed :) Please let us know once you reached this number.',
#  "@The_ScriptNinja I'm good thanks hope all well with you and yours :-)) xx",
#  'Dry, hot, scorching summer #FF :) @infocffm @MediationMK @ExeterMediation @KentFMS @EssexMediation',
#  '@tom_peters @pallavijha Maybe a younger woman has more stamina than you Tom&gt; :)',
#  "@digestdigital things aren't looking too great here either - can we expect anything less? lol! At least it's the weekend :)",
#  'Finally get to be in bed. :) good night, tweeties!',
#  '@anish_kochar @bangaloretrance Thanks guys! :)',
#  '@alistairbeech FAB! Thank you for your support :)',
#  '@TurnUpTexas I really dont I love you so much :)',
#  '#FF follow her --&gt; "@__KaraboM: 10 loners this side please :)""',
#  '@RiahanneNavarro and a charger :))',
#  'This is so me :-) http://t.co/9aqyX0UxuV',
#  '@electricgecko (Introducing a new word vs. altering the understanding of a word) x spreading either = The Big Problem. :)',
#  '@JAOlivar0731  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '#FF my Wooftastic TWOOFS hope you have a supa dupa weekend :)\n@MyPackofWolves\n@Skythegsd\n@helvellyn\n@BennyBoygr\nhttp://t.co/fIYPR3t2Ai',
#  '@clivewalker near enough to Dartmoor :)',
#  "@buymobiles_help I'm gonna stay with the gold colour. Hopefully it will come soon. Thank you anyway :)",
#  '@Taylor_Marisa Follow back ? :)',
#  '@ijn_mikky yay ok!!! :D',
#  "Someday we'll know. :))",
#  '@Smiling_Girly_  U r my dii n i cant forget my Sis :)',
#  'Jgh fr. smf &amp; Ft, W/ My girl. &lt;3 :)',
#  'maybe we can get some japanese import hello kitty matching stationary :)',
#  'The weekend is drawing close.  What are your plans ? :D http://t.co/ag4r421hF1',
#  '@peterlizmaher Hi! Saw who u follow and thought u might like "Dark" https://t.co/aloXWsqdjh .Plz let us know what u think :)',
#  'AND HELLO TWITTER, MY ACCOUNT IS BROKEN AGAIN :)',
# ...
#  "@Parulcoolthougs I'm here if you want to talk :)",
#  'I always tweet hit me or snap me... no one ever does but its worth a try :)',
#  'The homies bought me skins for my bday :D',
#  '@awadkum - Just chant Jai Italy 100/times fast. :)) @BJP4India @AmitShahOffice @narendramodi',
#  'Heeeeyyy. Can all of you follow my fan account? @KINGT0MLINS0N \n\nThank you! :)',
#  '@leonrestaurants in the UK :)',
#  '@JEDIEV11 thank you!! :D',
#  '@Blahkumaran woah! nice nice!! :-)',
#  '@cuteHiddlesmile u are welcome :-) ♥',
#  '@lucahollic good and you ? :)',
#  "And here's @mayankw14's ★★★★ review: http://t.co/wNVIPDDRe6 Phew! We're literally overwhelmed. :)",
#  "@PatoFer222 Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)",
#  "@Anaateresaa_ you &amp; the baby😊😊😊 next time , it's my house ! I have it whenever :)",
#  '@TfLWaystoPay got it, thanks g :)',
#  '@jonathanhobbs71 Have you encouraged your employer on board (http://t.co/sczAWaxEW0) or stuck a poster up (http://t.co/J024E6Dwvk)? :)',
#  '@MsKristinKreuk Hugs ang Kisses from the philippines :)',
#  "I've entered to WIN a huge @BlueMicrophones package from @CazuaLLUK &amp; @Marzbargaming :) ENTER HERE: https://t.co/yRlT7jltqP #Giveaway",
#  '@Jim_Edwards yes, it works now :)',
#  '@reyes_reynaldoz  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  'Hi @BridgeHouseThel , great to connect. We specialise in thermal imaging surveys – here if you need us :)',
#  '@juanchavarin52 @taliagarcia__ yeah so you can bruise my rib again :-)',
#  "@PallaviRuhail @BhaktisBanter #FlipkartFashionFriday 😀😁😂😃😄😅😉 No No won't give dear don't worry :)",
#  '#TombRaider #hype thought you might like this @MelonieMac :D http://t.co/aXxprx1PRz',
#  'Oh Me Oh Me Oh my its #TheJuiceInTheMix @POTUS rela @talliaoyando in the building :) @HomeboyzRadio @DJBashKenya',
#  'Low priority match :) hahaha',
#  '@dxuntlesslarry fback? :)',
#  '@HelpingGroupDms I want Harry Dm bc I wanna give a surprise to my friend for her birthday. I just wanna make her happy :)',
#  'Is now not an opportune time 2 collapse chaotic Cosas? &lt;--- note the alliteration :-)  @NomalangaSA @barrybateman @AndileMlondo',
#  "@sungjookxm going well oppayaa! How's yours? :D",
#  '@khalidALSALEM @Azizsm_ we did our best, as you want body :)',
#  "#NatGeo new show U can't lick ur elbow. .seems interesting....:)",
#  'Stats for the day have arrived. 7 new followers and NO unfollowers :) via http://t.co/C6u8lINDwD.',
#  '“@MileyCyrus: Emu is stoked thank you :) http://t.co/l5Xyt9EM6G” @creampuffshinee',
#  "Woke up yo @trentowers fav' my tweet this made my day :))) now just @luketurner89 😂😂 http://t.co/oGw5sVij7G",
#  "Remember, you don't need people's approval when you have God's approval. :-)",
#  'and jisung is the kid sunshine :)  https://t.co/LBjXDWIAPE',
#  '@TheLlamaverse mm okay thanks! :)',
#  '@noodles78 Message us right here Nicola and we can forward this on :) Brighten up our day :D Helen',
#  '@_dreyaniks  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@sunofsides CONGRATS :)',
#  "@gunnersx4 Hi Brian I'll  get it shipped today for you and it can take between 2-3 weeks to Australia. Many thanks :) http://t.co/IBoe0e1aXt",
#  "@JanPrince63 @AWonderBall was good fun at the time but the ol' bones are now a creaking :)",
#  '@Mokhenerale Eh abUtI, WelcOmE to TweetLand.....Lol :p',
#  '@davidc79 thx! And Android support in by Xmas :)',
#  '@phedran A great Skyblock stream too. :)',
#  'this is why im standing and always being a Belieber :) its all bcause of him @justinbieber 2009 until Die :)',
#  '@BOHEffy I am streaming now on Twitch Join :D\nhttp://www/twitch.tv/lockedbeast1',
#  '@BRBCODY it was a.. sympathy laugh :)',
#  '@huskar_nana who would you like? :) xo',
#  '@DrtyChimichanga Awesome! :D',
#  '@kimtaaeyeonss unnieeee!!!:)',
#  'Tonight is the Night ... :) #nuka #penacova #djset #free #EDM #kizomba #latinhouse #HouseMusic #portugal2015 #summer http://t.co/m5WqWKfqs3',
#  "@moonlight69 well you're in for a wild ride &gt;:D",
#  '@TokyoTantra Hahaha tell me anytime you wanna taste it! oh, with yer address to send it :)',
#  '@mtnza @mtn8 thanks team yellow :) #MTN8',
#  '@Acsxy Maganda. You look very pretty with short hair. cute. :D',
#  '@MistressSaphire Good morning to you, gorgeous Mistress Saphire :)',
#  "@Aware_GinGi I'm at work and I'm busy, so I will help you once I finish and im at home :)",
#  'Thanks to amazing 4000 Followers on Instagram\nIf you´re not among them yet,\nfeel free to connect :-)... http://t.co/ILy03AtJ83',
#  'Coconut Sambal Mussels Recipe :-) http://t.co/FSfkpOwTpS',
#  'Thanks Kalin :) http://t.co/ihELksfJjT',
#  'Follow @JaHz73 on Mixcloud :)\n\nhttps://t.co/HviVk8rMmp',
#  '@L0MLHES fback? :)',
#  '@implodingpika Thankyou ! Greetings from Australia :)',
#  '@MIKEYGEE110 I cant work out if this is sarcasm or not :), i know some Chelsea supports think hes useless but when he comes on he does ok.',
#  '@IBePyari follow back :)',
#  '@aubreysablan I come back next Thursday!! We can still hang out :-) hehe she said hi love u',
#  '@shaunamanda2012 Benson is gorgeous!! Thank you so much for sharing him with us :) You can also enter on our Facebook too...',
#  '@ItsLukeEv you look a solid 16/17 :)',
#  'Great night! :D',
#  '@primavera_bella 30°C 😜\xa0so we just should change for few days and all is good :)))',
#  'Add me on Snapchat - MaryHicks18 #snapchat #kikmeboys #photooftheday #fuck #chat #musicbiz #sheskindahot :) http://t.co/plFpD86iEq',
#  '"fleekile mbalula", he said. i repeat, i love my south africa. :)',
#  "when your friend is making fun of the fact that your mexican so you hurt his feelings that'll leave him scarred for life :)",
#  "@SophiaDelPizzo it's my office today :)",
#  '@jeremygutsche we like this amazing donut recipe! we share with #foiegras lovers! :)',
#  'Despite the weather today the wedding is going to be beautiful :)',
#  'Where Was Tony Stark? :) - From Incredible Tony Pictures http://t.co/uwhGYM0BWb http://t.co/pHp6OcHlXH',
#  "To sit and write poems or stories that's been bubbling in my head~ :)",
#  'Last night :))) http://t.co/8EDHMc2tiJ',
#  '@EmilySmith_91 Dale send a billion kiss to her :) Have a magical day!',
#  '@mcllary That might work :) Have a great weekend. \\OP',
#  "Smile, it's #friday :) #TGIF #weekend http://t.co/L6KxKEAl75",
#  'i will not cast my vote in next elections :) #JCReport',
#  '@PebbleHelp Have done! Thank you for your tweet :)',
#  '@JILLCLARK1808 @BigAl_lfc @SuePeace1 @michell47881905 @Bevanns @susanhorgan1 Oh piggin just go will yer, give us some peace :)',
#  '@alElizabeth Appreciate the follow :) have you heard of our botanical soaps?',
#  '@Ashton5SOS @5SOS love u 2 :-)',
#  'Late upload. Freshly done/3weeks old healed. :)',
#  "@Im_MsKittenns oh. I was in bed haha. I can't sleep though. My day was too exciting :)",
#  '@TOBMAST3R @inspchin @koeitecmoeurope @TanikoHorigome @GoldxFierce @Kronin1 @Addictrian @chako33 @MatthewRumple thx Tobi-bro! :D',
#  '@nikimcglynn How good is that! I think it was my first ISP too! :)',
#  "@tessasmith4evr @BlueBellEMS we'll steel some from the @BlueBellEMS next Wednesday and see what it's like!:)",
#  'hey there :)',
#  "@camerondallas definitely loves making people smile cause I swear since I met him earlier, I haven't stopped smiling :) i love you cam 😭❤️",
#  "@SabihaMahmoud ... except for her Lord, masha'Allah :)",
#  '@NeilWhoreAnn some French fans made a movie about the WWAT in France last year with our videos and photos :)',
#  '@max_pen1 It has been fixed, thanks for your feedback :)',
#  'Thanks to everyone who came to the stream :D Hope you guys enjoyed. Night all!',
#  '@siddichan @Twitch YAAAAAAAAY thx :)',
#  'Looking forward to reviewing ours :-)  https://t.co/y8SUBXjqXk',
#  'Thank you Beiruting :)',
#  '@coolkidsftnjh fback? :)',
#  'Thanks for updating your profile page @AlexaPoppe :-)  http://t.co/JK3NSXIRMe',
#  'Lovely coffee :) @CoffeesToGo1',
#  "Here's a cute panda to make your day! :) http://t.co/zCaWqrjSvr http://t.co/FuZNhjGWD7",
#  '@x0lovestephi thank you eonnie :))',
#  '@stokebrisbane Hi! Saw who u follow and thought u might like "Dark" https://t.co/CFl0s5hwWw .Plz let us know what u think :)',
#  '@Polished_teeth my favourite too! :) @ciatelondon Cream Soda :)',
#  "I love my body, when it's fuller, and shit, even when it's not lol. I'm just happy to be healthy :) happy to be happy.. 💓",
#  'Rettweet :-) http://t.co/l6T0rx7bEf',
#  '@DianaaOrtizz the real MVG (MOST VALUABLE GIRLFRIEND) for staying up with me till the Madrid game starts :-)',
#  '@OLX_OHayoung96 sore ya :)',
#  "@tmhcuddly I'm so excited, we should definitely meet up :)",
#  "@morriskid are you coming to Bergerac?  Have the first team left any u21's I'd know of? #checking for chants :-)",
#  '@rizwanism :) just a choice of food. Left to the individuals.',
#  "@VickiCartagena The episode is excellent so far.:-) I love Adam Beach's movies &amp; shows.I'm looking forward to seeing Suicide Squad next year",
#  "Growing very fond of Christopher, didn't like him initially because he was cocky and didn't really prove it but his attitude's improving :D",
#  '@GlenOcsko sounds good! Can you DM me your email address? Will suggest some dates for a coffee! :)',
#  '@forlodge1 It is indeed - many thanks :-)',
#  'Just smile even your in Pain :) http://t.co/AxTiqf0xek',
#  'Hi happys!!:) http://t.co/AGiLlxJdbi',
#  'Funny. Intelligent, strong and funny. Just funny... :-) https://t.co/IqJwYRF52C',
#  'Hello :) Get Youth Job Opportunities follow &gt;&gt; @tolajobjobs @me1campbell',
#  '@mokwepa no, other than it using Cs :)',
#  "you ever watch certain people's snapchat over and over again, bc i know i do :-)))",
#  "@IbnNabih1 that's all ok I know your busy :)",
#  'Last 2 exams :)',
#  'forgot u were up. :)))  https://t.co/Or6eATWDjm',
#  'Fun fact: I love meeting new people :)',
#  '@jaseygalore I know the home-based office busy feeling :-) Pity about your knee - what happened?',
#  'SALE FLEUR DRESS CREAM #Readystock_hijabmart\nIDR 325.000 ====&gt; IDR 200.000 :) http://t.co/AGp51NQMbS',
#  '@pprabha014 Thankyou :)',
#  '@fernandeznoemi4  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  'Is Tompolo meeting aimed at stopping the sale of the oil that we cannot find buyers for? :D',
#  "@Centerfxld that's true, @johngreen doesn't disappoint! Looking forward to Paper Towns? :)",
#  "That's all I need to know, is that everything is going to be okay :-)",
#  '@LTBeautyBlog @FDNCoffee I say less slacking &amp; getting cracking :)',
#  "@JulieWestern I don't know the name but it is particularly striking. Happy days :)",
#  "@misshollylou Hey, here's your invite to join Scope as an influencer :)  http://t.co/ipJ2yOiGet",
#  '@DeewaniVeronica 31* My Bad Mam :p',
#  '@FrancesBeeton Lovely looking cake, bet it tastes good too :-)',
#  'FeyTyaz Follback ya :)',
#  '@dalenaha1 so I found this last night, lets just say there was an instant stiffening of my interest :) https://t.co/sw5O1Bz4y9',
#  'Rettweet :-) http://t.co/zBOvLw0y5S',
#  '@CHUBANHES fback? :)',
#  'Rettweet :-) http://t.co/CGTjR664Kj',
#  'ricky_febs Follback ya :)',
#  'Got Secrets of Grindea, Courier of the Crypts and possibly some Arma 3 to record today..... Gosh! And a new game that looks like Limbo :)',
#  '@siaramelatienza  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@MyriadPhoto  thanks for retweeting @madsenjewellery orchard art show, have a super weekend :)',
#  'Karachi ka Venice after rains :) @rizz_javaid “@JaagAlerts: Several parts of Karachi witness accumulated rain water,http://t.co/Wionr1evBo”',
#  'maroon cocktail dresses http://t.co/Ioj5YzNRwu #MidiDresses for @filipinaniah :) http://t.co/Vj1U5fIzBw',
#  '@IamPatmae_ fback po? :)',
#  '0-100 real quick :)',
#  '@Iron_Vein Morning! : ) Mine is 1100D. Usually auto-focus. I only use manual for  really close up like shooting veins on crackle glaze. :)',
#  'the new layout looks bomb! :-) \n-g',
#  "Thanks for connecting @garrowlscq Hope you're having an Great Day!  Have a social/website question? Just ask :-)",
#  '@Tweetnesian pake :)',
#  '@gabrielaliuw hi we made some changes in our design, hope you like it :) https://t.co/EXt098Yq1b',
#  'joim me while I feed the troops. :) https://t.co/ZlcsRuUpPY via @audioBoom',
#  'Any brands wanting me to review BEAUTY products on my blog? mail me at: ladolcevitainluxembourg@hotmail.com #prrequest #journorequest :)',
#  'The_MadStork Follback ya :)',
#  '@SSalchli Good luck, Shaun! :)',
#  '@madziucha_5 yes he is :)',
#  'Anyone who wants to be added to the bot just DM me!! :) #bot',
#  '@ChloeGMoretz Chloe I watched "Let me in" yesterday and you were really awesome! Really talented and intelligent actress, beautiful too! :)',
#  '@hesfallenangel could i get some free solo  dms? Any to give away? :) xoxo',
#  '@TripVerse @outboundapp thanks for sharing! Wishing you a wicked weekend :)',
#  "Hola juan.. sending you a big Hi from Houston tx! :) I've been a fan of jenni  and the family for year's.  I stumble upon a video of you",
#  '@padaleckbye. No prob.nice choker btw :)',
#  '@seoulsjin @seouljins seouljins :) both are fine tbh',
#  'Photoset: sadomasochistsparadise: Wynter bottoms- and an outtake :) Sadomasochist’s Paradise Cuties http://t.co/GNW1lwjFK1',
#  'You make my day by just smiling :)',
#  '@ghostkidluke fback? :)',
#  '@itsRebeccaRayne :D ty bby!',
#  'Please enjoy this clip of me losing my shit during cypher :) http://t.co/8FIyPQ6kkn',
#  '@athrawestokio @AdeccoWaytoWork @AdeccoJapan next week, i will be at my office ! so lets go :)',
#  '@DanielCWest thank you for following me :D',
#  'Stats for the day have arrived. 2 new followers and NO unfollowers :) via http://t.co/e644DJI0zw.',
#  '@purehaire Amen. Thanks :)',
#  'Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x32',
#  '@shyayen  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@DrenchinWine @2fai @Chompu_Kusuma paper girl :D',
#  '@gculloty87 I know would of been lovely to have her in that pic :)) x',
#  '@adnanCad Planted people are allowed to do any thing and every thing :p',
#  '@mRpOrTeR7 "This Corner" is so fucking Dope!! Getting addicted to it..\nGreat Job :D',
#  'My bby gurl :) http://t.co/S0IiU35MWw',
#  'Hey hey :D',
#  '@NickTheBullsFan @CashNastyGaming still suck at editing but if this turns into something special I owe it to you guys :)',
#  '@ayokejkt Visit my blog http://t.co/UzOAqroWKx thanks :D',
#  "@daannymoncada @breannelaflare YOU'RE UGLY DANIEL, is it good ape?:)",
#  'Happy bday @Cinemainmygenes  Saar....\nHave a great year ahead... :)',
#  '@LucyLu_xx Thought you might! I saw it and I loved the verse. The butterfly part was just a bonus :).',
#  'Thank you :-))) OK \nHave fun!!\n@anvy2446 @4HUMANITEEs @SexyAF12 @kikbella @adasamper @RachelLFilsoof\nEnjoy day u all\nhttp://t.co/5Y5OAESAzv',
#  'well. good morning. :D',
#  '@palakspatel would you follow me?:)',
#  'Busy, productive day filled with a few tears, but hours and hours of laughter. Today was a good day. :)',
#  '@17bljpk hi. You have 5sos tickets?? Dm me :)',
#  'Yummmyyy.... :-) — eating dosa',
#  '@bbcdoctorwho so do I :D',
#  '@MegLovesGames its probably easier to meet at the station? Unless you particularly want to show me your house? :)',
#  'A Huge &amp; Warm Welcome to @VodkaBlond :-))',
#  'ACHI!!!! Im busy next week because of our exams. Hope you understand that I cant tweet youuu, Bawi ako queenesther! :) @esthercarodan',
#  '@LeeMcKenzieTV Looking sharp :-)',
#  '@xWinnerMino yess im 1 year younger than u :-) no wonder youre huge boy',
#  "I'm playing Brain Dots : ) #BrainDots\nhttp://t.co/ilDzDRHf9d http://t.co/VTXNFCPFuI",
#  'Ha! All in one picture :-) http://t.co/IgLPwLvSfz',
#  '@Galatasaray @Podolski10 is ready :) #Poldi #Cimbom',
#  '@LuvSocial_Media Thanks for the share :)',
#  '@LOSTCHILLHORAN fback? :)',
#  '@24f567234e3c410  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#  '@graphure Happy birthday buddy! :D',
#  '@waterrat77 Thank you :-)',
#  '*sigh* "@Whykaysbeauty: Bruhhh“@Dopjones: Call me daddy one more time :)”"',
#  ...]

# %%
#TwitterCorpusReader object has no attribute word_tokenize
pos_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
neg_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')
#print(pos_tag(pos_tweet_tokens[0]))

# %%
def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        # stemming with lemmatization needs a part of speech parameter, so that's why we're finding POS
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

#print(lemmatize_sentence(tweet_tokens[0]))

# %%
def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
stop_words = stopwords.words('english')
#print(remove_noise(tweet_tokens[0], stop_words))

# %%
positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in pos_tweet_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

for tokens in neg_tweet_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

# %%
def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

all_pos_words = get_all_words(positive_cleaned_tokens_list)

# %%
freq_dist_pos = FreqDist(all_pos_words)
#print(freq_dist_pos.most_common(10))

# %%
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

# %%
positive_dataset = [(tweet_dict, "Positive")
                     for tweet_dict in positive_tokens_for_model]

negative_dataset = [(tweet_dict, "Negative")
                     for tweet_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:7000]
test_data = dataset[7000:]

# %%
positive_dataset
# Out:
# [({'#followfriday': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'hey': True,
#    'james': True,
#    'odd': True,
#    ':/': True,
#    'please': True,
#    'call': True,
#    'contact': True,
#    'centre': True,
#    '02392441234': True,
#    'able': True,
#    'assist': True,
#    ':)': True,
#    'many': True,
#    'thanks': True},
#   'Positive'),
#  ({'listen': True,
#    'last': True,
#    'night': True,
#    ':)': True,
#    'bleed': True,
#    'amazing': True,
#    'track': True,
#    'scotland': True},
#   'Positive'),
#  ({'congrats': True, ':)': True}, 'Positive'),
#  ({'yeaaaah': True,
#    'yippppy': True,
#    'accnt': True,
#    'verify': True,
#    'rqst': True,
#    'succeed': True,
#    'get': True,
#    'blue': True,
#    'tick': True,
#    'mark': True,
#    'fb': True,
#    'profile': True,
#    ':)': True,
#    '15': True,
#    'day': True},
#   'Positive'),
#  ({'one': True,
#    'irresistible': True,
#    ':)': True,
#    '#flipkartfashionfriday': True},
#   'Positive'),
#  ({'like': True,
#    'keep': True,
#    'lovely': True,
#    'customer': True,
#    'wait': True,
#    'long': True,
#    'hope': True,
#    'enjoy': True,
#    'happy': True,
#    'friday': True,
#    'lwwf': True,
#    ':)': True},
#   'Positive'),
#  ({'second': True,
#    'thought': True,
#    '’': True,
#    'enough': True,
#    'time': True,
#    'dd': True,
#    ':)': True,
#    'new': True,
#    'short': True,
#    'enter': True,
#    'system': True,
#    'sheep': True,
#    'must': True,
#    'buy': True},
#   'Positive'),
#  ({'jgh': True, 'go': True, 'bayan': True, ':d': True, 'bye': True},
#   'Positive'),
#  ({'act': True,
#    'mischievousness': True,
#    'call': True,
#    'etl': True,
#    'layer': True,
#    'in-house': True,
#    'warehouse': True,
#    'app': True,
#    'katamari': True,
#    'well': True,
#    '…': True,
#    'name': True,
#    'imply': True,
#    ':p': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'love': True,
#    'big': True,
#    '...': True,
#    'juicy': True,
#    'selfies': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'perfect': True,
#    'already': True,
#    'know': True,
#    "what's": True,
#    'wait': True,
#    ':)': True},
#   'Positive'),
#  ({'great': True,
#    'new': True,
#    'opportunity': True,
#    'junior': True,
#    'triathletes': True,
#    'age': True,
#    '12': True,
#    '13': True,
#    'gatorade': True,
#    'series': True,
#    'get': True,
#    'entry': True,
#    ':)': True},
#   'Positive'),
#  ({'laying': True,
#    'greeting': True,
#    'card': True,
#    'range': True,
#    'print': True,
#    'today': True,
#    'love': True,
#    'job': True,
#    ':-)': True},
#   'Positive'),
#  ({"friend's": True,
#    'lunch': True,
#    '...': True,
#    'yummmm': True,
#    ':)': True,
#    '#nostalgia': True,
#    '#tbs': True,
#    '#ku': True},
#   'Positive'),
#  ({'id': True,
#    'conflict': True,
#    'thanks': True,
#    'help': True,
#    ':d': True,
#    "here's": True,
#    'screenshot': True,
#    'work': True},
#   'Positive'),
#  ({'hi': True, 'liv': True, ':)': True}, 'Positive'),
#  ({'hello': True,
#    'need': True,
#    'know': True,
#    'something': True,
#    'u': True,
#    'fm': True,
#    'twitter': True,
#    '—': True,
#    'sure': True,
#    'thing': True,
#    ':)': True,
#    'dm': True,
#    'x': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({"i've": True,
#    'hear': True,
#    'four': True,
#    'seasons': True,
#    'pretty': True,
#    'dope': True,
#    'penthouse': True,
#    'obvs': True,
#    '#gobigorgohome': True,
#    'fun': True,
#    "y'all": True,
#    ':)': True},
#   'Positive'),
#  ({'yeah': True,
#    'suppose': True,
#    'lol': True,
#    'chat': True,
#    'bit': True,
#    'x': True,
#    ':)': True},
#   'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True},
#   'Positive'),
#  ({'💅': True, '🏽': True, '💋': True, ':)': True, 'see': True, 'year': True},
#   'Positive'),
#  ({'thank': True, ':-)': True}, 'Positive'),
#  ({'hope': True,
#    'rest': True,
#    'night': True,
#    'go': True,
#    'quickly': True,
#    '...': True,
#    'bed': True,
#    'get': True,
#    'music': True,
#    'fix': True,
#    'time': True,
#    'dream': True,
#    ':)': True},
#   'Positive'),
#  ({'spiritual': True,
#    'ritual': True,
#    'festival': True,
#    'népal': True,
#    'beginning': True,
#    'line-up': True,
#    ':)': True,
#    'leave': True,
#    'see': True,
#    '...': True},
#   'Positive'),
#  ({'hey': True,
#    'sarah': True,
#    'send': True,
#    'us': True,
#    'email': True,
#    'bitsy.com': True,
#    "we'll": True,
#    'help': True,
#    'asap': True,
#    ':)': True},
#   'Positive'),
#  ({'lols': True, ':d': True}, 'Positive'),
#  ({'kik': True,
#    'hatessuce': True,
#    '32429': True,
#    '#kik': True,
#    '#kikme': True,
#    '#lgbt': True,
#    '#tinder': True,
#    '#nsfw': True,
#    '#akua': True,
#    '#cumshot': True,
#    ':)': True},
#   'Positive'),
#  ({'come': True, 'house': True, ':)': True}, 'Positive'),
#  ({'#nsn_supplements': True,
#    'effective': True,
#    'press': True,
#    'release': True,
#    'distribution': True,
#    'result': True,
#    ':)': True,
#    'link': True,
#    'remove': True,
#    '#pressrelease': True,
#    '#newsdistribution': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x46': True},
#   'Positive'),
#  ({'everyone': True,
#    'watch': True,
#    'documentary': True,
#    'earthlings': True,
#    'youtube': True,
#    ':-)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'buuuuuuuut': True, 'oh': True, 'well': True, ':-)': True}, 'Positive'),
#  ({'look': True,
#    'forward': True,
#    'visit': True,
#    'next': True,
#    'week': True,
#    '#letsgetmessy': True,
#    'jo': True,
#    ':-)': True},
#   'Positive'),
#  ({'make': True,
#    'u': True,
#    'feel': True,
#    'good': True,
#    'never': True,
#    'see': True,
#    'anyone': True,
#    'kpop': True,
#    'flesh': True,
#    ':d': True},
#   'Positive'),
#  ({'good': True, 'girl': True, 'best': True, 'wish': True, ':-)': True},
#   'Positive'),
#  ({'great': True,
#    'enough': True,
#    'reason': True,
#    'listen': True,
#    'one': True,
#    'epic': True,
#    'soundtrack': True,
#    ':d': True},
#   'Positive'),
#  ({'thank': True, 'shout': True, 'great': True, 'friday': True, ':)': True},
#   'Positive'),
#  ({'add': True,
#    'video': True,
#    'playlist': True,
#    'im': True,
#    'back': True,
#    'twitch': True,
#    'today': True,
#    'go': True,
#    'league': True,
#    ':)': True,
#    '1': True,
#    '4': True},
#   'Positive'),
#  ({'would': True,
#    'love': True,
#    'see': True,
#    'dear': True,
#    '#jordan': True,
#    ':)': True,
#    'wait': True},
#   'Positive'),
#  ({'oh': True, 'okay': True, ':d': True, 'thanks': True}, 'Positive'),
#  ({'like': True,
#    'fake': True,
#    'gameplays': True,
#    ';)': True,
#    'haha': True,
#    'im': True,
#    'kidding': True,
#    'good': True,
#    'stuff': True,
#    ':)': True},
#   'Positive'),
#  ({'yeah': True, 'exactly': True, ':)': True}, 'Positive'),
#  ({'new': True,
#    'product': True,
#    'line': True,
#    '#etsy': True,
#    'shop': True,
#    'check': True,
#    ':)': True,
#    '#boxroomcrafts': True},
#   'Positive'),
#  ({'hope': True, 'vacation': True, 'go': True, 'great': True, ':d': True},
#   'Positive'),
#  ({'rechargeable': True,
#    'normally': True,
#    'come': True,
#    'charger': True,
#    'u': True,
#    'buy': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'well': True,
#    'asleep': True,
#    'one': True,
#    'talk': True,
#    'sooo': True,
#    'someone': True,
#    'text': True,
#    ':)': True},
#   'Positive'),
#  ({'yes': True,
#    'suppose': True,
#    'bet': True,
#    "he'll": True,
#    'blue': True,
#    'fit': True,
#    'hear': True,
#    'speech': True,
#    'today': True,
#    'pity': True,
#    ':-)': True},
#   'Positive'),
#  ({'green': True,
#    'garden': True,
#    'midnight': True,
#    'sun': True,
#    'beautiful': True,
#    'canal': True,
#    'dasvidaniya': True,
#    'till': True,
#    'next': True,
#    'visit': True,
#    ':)': True},
#   'Positive'),
#  ({'scout': True,
#    'sg': True,
#    'future': True,
#    'wlan': True,
#    'pro': True,
#    'conference': True,
#    'asia': True,
#    ':)': True},
#   'Positive'),
#  ({'good': True,
#    'u': True,
#    'change': True,
#    'lollipop': True,
#    '🍭': True,
#    ':)': True},
#   'Positive'),
#  ({'<3': True, 'u': True, 'nez': True, ':)': True, '#agnezmo': True},
#   'Positive'),
#  ({'follow': True, 'please': True, ':)': True, 'big': True, 'dream': True},
#   'Positive'),
#  ({'oley': True, ':d': True}, 'Positive'),
#  ({'mama': True, 'reason': True, 'stand': True, 'strong': True, ':)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'oh': True,
#    'god': True,
#    'misty': True,
#    'baby': True,
#    'cute': True,
#    ':d': True},
#   'Positive'),
#  ({'love': True, 'blue': True, ':)': True, '#flipkartfashionfriday': True},
#   'Positive'),
#  ({'woohoo': True,
#    "can't": True,
#    'wait': True,
#    ':)': True,
#    'sign': True,
#    'yet': True,
#    'still': True,
#    'think': True,
#    'mka': True},
#   'Positive'),
#  ({'liam': True, 'access': True, ':)': True}, 'Positive'),
#  ({'welcome': True, ':)': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'surprise': True, '...': True, 'amazing': True, 'figure': True, ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'#happybirthdayemilybett': True,
#    ':)': True,
#    'wishing': True,
#    'best': True,
#    'beautiful': True,
#    'sweet': True,
#    'talented': True,
#    'amaze': True,
#    '…': True},
#   'Positive'),
#  ({'2': True,
#    'plan': True,
#    'day': True,
#    'drain': True,
#    'great': True,
#    ':)': True},
#   'Positive'),
#  ({'gotta': True, 'love': True, 'timezones': True, ':p': True}, 'Positive'),
#  ({'parent': True,
#    'proud': True,
#    '—': True,
#    'lol': True,
#    'least': True,
#    ':d': True,
#    'maybe': True,
#    'sometimes': True,
#    'get': True,
#    'happy': True,
#    'grade': True,
#    'al': True,
#    '...': True},
#   'Positive'),
#  ({'grande': True, ':)': True}, 'Positive'),
#  ({'manila_bro': True,
#    'choose': True,
#    'follow': True,
#    'twitter': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({'sure': True,
#    'let': True,
#    'know': True,
#    'around': True,
#    '..': True,
#    'side': True,
#    'world': True,
#    '#eh': True,
#    'u': True,
#    'take': True,
#    'care': True,
#    ':-)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'finally': True, 'fuck': True, 'weekend': True, ':)': True}, 'Positive'),
#  ({'real': True, ':)': True}, 'Positive'),
#  ({'thanks': True, ':d': True}, 'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x45': True},
#   'Positive'),
#  ({'yes': True,
#    'joined': True,
#    '#hushedcallwithfraydoe': True,
#    'call': True,
#    'gift': True,
#    '<3': True,
#    'gotta': True,
#    'get': True,
#    ':d': True},
#   'Positive'),
#  ({'yeahhh': True, ':)': True}, 'Positive'),
#  ({'dm': True, 'make': True, 'night': True, 'good': True, ':)': True},
#   'Positive'),
#  ({'join': True,
#    '#hushedpinwithsammy': True,
#    'event': True,
#    ':d': True,
#    'might': True,
#    'get': True,
#    'text': True,
#    'day': True,
#    'luv': True,
#    'u': True},
#   'Positive'),
#  ({'would': True,
#    'really': True,
#    'appreciate': True,
#    'share': True,
#    'video': True,
#    'around': True,
#    ':)': True},
#   'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True},
#   'Positive'),
#  ({'oh': True, 'wow': True, 'beautiful': True, 'tom': True, ':)': True},
#   'Positive'),
#  ({'love': True, ':)': True}, 'Positive'),
#  ({'add': True,
#    'video': True,
#    'playlist': True,
#    'im': True,
#    'back': True,
#    'twitch': True,
#    'today': True,
#    'go': True,
#    'league': True,
#    ':)': True,
#    '1': True,
#    '3': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'gym': True,
#    'monday': True,
#    "can't": True,
#    'wait': True,
#    ':)': True,
#    'likes': True},
#   'Positive'),
#  ({'hey': True,
#    "here's": True,
#    'invite': True,
#    'join': True,
#    'scope': True,
#    'influencer': True,
#    ':)': True},
#   'Positive'),
#  ({'friend': True, 'know': True, ':)': True}, 'Positive'),
#  ({'wait': True, 'nude': True, ':-)': True}, 'Positive'),
#  ({'go': True, 'sleep': True, 'u': True, ':)': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'birthday': True, 'week': True, 'today': True, ':d': True}, 'Positive'),
#  ({'want': True, 't-shirts': True, 'cool': True, ':d': True}, 'Positive'),
#  ({'haw': True,
#    'phela': True,
#    'look': True,
#    'like': True,
#    'mom': True,
#    'obviously': True,
#    ':)': True},
#   'Positive'),
#  ({'prince': True, 'charm': True, 'stage': True, ':)': True, 'x': True},
#   'Positive'),
#  ({'really': True, 'good': True, 'luck': True, ':)': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'tyler': True, 'hipster': True, 'glass': True, ':d': True}, 'Positive'),
#  ({'hey': True,
#    'marty': True,
#    'glad': True,
#    'see': True,
#    'twitter': True,
#    ':)': True},
#   'Positive'),
#  ({'hi': True, 'join': True, 'today': True, ':)': True}, 'Positive'),
#  ({'thanks': True, ':-)': True}, 'Positive'),
#  ({'already': True,
#    'afternoon': True,
#    'let': True,
#    'read': True,
#    'al': True,
#    'kahfi': True,
#    'day': True,
#    'finish': True,
#    ':)': True},
#   'Positive'),
#  ({'ohmyg': True,
#    'yaya': True,
#    'dub': True,
#    'im': True,
#    'stalk': True,
#    'ig': True,
#    'accnt': True,
#    '..': True,
#    'gondooo': True,
#    'moo': True,
#    'tologooo': True,
#    ':)': True,
#    'haha': True},
#   'Positive'),
#  ({"here's": True,
#    'invite': True,
#    'become': True,
#    'scope': True,
#    'influencer': True,
#    ':)': True,
#    'details': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'thanks': True, ':)': True, 'zzz': True, 'xx': True}, 'Positive'),
#  ({'physiotherapy': True,
#    'friday': True,
#    'hashtag': True,
#    'today': True,
#    'custom': True,
#    ':-)': True},
#   'Positive'),
#  ({'know': True,
#    '💪': True,
#    'monica': True,
#    'miss': True,
#    'yeah': True,
#    'sound': True,
#    'good': True,
#    ':)': True},
#   'Positive'),
#  ({'good': True,
#    'morning': True,
#    'beautiful': True,
#    ':)': True,
#    "that's": True,
#    'take': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x43': True},
#   'Positive'),
#  ({'oh': True,
#    'yeah': True,
#    'definitely': True,
#    'go': True,
#    'try': True,
#    'tonight': True,
#    ':)': True,
#    'take': True,
#    'advice': True,
#    'treviso': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'hi': True,
#    'would': True,
#    'like': True,
#    'concert': True,
#    'let': True,
#    'know': True,
#    'city': True,
#    'country': True,
#    "i'll": True,
#    'start': True,
#    'work': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({'fine': True,
#    '...': True,
#    'gorgeous': True,
#    'friday': True,
#    'friend': True,
#    '..': True,
#    'xo': True,
#    ':)': True},
#   'Positive'),
#  ({'oven': True,
#    'roast': True,
#    'garlic': True,
#    'olive': True,
#    'oil': True,
#    'sun': True,
#    'dry': True,
#    'tomato': True,
#    'dried': True,
#    'basil': True,
#    'century': True,
#    'tuna': True,
#    ':)': True},
#   'Positive'),
#  ({'right': True,
#    'back': True,
#    'atchya': True,
#    'great': True,
#    'day': True,
#    'everyone': True,
#    ':)': True},
#   'Positive'),
#  ({'even': True, 'follow': True, 'back': True, ':-)': True}, 'Positive'),
#  ({'future': True, 'almost': True, ':)': True}, 'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'chance': True, ':)': True}, 'Positive'),
#  ({'cheer': True, ':)': True}, 'Positive'),
#  ({'go': True, 'po': True, 'ice': True, 'cream': True, ':)': True},
#   'Positive'),
#  ({'agree': True, '100': True, ':)': True}, 'Positive'),
#  ({'hehehehe': True, 'thats': True, 'point': True, ':p': True}, 'Positive'),
#  ({'next': True, 'time': True, 'stay': True, 'home': True, ':)': True},
#   'Positive'),
#  ({'thanks': True, ':)': True}, 'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'soon': True, 'promise': True, ':)': True}, 'Positive'),
#  ({'web': True,
#    'whatsapp': True,
#    'volta': True,
#    'funcionar': True,
#    'com': True,
#    'iphone': True,
#    'jailbroken': True,
#    ':-)': True},
#   'Positive'),
#  ({'plan': True,
#    'watch': True,
#    'late': True,
#    '34': True,
#    'min': True,
#    'leia': True,
#    'appear': True,
#    'hologram': True,
#    'r2d2': True,
#    'w': True,
#    'message': True,
#    'obi': True,
#    'wan': True,
#    'sit': True,
#    'luke': True,
#    ':)': True},
#   'Positive'),
#  ({'inter': True,
#    '3': True,
#    'ucl': True,
#    'arsenal': True,
#    '...': True,
#    'small': True,
#    'team': True,
#    'right': True,
#    ':)': True},
#   'Positive'),
#  ({'passing': True,
#    ':)': True,
#    '🚂': True,
#    'dewsbury': True,
#    'railway': True,
#    'station': True,
#    'dew': True,
#    'west': True,
#    'yorkshire': True},
#   'Positive'),
#  ({':)': True, '430': True, 'smh': True}, 'Positive'),
#  ({'9:25': True,
#    ':)': True,
#    'live': True,
#    'scotland': True,
#    'strange': True,
#    'imagine': True,
#    'megan': True,
#    'xx': True},
#   'Positive'),
#  ({'#masaantoday': True,
#    'a4': True,
#    '...': True,
#    'shweta': True,
#    'tripathi': True,
#    ':-)': True,
#    '..': True},
#   'Positive'),
#  ({'5': True,
#    '20': True,
#    'w': True,
#    'kurta': True,
#    'mom': True,
#    'half': True,
#    'number': True,
#    ':d': True,
#    '#wsalelove': True},
#   'Positive'),
#  ({'ah': True, 'hello': True, 'back': True, 'larry': True, ':)': True},
#   'Positive'),
#  ({'anyway': True,
#    'friday': True,
#    'look': True,
#    'kinda': True,
#    'gooood': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'lol': True,
#    'well': True,
#    "that's": True,
#    'life': True,
#    ':)': True,
#    'thank': True,
#    'god': True,
#    'enn': True},
#   'Positive'),
#  ({'surely': True,
#    'could': True,
#    'warmup': True,
#    'morning': True,
#    'coming': True,
#    '15th': True,
#    'bath': True,
#    ':)': True,
#    'xx': True},
#   'Positive'),
#  ({'dum': True,
#    'andar': True,
#    'ram': True,
#    'sampath': True,
#    'sona': True,
#    'mohapatra': True,
#    'samantha': True,
#    'edwards': True,
#    'mein': True,
#    'tulane': True,
#    'razi': True,
#    'wah': True,
#    "that's": True,
#    'josh': True,
#    ':)': True},
#   'Positive'),
#  ({':)': True, 'always': True, 'smile': True}, 'Positive'),
#  ({'picture': True, ':)': True}, 'Positive'),
#  ({'thanks': True,
#    'time': True,
#    '16.20': True,
#    'right': True,
#    "that's": True,
#    'perfect': True,
#    'timing': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'know': True, ':)': True}, 'Positive'),
#  ({'#giveitup': True,
#    'already': True,
#    'give': True,
#    'gas': True,
#    'subsidy': True,
#    'long': True,
#    'back': True,
#    'initiative': True,
#    'propose': True,
#    '..': True,
#    'feeling': True,
#    'delight': True,
#    ':)': True},
#   'Positive'),
#  ({'miss': True, 'yesterday': True, ':-)': True}, 'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x42': True},
#   'Positive'),
#  ({'lmaoo': True,
#    'best': True,
#    'song': True,
#    'ever': True,
#    '<3': True,
#    'shall': True,
#    'little': True,
#    'throwback': True,
#    'week': True,
#    ':p': True},
#   'Positive'),
#  ({'go': True,
#    'outlying': True,
#    'island': True,
#    'cheung': True,
#    'chau': True,
#    'mui': True,
#    'wo': True,
#    '...': True,
#    'totally': True,
#    'different': True,
#    ':)': True},
#   'Positive'),
#  ({'#kfckitchentours': True,
#    'kitchen': True,
#    'clean': True,
#    "i'm": True,
#    'totally': True,
#    'amaze': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'cusp': True,
#    'test': True,
#    'water': True,
#    'hope': True,
#    'reward': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'arummzz': True,
#    "let's": True,
#    'go': True,
#    '...': True,
#    "i'll": True,
#    'drive': True,
#    ':p': True,
#    '#traveling': True,
#    '#traveler': True,
#    '#yogyakarta': True,
#    '#jeep': True,
#    '#indonesia': True,
#    '#instamood': True,
#    '…': True},
#   'Positive'),
#  ({'anyone': True, 'wanna': True, 'skype': True, ':d': True}, 'Positive'),
#  ({'may': True,
#    'look': True,
#    'bit': True,
#    'real': True,
#    'nice': True,
#    'friendly': True,
#    'girl': True,
#    ':-)': True},
#   'Positive'),
#  ({'im': True, 'like': True, 'pretend': True, ':)': True}, 'Positive'),
#  ({'watch': True, 'concert': True, 'film': True, ':)': True}, 'Positive'),
#  ({'congratulations': True,
#    'winner': True,
#    '#cheesydelights': True,
#    'contest': True,
#    ':)': True,
#    'please': True,
#    'dm': True,
#    'us': True,
#    'address': True,
#    'contact': True,
#    'number': True},
#   'Positive'),
#  ({':)': True, 'great': True, 'weekend': True, 'guy': True}, 'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'cool': True, 'see': True, 'film': True, 'today': True, ':)': True},
#   'Positive'),
#  ({'check': True,
#    'email': True,
#    'marketing': True,
#    '24/7': True,
#    'regret': True,
#    'buy': True,
#    ':)': True},
#   'Positive'),
#  ({'lol': True,
#    'come': True,
#    'join': True,
#    'us': True,
#    '...': True,
#    'see': True,
#    'u': True,
#    'around': True,
#    '14': True,
#    'hour': True,
#    'leave': True,
#    'without': True,
#    'delay': True,
#    ':)': True},
#   'Positive'),
#  ({'actually': True,
#    'easy': True,
#    'like': True,
#    'must': True,
#    'station': True,
#    'guess': True,
#    'train': True,
#    'wd': True,
#    'take': True,
#    'least': True,
#    'hour': True,
#    'shift': True,
#    'engine': True,
#    'etc': True,
#    ':-)': True},
#   'Positive'),
#  ({'sunburn': True, 'peel': True, ':-)': True}, 'Positive'),
#  ({'visit': True, 'blog': True, 'thanks': True, ':d': True}, 'Positive'),
#  ({'hi': True,
#    'would': True,
#    'like': True,
#    'concert': True,
#    'let': True,
#    'know': True,
#    'city': True,
#    'country': True,
#    "i'll": True,
#    'start': True,
#    'work': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({'talk': True, 'help': True, ':)': True}, 'Positive'),
#  ({'huge': True,
#    'warm': True,
#    'welcome': True,
#    ':-)': True,
#    '☆': True,
#    'finally': True,
#    'complete': True,
#    'triangle': True},
#   'Positive'),
#  ({'live': True,
#    'northern': True,
#    'ireland': True,
#    ':)': True,
#    'sight': True,
#    'see': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'feel': True,
#    'smthng': True,
#    'fr': True,
#    'u': True,
#    '...': True,
#    'lol': True,
#    'wanna': True,
#    'hug': True,
#    'xoxo': True,
#    'love': True,
#    'uu': True,
#    'jaann': True,
#    'take': True,
#    'care': True,
#    ':)': True,
#    '<3': True},
#   'Positive'),
#  ({'thanks': True, 'mom': True, ':)': True}, 'Positive'),
#  ({'thanks': True,
#    '#topnewfollowers': True,
#    'happy': True,
#    'connect': True,
#    ':)': True},
#   'Positive'),
#  ({'wonderful': True,
#    'thing': True,
#    'make': True,
#    'feel': True,
#    'fluffy': True,
#    'inside': True,
#    'great': True,
#    'pirouette': True,
#    'moose': True,
#    ':d': True},
#   'Positive'),
#  ({'trip': True,
#    'philly': True,
#    'december': True,
#    ':)': True,
#    "i'd": True,
#    'love': True,
#    'come': True,
#    'dude': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x41': True},
#   'Positive'),
#  ({'question': True,
#    'flaw': True,
#    'pain': True,
#    'negate': True,
#    'strength': True,
#    ':)': True},
#   'Positive'),
#  ({'go': True, 'solo': True, 'move': True, 'make': True, ':d': True},
#   'Positive'),
#  ({'hey': True,
#    'fav': True,
#    'nirvana': True,
#    'song': True,
#    'smell': True,
#    'like': True,
#    'teen': True,
#    'spirit': True,
#    'rip': True,
#    'amy': True,
#    'winehouse': True,
#    ':-)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({"let's": True,
#    'go': True,
#    '...': True,
#    "i'll": True,
#    'drive': True,
#    ':p': True,
#    '#traveling': True,
#    '#traveler': True,
#    '#yogyakarta': True,
#    '#jeep': True,
#    '#indonesia': True,
#    '#instamood': True,
#    '…': True},
#   'Positive'),
#  ({'name': True,
#    'couple': True,
#    'yet': True,
#    '#tomhiddleston': True,
#    '#elizabetholsen': True,
#    '#yaytheylookgreat': True,
#    ':)': True},
#   'Positive'),
#  ({'love': True,
#    'goodnight': True,
#    'vid': True,
#    'go': True,
#    'wake': True,
#    'one': True,
#    ':)': True},
#   'Positive'),
#  ({'weekend': True,
#    'gonna': True,
#    'shoot': True,
#    'lovely': True,
#    '<3': True,
#    'picture': True,
#    'make': True,
#    'last': True,
#    'time': True,
#    ':d': True},
#   'Positive'),
#  ({'anyway': True, ':-)': True}, 'Positive'),
#  ({'itty': True, 'bitty': True, 'teenie': True, 'bikini': True, ':)': True},
#   'Positive'),
#  ({'join': True,
#    '#hushedpinwithsammy': True,
#    'event': True,
#    ':d': True,
#    'might': True,
#    'get': True,
#    'text': True,
#    'day': True,
#    'luv': True,
#    'u': True},
#   'Positive'),
#  ({'always': True,
#    'much': True,
#    'fun': True,
#    '4th': True,
#    'hour': True,
#    'get': True,
#    'together': True,
#    ':)': True,
#    'ending': True,
#    'night': True,
#    'ice': True,
#    'cream': True,
#    'xfiles': True,
#    'content': True},
#   'Positive'),
#  ({'easy': True, ':d': True}, 'Positive'),
#  ({'yes': True,
#    'surprise': True,
#    'see': True,
#    'bit': True,
#    'rain': True,
#    'today': True,
#    '...': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'fabulous': True,
#    'friday': True,
#    'keep': True,
#    'fantastic': True,
#    'work': True,
#    ':)': True},
#   'Positive'),
#  ({'please': True,
#    'follow': True,
#    '♡': True,
#    'jb': True,
#    'love': True,
#    'always': True,
#    'forever': True,
#    "i'm": True,
#    'belieber': True,
#    ':)': True,
#    'u': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'morning': True, ':)': True}, 'Positive'),
#  ({'good': True, 'hear': True, ':)': True}, 'Positive'),
#  ({'nighty': True,
#    'night': True,
#    'let': True,
#    'bed': True,
#    'bug': True,
#    'bite': True,
#    ':d': True},
#   'Positive'),
#  ({'beautiful': True,
#    'bracelet': True,
#    'good': True,
#    'idea': True,
#    ':)': True},
#   'Positive'),
#  ({'wait': True, 'foundry': True, ':)': True}, 'Positive'),
#  ({'like': True, 'game': True, ':)': True}, 'Positive'),
#  ({'ah': True,
#    'make': True,
#    'sense': True,
#    '...': True,
#    'see': True,
#    'pic': True,
#    'eff': True,
#    'phone': True,
#    'last': True,
#    'night': True,
#    'woot': True,
#    ':)': True,
#    'x': True},
#   'Positive'),
#  ({'hi': True,
#    'derek': True,
#    'could': True,
#    'try': True,
#    'use': True,
#    'parkshare': True,
#    'gloucestershire': True,
#    ':)': True},
#   'Positive'),
#  ({'aaaahhh': True,
#    'man': True,
#    'track': True,
#    'traffic': True,
#    'stress': True,
#    'reliever': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({"how're": True, 'today': True, 'dear': True, ':)': True}, 'Positive'),
#  ({'hear': True, 'guy': True, 'want': True, 'arbeloa': True, ':d': True},
#   'Positive'),
#  ({'turn': True,
#    '17': True,
#    '15': True,
#    'day': True,
#    '...': True,
#    'omg': True,
#    'least': True,
#    '3': True,
#    'year': True,
#    'difference': True,
#    ':)': True},
#   'Positive'),
#  ({'well': True,
#    'say': True,
#    'europe': True,
#    'rise': True,
#    'find': True,
#    'hard': True,
#    'believe': True,
#    ':)': True},
#   'Positive'),
#  ({'#wsalelove': True,
#    'uncountable': True,
#    'coz': True,
#    'love': True,
#    'unlimited': True,
#    ':)': True},
#   'Positive'),
#  ({'yes': True, 'course': True, ':)': True, '#teampositive': True},
#   'Positive'),
#  ({'yes': True, 'love': True, ':-)': True, '#aldub': True}, 'Positive'),
#  ({':)': True, '☕': True, 'thank': True, 'rita': True}, 'Positive'),
#  ({'hi': True,
#    'could': True,
#    'please': True,
#    'dm': True,
#    'us': True,
#    'info': True,
#    "we'd": True,
#    'happy': True,
#    'help': True,
#    ':)': True},
#   'Positive'),
#  ({'way': True, 'boy': True, ':)': True}, 'Positive'),
#  ({'hope': True,
#    'get': True,
#    'lot': True,
#    'nice': True,
#    'gift': True,
#    ':d': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x40': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'true': True, ':)': True}, 'Positive'),
#  ({'add': True,
#    'video': True,
#    'playlist': True,
#    'im': True,
#    'back': True,
#    'twitch': True,
#    'today': True,
#    'go': True,
#    'league': True,
#    ':)': True,
#    '1': True,
#    '3': True},
#   'Positive'),
#  ({'sethi': True, 'high': True, ':)': True}, 'Positive'),
#  ({'exe': True, 'skeem': True, 'saam': True, ':)': True}, 'Positive'),
#  ({'people': True, 'make': True, 'smile': True, ':)': True}, 'Positive'),
#  ({'thanks': True, 'invite': True, ':)': True}, 'Positive'),
#  ({'polite': True,
#    'izzat': True,
#    ':)': True,
#    'wese': True,
#    'trust': True,
#    'khawateen': True,
#    'k': True,
#    'sath': True,
#    'selfies': True,
#    'say': True,
#    'mana': True,
#    'kar': True,
#    'deya': True},
#   'Positive'),
#  ({'thank': True,
#    "that's": True,
#    'friday': True,
#    'evening': True,
#    'sort': True,
#    ':-)': True},
#   'Positive'),
#  ({'smart': True, ':)': True}, 'Positive'),
#  ({':-)': True, 'nice': True, 'hair': True, 'tbh': True}, 'Positive'),
#  ({'5': True, 'year': True, ':)': True}, 'Positive'),
#  ({'jacob': True, 'g': True, 'upgrade': True, ':-)': True}, 'Positive'),
#  ({'nice': True, 'tee': True, 'man': True, ':)': True}, 'Positive'),
#  ({'happy': True,
#    'family': True,
#    'vacation': True,
#    '..': True,
#    ':d': True,
#    'pic': True,
#    '—': True},
#   'Positive'),
#  ({'sleep': True, 'would': True, 'nice': True, ':-)': True}, 'Positive'),
#  ({'reading': True, 'beautiful': True, 'like': True, 'read': True, ':)': True},
#   'Positive'),
#  ({'talking': True,
#    'one': True,
#    'person': True,
#    '...': True,
#    'two': True,
#    'conversations': True,
#    ':)': True},
#   'Positive'),
#  ({'skype': True, 'fun': True, ':-)': True}, 'Positive'),
#  ({'online': True, ':)': True}, 'Positive'),
#  ({'...': True, 'friday': True, ':d': True}, 'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'something': True,
#    'get': True,
#    '#friday': True,
#    'great': True,
#    'start': True,
#    ':)': True,
#    'day': True,
#    '#mclaren': True,
#    '#fridayfeeling': True,
#    '#tgif': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'square': True,
#    'enix': True,
#    'bissmillah': True,
#    'ya': True,
#    'allah': True,
#    ':)': True},
#   'Positive'),
#  ({"we're": True,
#    'training': True,
#    '#socent': True,
#    'startup': True,
#    'week': True,
#    'w': True,
#    "we'd": True,
#    'love': True,
#    'drop': True,
#    'youre': True,
#    'arnd': True,
#    'town': True,
#    ':)': True},
#   'Positive'),
#  ({'basically': True, 'piss': True, 'cup': True, 'test': True, ':)': True},
#   'Positive'),
#  ({'next': True, ':)': True}, 'Positive'),
#  ({'also': True,
#    'twitter': True,
#    'terrible': True,
#    'complicated': True,
#    'discussion': True,
#    ':)': True},
#   'Positive'),
#  ({'snapchat': True,
#    'lynettelowe': True,
#    '#snapchat': True,
#    '#kikmenow': True,
#    '#snapme': True,
#    '#hot': True,
#    '#amazon': True,
#    '#kikmeguys': True,
#    ':)': True},
#   'Positive'),
#  ({'look': True,
#    'forward': True,
#    '12': True,
#    'hour': True,
#    'shift': True,
#    'today': True,
#    ':)': True},
#   'Positive'),
#  ({'definately': True,
#    'agree': True,
#    'grow': True,
#    'sport': True,
#    'drop': True,
#    'email': True,
#    'detail': True,
#    'see': True,
#    ':-)': True},
#   'Positive'),
#  ({'last': True, 'rt': True, ':)': True}, 'Positive'),
#  ({'...': True,
#    'rakyat': True,
#    'keep': True,
#    'visit': True,
#    'blog': True,
#    'read': True,
#    'write': True,
#    ':)': True},
#   'Positive'),
#  ({'ever': True,
#    'since': True,
#    'mention': True,
#    'fly': True,
#    'fish': True,
#    'day': True,
#    "i'm": True,
#    'get': True,
#    'follow': True,
#    'promoted': True,
#    'post': True,
#    'lol': True,
#    'cyber': True,
#    'stalk': True,
#    ':-)': True},
#   'Positive'),
#  ({'#ourdaughtersourpride': True,
#    '#mypapamypride': True,
#    'proud': True,
#    'papa': True,
#    'coach': True,
#    ':)': True},
#   'Positive'),
#  ({'great': True, 'talk': True, ':d': True}, 'Positive'),
#  ({'never': True,
#    'see': True,
#    'positive': True,
#    'kha': True,
#    'u': True,
#    'could': True,
#    'also': True,
#    'mention': True,
#    'atleast': True,
#    'go': True,
#    ':)': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x39': True},
#   'Positive'),
#  ({'mango': True,
#    "lassi's": True,
#    "monty's": True,
#    'marvellous': True,
#    ':d': True,
#    'though': True,
#    'suspect': True,
#    "that's": True,
#    'mean': True,
#    '...': True},
#   'Positive'),
#  ({'#followfriday': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'haha': True,
#    'yes': True,
#    '24': True,
#    'hr': True,
#    'time': True,
#    'come': True,
#    'touch': True,
#    'kepler': True,
#    '452b': True,
#    'chalna': True,
#    'hai': True,
#    ':d': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'thankyou': True, 'pretty': True, ':)': True}, 'Positive'),
#  ({'definitely': True,
#    'hazel': True,
#    'food': True,
#    'market': True,
#    'brooklyn': True,
#    'pta': True,
#    ':)': True},
#   'Positive'),
#  ({'still': True, 'awake': True, ':)': True}, 'Positive'),
#  ({'okayy': True, ':d': True}, 'Positive'),
#  ({'awww': True, 'thank': True, ':)': True}, 'Positive'),
#  ({'ha': True,
#    'surprise': True,
#    'least': True,
#    'okay': True,
#    'see': True,
#    'doc': True,
#    'afternoon': True,
#    'yorkshire': True,
#    'splendid': True,
#    'though': True,
#    ':)': True,
#    'xx': True},
#   'Positive'),
#  ({'spam': True,
#    'folder': True,
#    'wow': True,
#    'win': True,
#    'huge': True,
#    'amount': True,
#    'need': True,
#    'travel': True,
#    'nigeria': True,
#    'claim': True,
#    ':)': True},
#   'Positive'),
#  ({'rted': True, 'good': True, 'luck': True, ':)': True}, 'Positive'),
#  ({'legs': True, 'hurt': True, 'bad': True, ':)': True}, 'Positive'),
#  ({'get': True, 'mine': True, 'saturday': True, ':-)': True}, 'Positive'),
#  ({'thaaanks': True, 'december': True, 'puhon': True, ':)': True}, 'Positive'),
#  ({'happiness': True, ':)': True}, 'Positive'),
#  ({'true': True,
#    'change': True,
#    'tnc': True,
#    'without': True,
#    'prior': True,
#    'notification': True,
#    'could': True,
#    'use': True,
#    'last': True,
#    'night': True,
#    ':-)': True},
#   'Positive'),
#  ({'probably': True, 'find': True, 'funny': True, '2:22': True, ':-)': True},
#   'Positive'),
#  ({'fat': True,
#    'co': True,
#    'probably': True,
#    'eat': True,
#    'yuna': True,
#    ':d': True},
#   'Positive'),
#  ({'fun': True, 'tameside': True, ':)': True}, 'Positive'),
#  ({':-)': True}, 'Positive'),
#  ({'´': True, 'welcome': True, ':)': True}, 'Positive'),
#  ({'google': True, 'account': True, ':)': True}, 'Positive'),
#  ({'call': True,
#    'scouser': True,
#    'everything': True,
#    'hope': True,
#    'zoe': True,
#    'well': True,
#    'mate': True,
#    ':)': True},
#   'Positive'),
#  ({'right': True,
#    'literally': True,
#    'like': True,
#    'maybe': True,
#    'u': True,
#    'get': True,
#    'people': True,
#    'actually': True,
#    'know': True,
#    "they're": True,
#    ':-)': True},
#   'Positive'),
#  ({'sameee': True, 'rest': True, 'well': True, ':)': True}, 'Positive'),
#  ({'happy': True,
#    'birthday': True,
#    'edgar': True,
#    'hope': True,
#    'good': True,
#    'one': True,
#    'keep': True,
#    'update': True,
#    'travel': True,
#    'log': True,
#    ':)': True},
#   'Positive'),
#  ({'hello': True, ':d': True}, 'Positive'),
#  ({'bring': True, 'abes': True, ':)': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '2': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'someone': True, 'talk': True, ':)': True}, 'Positive'),
#  ({'never': True, 'ever': True, 'meet': True, ':d': True}, 'Positive'),
#  ({'come': True, 'man': True, ':d': True}, 'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x38': True},
#   'Positive'),
#  ({'sigh': True,
#    'dreamily': True,
#    'pout': True,
#    'come': True,
#    'bath': True,
#    'eye': True,
#    ':-)': True,
#    '#quacketyquack': True},
#   'Positive'),
#  ({'happy': True, 'birthday': True, 'love': True, ':)': True}, 'Positive'),
#  ({'cheers': True, ':-)': True}, 'Positive'),
#  ({'funny': True, 'happen': True, 'phil': True}, 'Positive'),
#  ({"i'd": True,
#    'call': True,
#    'em': True,
#    'del': True,
#    'rodders': True,
#    ':)': True,
#    'else': True},
#   'Positive'),
#  ({'hi': True,
#    'may': True,
#    'like': True,
#    'play': True,
#    'new': True,
#    'gamejam': True,
#    'game': True,
#    'would': True,
#    'happy': True,
#    ':)': True},
#   'Positive'),
#  ({'great': True,
#    'irish': True,
#    'literature': True,
#    'really': True,
#    'inaccessible': True,
#    'us': True,
#    'without': True,
#    ':)': True},
#   'Positive'),
#  ({'yeah': True, 'fun': True, ':)': True, '#flipkartfashionfriday': True},
#   'Positive'),
#  ({'nice': True, 'music': True, ':)': True, 'check': True}, 'Positive'),
#  ({'strange': True,
#    "kareena's": True,
#    'fans': True,
#    'knowing': True,
#    ':)': True},
#   'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True},
#   'Positive'),
#  ({'good': True, ':)': True}, 'Positive'),
#  ({'cool': True, 'look': True, ':)': True}, 'Positive'),
#  ({':)': True, 'beautiful': True}, 'Positive'),
#  ({"i'm": True, 'play': True, 'brain': True, 'dots': True, '#braindots': True},
#   'Positive'),
#  ({"that's": True,
#    'fair': True,
#    'enough': True,
#    ':)': True,
#    'rush': True,
#    'back': True,
#    'either': True},
#   'Positive'),
#  ({'brandi': True,
#    '18': True,
#    'fb': True,
#    'drop': True,
#    'selfie': True,
#    ':)': True,
#    'fun': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'carnival': True,
#    'men': True,
#    'put': True,
#    'mask': True,
#    'xavier': True,
#    'forneret': True,
#    ':-)': True},
#   'Positive'),
#  ({'jennifer': True,
#    'check': True,
#    'site': True,
#    'u': True,
#    'wanna': True,
#    'get': True,
#    'free': True,
#    '50.000': True,
#    '8': True,
#    'ball': True,
#    'pool': True,
#    'coins': True,
#    'thank': True,
#    ':)': True},
#   'Positive'),
#  ({'beautiful': True,
#    'edit': True,
#    'trish': True,
#    ':)': True,
#    'loved': True,
#    '♥': True},
#   'Positive'),
#  ({'gratefulness': True,
#    'happiness': True,
#    ':)': True,
#    'post': True,
#    'three': True,
#    'thing': True,
#    'grateful': True,
#    'today': True,
#    'comment': True},
#   'Positive'),
#  ({'love': True,
#    'wakeup': True,
#    'beside': True,
#    'real': True,
#    'dirty': True,
#    'sex': True,
#    ':-)': True},
#   'Positive'),
#  ({'lmaooo': True,
#    'hot': True,
#    '😤': True,
#    'like': True,
#    'louis': True,
#    ':)': True,
#    "he's": True},
#   'Positive'),
#  ({'gonna': True,
#    'throw': True,
#    'idea': True,
#    'cause': True,
#    "they're": True,
#    'bad': True,
#    'inspire': True,
#    'think': True,
#    'something': True,
#    'much': True,
#    'good': True,
#    ':-)': True},
#   'Positive'),
#  ({'#ff': True,
#    'best': True,
#    'twoofs': True,
#    'follow': True,
#    'gr8': True,
#    'wkend': True,
#    ':)': True},
#   'Positive'),
#  ({'wish': True,
#    'could': True,
#    'maybe': True,
#    'one': True,
#    'year': True,
#    ':)': True},
#   'Positive'),
#  ({'hey': True, 'guy': True, ':)': True}, 'Positive'),
#  ({'think': True,
#    'need': True,
#    'go': True,
#    'bed': True,
#    'kind': True,
#    'exhausted': True,
#    'good': True,
#    'night': True,
#    'twitter': True,
#    ':)': True},
#   'Positive'),
#  ({'thank': True,
#    'much': True,
#    '..': True,
#    'glad': True,
#    'like': True,
#    ':-)': True},
#   'Positive'),
#  ({'get': True, 'good': True, 'time': True, ':)': True}, 'Positive'),
#  ({'kind': True,
#    'word': True,
#    'thank': True,
#    'much': True,
#    'good': True,
#    '#cheltenham': True,
#    'area': True,
#    ':)': True},
#   'Positive'),
#  ({'hi': True,
#    'beautiful': True,
#    'follow': True,
#    'please': True,
#    ':)': True,
#    '9': True},
#   'Positive'),
#  ({'’': True,
#    'kale': True,
#    'crisp': True,
#    ':-)': True,
#    'ruin': True,
#    'good': True,
#    'thing': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x37': True},
#   'Positive'),
#  ({'open': True, 'worldwide': True, ':)': True}, 'Positive'),
#  ({'get': True, 'fuck': True, 'outta': True, ':d': True}, 'Positive'),
#  ({'cool': True,
#    'guys': True,
#    '#sfvbeta': True,
#    'release': True,
#    'work': True,
#    ':)': True},
#   'Positive'),
#  ({'really': True, 'look': True, 'vantastic': True, ':)': True}, 'Positive'),
#  ({'today': True,
#    'finally': True,
#    'time': True,
#    'work': True,
#    'xcylin': True,
#    ':d': True},
#   'Positive'),
#  ({'thank': True,
#    'bundle': True,
#    'show': True,
#    'internet': True,
#    'price': True,
#    'phone': True,
#    'realisticly': True,
#    'pay': True,
#    'net': True,
#    ':)': True},
#   'Positive'),
#  ({':)': True,
#    'true': True,
#    'education': True,
#    'powerful': True,
#    'weapon': True,
#    'use': True,
#    'change': True,
#    'world': True,
#    'nelson': True,
#    'mandela': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'recent': True,
#    'trip': True,
#    'j': True,
#    'k': True,
#    'totally': True,
#    'love': True,
#    ':d': True,
#    "that's": True,
#    'chenab': True,
#    'flow': True,
#    'pakistan': True,
#    '#incredibleindia': True},
#   'Positive'),
#  ({'#teenchoice': True,
#    '#choiceinternationalartist': True,
#    '#superjunior': True,
#    ':)': True},
#   'Positive'),
#  ({'caught': True, 'first': True, 'salmon': True, 'today': True, ':d': True},
#   'Positive'),
#  ({'happy': True,
#    'friday': True,
#    'check': True,
#    'see': True,
#    'enjoy': True,
#    'super-blend': True,
#    ':)': True},
#   'Positive'),
#  ({'thanks': True,
#    'follow': True,
#    'get': True,
#    'touch': True,
#    'like': True,
#    'info': True,
#    'project': True,
#    'youth.org.uk': True,
#    ':)': True},
#   'Positive'),
#  ({'please': True,
#    'go': True,
#    'check': True,
#    'awesome': True,
#    "friend's": True,
#    'stream': True,
#    "he's": True,
#    'fantastic': True,
#    'artist': True,
#    ':)': True},
#   'Positive'),
#  ({'alma': True,
#    'mater': True,
#    ':)': True,
#    '#highschooldays': True,
#    '#clientvisit': True,
#    'faith': True,
#    'christian': True,
#    'school': True},
#   'Positive'),
#  ({'good': True,
#    'luck': True,
#    '#lizaminnelli': True,
#    'upcoming': True,
#    'uk': True,
#    'appearance': True,
#    ':-)': True},
#   'Positive'),
#  ({'lol': True,
#    '😄': True,
#    'really': True,
#    "can't": True,
#    'believe': True,
#    'beautiful': True,
#    'girl': True,
#    'like': True,
#    'single': True,
#    ':p': True},
#   'Positive'),
#  ({'never': True, 'listen': True, 'hills': True, 'every': True, ':-)': True},
#   'Positive'),
#  ({'would': True,
#    'listen': True,
#    'beats': True,
#    '1': True,
#    'go': True,
#    'wrong': True,
#    'life': True,
#    ':)': True},
#   'Positive'),
#  ({'haha': True, "that's": True, 'great': True, ':)': True}, 'Positive'),
#  ({'getting': True,
#    'everything': True,
#    'ready': True,
#    'natural': True,
#    'pefumery': True,
#    'workshop': True,
#    'neals': True,
#    'yard': True,
#    'covent': True,
#    'garden': True,
#    'tomorrow': True,
#    ':)': True},
#   'Positive'),
#  ({'fback': True, ':)': True, 'indo': True, 'harmos': True}, 'Positive'),
#  ({'americano': True, ':)': True}, 'Positive'),
#  ({':-)': True}, 'Positive'),
#  ({'love': True, 'way': True, ':)': True, '<3': True}, 'Positive'),
#  ({'always': True, 'remember': True, ':)': True}, 'Positive'),
#  ({'aww': True, 'thank': True, 'beautiful': True, 'pic': True, ':d': True},
#   'Positive'),
#  ({'head': True, ':)': True}, 'Positive'),
#  ({'hi': True,
#    'saw': True,
#    'u': True,
#    'follow': True,
#    'think': True,
#    'might': True,
#    'like': True,
#    'dark': True,
#    'plz': True,
#    'let': True,
#    'us': True,
#    'know': True,
#    ':)': True},
#   'Positive'),
#  ({'smart': True, 'handshome': True, 'cute': True, 'juga': True, ':d': True},
#   'Positive'),
#  ({'hurray': True,
#    'looking': True,
#    'forward': True,
#    'meeting': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'cause': True,
#    'hate': True,
#    'course': True,
#    'lol': True,
#    'cant': True,
#    'decide': True,
# ...
#   'Positive'),
#  ({'might': True,
#    'work': True,
#    ':)': True,
#    'great': True,
#    'weekend': True,
#    'op': True},
#   'Positive'),
#  ({'smile': True,
#    '#friday': True,
#    ':)': True,
#    '#tgif': True,
#    '#weekend': True},
#   'Positive'),
#  ({'cast': True,
#    'vote': True,
#    'next': True,
#    'election': True,
#    ':)': True,
#    '#jcreport': True},
#   'Positive'),
#  ({'thank': True, 'tweet': True, ':)': True}, 'Positive'),
#  ({'oh': True,
#    'piggin': True,
#    'go': True,
#    'yer': True,
#    'give': True,
#    'us': True,
#    'peace': True,
#    ':)': True},
#   'Positive'),
#  ({'appreciate': True,
#    'follow': True,
#    ':)': True,
#    'hear': True,
#    'botanical': True,
#    'soap': True},
#   'Positive'),
#  ({'love': True, 'u': True, '2': True, ':-)': True}, 'Positive'),
#  ({'late': True,
#    'upload': True,
#    'freshly': True,
#    '3weeks': True,
#    'old': True,
#    'heal': True,
#    ':)': True},
#   'Positive'),
#  ({'oh': True,
#    'bed': True,
#    'haha': True,
#    "can't": True,
#    'sleep': True,
#    'though': True,
#    'day': True,
#    'exciting': True,
#    ':)': True},
#   'Positive'),
#  ({'thx': True, 'tobi-bro': True, ':d': True}, 'Positive'),
#  ({'good': True, 'think': True, 'first': True, 'isp': True, ':)': True},
#   'Positive'),
#  ({"we'll": True,
#    'steel': True,
#    'next': True,
#    'wednesday': True,
#    'see': True,
#    'like': True,
#    ':)': True},
#   'Positive'),
#  ({'hey': True, ':)': True}, 'Positive'),
#  ({'definitely': True,
#    'love': True,
#    'make': True,
#    'people': True,
#    'smile': True,
#    'cause': True,
#    'swear': True,
#    'since': True,
#    'meet': True,
#    'early': True,
#    'stop': True,
#    ':)': True,
#    'cam': True,
#    '😭': True,
#    '❤': True,
#    '️': True},
#   'Positive'),
#  ({'...': True, 'except': True, 'lord': True, "masha'allah": True, ':)': True},
#   'Positive'),
#  ({'french': True,
#    'fan': True,
#    'make': True,
#    'movie': True,
#    'wwat': True,
#    'france': True,
#    'last': True,
#    'year': True,
#    'video': True,
#    'photo': True,
#    ':)': True},
#   'Positive'),
#  ({'fix': True, 'thanks': True, 'feedback': True, ':)': True}, 'Positive'),
#  ({'thanks': True,
#    'everyone': True,
#    'come': True,
#    'stream': True,
#    ':d': True,
#    'hope': True,
#    'guy': True,
#    'enjoy': True,
#    'night': True},
#   'Positive'),
#  ({'yaaaaaaaay': True, 'thx': True, ':)': True}, 'Positive'),
#  ({'looking': True, 'forward': True, 'review': True, ':-)': True}, 'Positive'),
#  ({'thank': True, 'beiruting': True, ':)': True}, 'Positive'),
#  ({'fback': True, ':)': True}, 'Positive'),
#  ({'thanks': True, 'update': True, 'profile': True, 'page': True, ':-)': True},
#   'Positive'),
#  ({'lovely': True, 'coffee': True, ':)': True}, 'Positive'),
#  ({"here's": True,
#    'cute': True,
#    'panda': True,
#    'make': True,
#    'day': True,
#    ':)': True},
#   'Positive'),
#  ({'thank': True, 'eonnie': True, ':)': True}, 'Positive'),
#  ({'hi': True,
#    'saw': True,
#    'u': True,
#    'follow': True,
#    'think': True,
#    'might': True,
#    'like': True,
#    'dark': True,
#    'plz': True,
#    'let': True,
#    'us': True,
#    'know': True,
#    ':)': True},
#   'Positive'),
#  ({'favourite': True, ':)': True, 'cream': True, 'soda': True}, 'Positive'),
#  ({'love': True,
#    'body': True,
#    'fuller': True,
#    'shit': True,
#    'even': True,
#    'lol': True,
#    "i'm": True,
#    'happy': True,
#    'healthy': True,
#    ':)': True,
#    '..': True,
#    '💓': True},
#   'Positive'),
#  ({'rettweet': True, ':-)': True}, 'Positive'),
#  ({'real': True,
#    'mvg': True,
#    'valuable': True,
#    'girlfriend': True,
#    'stay': True,
#    'till': True,
#    'madrid': True,
#    'game': True,
#    'start': True,
#    ':-)': True},
#   'Positive'),
#  ({'sore': True, 'ya': True, ':)': True}, 'Positive'),
#  ({"i'm": True, 'excited': True, 'definitely': True, 'meet': True, ':)': True},
#   'Positive'),
#  ({'come': True,
#    'bergerac': True,
#    'first': True,
#    'team': True,
#    'leave': True,
#    'u21': True,
#    "i'd": True,
#    'know': True,
#    '#checking': True,
#    'chant': True,
#    ':-)': True},
#   'Positive'),
#  ({':)': True, 'choice': True, 'food': True, 'left': True, 'individual': True},
#   'Positive'),
#  ({'episode': True,
#    'excellent': True,
#    'far': True,
#    ':-)': True,
#    'love': True,
#    'adam': True,
#    "beach's": True,
#    'movie': True,
#    'show': True,
#    "i'm": True,
#    'look': True,
#    'forward': True,
#    'see': True,
#    'suicide': True,
#    'squad': True,
#    'next': True,
#    'year': True},
#   'Positive'),
#  ({'growing': True,
#    'fond': True,
#    'christopher': True,
#    'like': True,
#    'initially': True,
#    'cocky': True,
#    'really': True,
#    'prove': True,
#    "attitude's": True,
#    'improve': True,
#    ':d': True},
#   'Positive'),
#  ({'sound': True,
#    'good': True,
#    'dm': True,
#    'email': True,
#    'address': True,
#    'suggest': True,
#    'date': True,
#    'coffee': True,
#    ':)': True},
#   'Positive'),
#  ({'indeed': True, 'many': True, 'thanks': True, ':-)': True}, 'Positive'),
#  ({'smile': True, 'even': True, 'pain': True, ':)': True}, 'Positive'),
#  ({'hi': True, 'happys': True, ':)': True}, 'Positive'),
#  ({'funny': True,
#    'intelligent': True,
#    'strong': True,
#    '...': True,
#    ':-)': True},
#   'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True},
#   'Positive'),
#  ({'use': True, 'cs': True, ':)': True}, 'Positive'),
#  ({'ever': True,
#    'watch': True,
#    'certain': True,
#    "people's": True,
#    'snapchat': True,
#    'bc': True,
#    'know': True,
#    ':-)': True},
#   'Positive'),
#  ({"that's": True, 'ok': True, 'know': True, 'busy': True, ':)': True},
#   'Positive'),
#  ({'last': True, '2': True, 'exam': True, ':)': True}, 'Positive'),
#  ({'forgot': True, 'u': True, ':)': True}, 'Positive'),
#  ({'fun': True,
#    'fact': True,
#    'love': True,
#    'meet': True,
#    'new': True,
#    'people': True,
#    ':)': True},
#   'Positive'),
#  ({'know': True,
#    'home-based': True,
#    'office': True,
#    'busy': True,
#    'feel': True,
#    ':-)': True,
#    'pity': True,
#    'knee': True,
#    'happen': True},
#   'Positive'),
#  ({'sale': True,
#    'fleur': True,
#    'dress': True,
#    'cream': True,
#    '#readystock_hijabmart': True,
#    'idr': True,
#    '325.000': True,
#    '200.000': True,
#    ':)': True},
#   'Positive'),
#  ({'thankyou': True, ':)': True}, 'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'tompolo': True,
#    'meeting': True,
#    'aim': True,
#    'stop': True,
#    'sale': True,
#    'oil': True,
#    'cannot': True,
#    'find': True,
#    'buyer': True,
#    ':d': True},
#   'Positive'),
#  ({"that's": True,
#    'true': True,
#    'disappoint': True,
#    'looking': True,
#    'forward': True,
#    'paper': True,
#    'towns': True,
#    ':)': True},
#   'Positive'),
#  ({"that's": True,
#    'need': True,
#    'know': True,
#    'everything': True,
#    'go': True,
#    'okay': True,
#    ':-)': True},
#   'Positive'),
#  ({'say': True,
#    'less': True,
#    'slacking': True,
#    'get': True,
#    'crack': True,
#    ':)': True},
#   'Positive'),
#  ({'know': True,
#    'name': True,
#    'particularly': True,
#    'striking': True,
#    'happy': True,
#    'day': True,
#    ':)': True},
#   'Positive'),
#  ({'hey': True,
#    "here's": True,
#    'invite': True,
#    'join': True,
#    'scope': True,
#    'influencer': True,
#    ':)': True},
#   'Positive'),
#  ({'31': True, 'bad': True, 'mam': True, ':p': True}, 'Positive'),
#  ({'lovely': True,
#    'look': True,
#    'cake': True,
#    'bet': True,
#    'taste': True,
#    'good': True,
#    ':-)': True},
#   'Positive'),
#  ({'feytyaz': True, 'follback': True, 'ya': True, ':)': True}, 'Positive'),
#  ({'find': True,
#    'last': True,
#    'night': True,
#    'let': True,
#    'say': True,
#    'instant': True,
#    'stiffening': True,
#    'interest': True,
#    ':)': True},
#   'Positive'),
#  ({'rettweet': True, ':-)': True}, 'Positive'),
#  ({'fback': True, ':)': True}, 'Positive'),
#  ({'rettweet': True, ':-)': True}, 'Positive'),
#  ({'ricky_febs': True, 'follback': True, 'ya': True, ':)': True}, 'Positive'),
#  ({'got': True,
#    'secrets': True,
#    'grindea': True,
#    'courier': True,
#    'crypts': True,
#    'possibly': True,
#    'arma': True,
#    '3': True,
#    'record': True,
#    'today': True,
#    '...': True,
#    'gosh': True,
#    'new': True,
#    'game': True,
#    'look': True,
#    'like': True,
#    'limbo': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'thanks': True,
#    'retweeting': True,
#    'orchard': True,
#    'art': True,
#    'show': True,
#    'super': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'karachi': True,
#    'ka': True,
#    'venice': True,
#    'rain': True,
#    ':)': True,
#    '“': True,
#    'several': True,
#    'part': True,
#    'witness': True,
#    'accumulate': True,
#    'water': True,
#    '”': True},
#   'Positive'),
#  ({'maroon': True,
#    'cocktail': True,
#    'dress': True,
#    '#mididresses': True,
#    ':)': True},
#   'Positive'),
#  ({'fback': True, 'po': True, ':)': True}, 'Positive'),
#  ({'0-100': True, 'real': True, 'quick': True, ':)': True}, 'Positive'),
#  ({'morning': True,
#    'mine': True,
#    '1100d': True,
#    'usually': True,
#    'auto-focus': True,
#    'use': True,
#    'manual': True,
#    'really': True,
#    'close': True,
#    'like': True,
#    'shoot': True,
#    'vein': True,
#    'crackle': True,
#    'glaze': True,
#    ':)': True},
#   'Positive'),
#  ({'new': True,
#    'layout': True,
#    'look': True,
#    'bomb': True,
#    ':-)': True,
#    'g': True},
#   'Positive'),
#  ({'thanks': True,
#    'connect': True,
#    'hope': True,
#    'great': True,
#    'day': True,
#    'social': True,
#    'website': True,
#    'question': True,
#    'ask': True,
#    ':-)': True},
#   'Positive'),
#  ({'pake': True, ':)': True}, 'Positive'),
#  ({'hi': True,
#    'make': True,
#    'change': True,
#    'design': True,
#    'hope': True,
#    'like': True,
#    ':)': True},
#   'Positive'),
#  ({'joim': True, 'fee': True, 'troop': True, ':)': True, 'via': True},
#   'Positive'),
#  ({'brand': True,
#    'want': True,
#    'review': True,
#    'beauty': True,
#    'product': True,
#    'blog': True,
#    'mail': True,
#    'ladolcevitainluxembourg.com': True,
#    '#prrequest': True,
#    '#journorequest': True,
#    ':)': True},
#   'Positive'),
#  ({'the_madstork': True, 'follback': True, 'ya': True, ':)': True},
#   'Positive'),
#  ({'good': True, 'luck': True, 'shaun': True, ':)': True}, 'Positive'),
#  ({'yes': True, ':)': True}, 'Positive'),
#  ({'anyone': True,
#    'want': True,
#    'add': True,
#    'bot': True,
#    'dm': True,
#    ':)': True,
#    '#bot': True},
#   'Positive'),
#  ({'chloe': True,
#    'watch': True,
#    'let': True,
#    'yesterday': True,
#    'really': True,
#    'awesome': True,
#    'talented': True,
#    'intelligent': True,
#    'actress': True,
#    'beautiful': True,
#    ':)': True},
#   'Positive'),
#  ({'could': True,
#    'get': True,
#    'free': True,
#    'solo': True,
#    'dm': True,
#    'give': True,
#    'away': True,
#    ':)': True,
#    'xoxo': True},
#   'Positive'),
#  ({'thanks': True,
#    'share': True,
#    'wishing': True,
#    'wicked': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'hola': True,
#    'juan': True,
#    '..': True,
#    'sending': True,
#    'big': True,
#    'hi': True,
#    'houston': True,
#    'tx': True,
#    ':)': True,
#    "i've": True,
#    'fan': True,
#    'jenni': True,
#    'family': True,
#    "year's": True,
#    'stumble': True,
#    'upon': True,
#    'video': True},
#   'Positive'),
#  ({'prob.nice': True, 'choker': True, 'btw': True, ':)': True}, 'Positive'),
#  ({'seouljins': True, ':)': True, 'fine': True, 'tbh': True}, 'Positive'),
#  ({'photoset': True,
#    'sadomasochistsparadise': True,
#    'wynter': True,
#    'bottoms': True,
#    'outtake': True,
#    ':)': True,
#    'sadomasochist': True,
#    '’': True,
#    'paradise': True,
#    'cuties': True},
#   'Positive'),
#  ({'make': True, 'day': True, 'smile': True, ':)': True}, 'Positive'),
#  ({'fback': True, ':)': True}, 'Positive'),
#  ({':d': True, 'ty': True, 'bby': True}, 'Positive'),
#  ({'please': True,
#    'enjoy': True,
#    'clip': True,
#    'lose': True,
#    'shit': True,
#    'cypher': True,
#    ':)': True},
#   'Positive'),
#  ({'next': True,
#    'week': True,
#    'office': True,
#    'let': True,
#    'go': True,
#    ':)': True},
#   'Positive'),
#  ({'thank': True, 'follow': True, ':d': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '2': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'amen': True, 'thanks': True, ':)': True}, 'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x32': True},
#   'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'paper': True, 'girl': True, ':d': True}, 'Positive'),
#  ({'know': True,
#    'would': True,
#    'lovely': True,
#    'pic': True,
#    ':)': True,
#    'x': True},
#   'Positive'),
#  ({'planted': True,
#    'people': True,
#    'allow': True,
#    'thing': True,
#    'every': True,
#    ':p': True},
#   'Positive'),
#  ({'corner': True,
#    'fucking': True,
#    'dope': True,
#    'getting': True,
#    'addict': True,
#    '..': True,
#    'great': True,
#    'job': True,
#    ':d': True},
#   'Positive'),
#  ({'bby': True, 'gurl': True, ':)': True}, 'Positive'),
#  ({'hey': True, ':d': True}, 'Positive'),
#  ({'still': True,
#    'suck': True,
#    'edit': True,
#    'turn': True,
#    'something': True,
#    'special': True,
#    'owe': True,
#    'guy': True,
#    ':)': True},
#   'Positive'),
#  ({'visit': True, 'blog': True, 'thanks': True, ':d': True}, 'Positive'),
#  ({'ugly': True, 'daniel': True, 'good': True, 'ape': True, ':)': True},
#   'Positive'),
#  ({'happy': True,
#    'bday': True,
#    'saar': True,
#    '...': True,
#    'great': True,
#    'year': True,
#    'ahead': True,
#    ':)': True},
#   'Positive'),
#  ({'thought': True,
#    'might': True,
#    'saw': True,
#    'love': True,
#    'verse': True,
#    'butterfly': True,
#    'part': True,
#    'bonus': True,
#    ':)': True},
#   'Positive'),
#  ({'thank': True,
#    ':-)': True,
#    'ok': True,
#    'fun': True,
#    'enjoy': True,
#    'day': True,
#    'u': True},
#   'Positive'),
#  ({'well': True, 'good': True, 'morning': True, ':d': True}, 'Positive'),
#  ({'would': True, 'follow': True, ':)': True}, 'Positive'),
#  ({'busy': True,
#    'productive': True,
#    'day': True,
#    'fill': True,
#    'tear': True,
#    'hour': True,
#    'laughter': True,
#    'today': True,
#    'good': True,
#    ':)': True},
#   'Positive'),
#  ({'hi': True, '5sos': True, 'ticket': True, 'dm': True, ':)': True},
#   'Positive'),
#  ({'yummmyyy': True,
#    '...': True,
#    ':-)': True,
#    '—': True,
#    'eat': True,
#    'dosa': True},
#   'Positive'),
#  ({':d': True}, 'Positive'),
#  ({'probably': True,
#    'easy': True,
#    'meet': True,
#    'station': True,
#    'unless': True,
#    'particularly': True,
#    'want': True,
#    'show': True,
#    'house': True,
#    ':)': True},
#   'Positive'),
#  ({'huge': True, 'warm': True, 'welcome': True, ':-)': True}, 'Positive'),
#  ({'achi': True,
#    'im': True,
#    'busy': True,
#    'next': True,
#    'week': True,
#    'exam': True,
#    'hope': True,
#    'understand': True,
#    'cant': True,
#    'tweet': True,
#    'youuu': True,
#    'bawi': True,
#    'ako': True,
#    'queenesther': True,
#    ':)': True},
#   'Positive'),
#  ({'looking': True, 'sharp': True, ':-)': True}, 'Positive'),
#  ({'yes': True,
#    'im': True,
#    '1': True,
#    'year': True,
#    'young': True,
#    'u': True,
#    ':-)': True,
#    'wonder': True,
#    'youre': True,
#    'huge': True,
#    'boy': True},
#   'Positive'),
#  ({"i'm": True, 'play': True, 'brain': True, 'dots': True, '#braindots': True},
#   'Positive'),
#  ({'ha': True, 'one': True, 'picture': True, ':-)': True}, 'Positive'),
#  ({'ready': True, ':)': True, '#poldi': True, '#cimbom': True}, 'Positive'),
#  ({'thanks': True, 'share': True, ':)': True}, 'Positive'),
#  ({'fback': True, ':)': True}, 'Positive'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'happy': True, 'birthday': True, 'buddy': True, ':d': True}, 'Positive'),
#  ({'thank': True, ':-)': True}, 'Positive'),
#  ({'sigh': True,
#    'bruhhh': True,
#    '“': True,
#    'call': True,
#    'daddy': True,
#    'one': True,
#    'time': True,
#    ':)': True,
#    '”': True},
#   'Positive'),
#  ...]

# %%
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.9963333333333333
# Most Informative Features
#                       :( = True           Negati : Positi =   2100.6 : 1.0
#                       :) = True           Positi : Negati =   1646.2 : 1.0
#                      sad = True           Negati : Positi =     35.0 : 1.0
#                 follower = True           Positi : Negati =     21.5 : 1.0
#                 followed = True           Negati : Positi =     15.6 : 1.0
#                     blog = True           Positi : Negati =     14.2 : 1.0
#                       aw = True           Negati : Positi =     13.8 : 1.0
#                     glad = True           Positi : Negati =     13.6 : 1.0
#                     miss = True           Negati : Positi =     12.8 : 1.0
#                    didnt = True           Negati : Positi =     11.8 : 1.0
# None

# %%
pickle.dump(classifier, open('tweets_text.sav', 'wb'))

# %%
def clean_tweet(tweet): 
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)", " ", tweet).split())

# %%
neutral_dataset = []
    
for custom_tweet in text:
    custom_tokens = remove_noise(word_tokenize(custom_tweet))
    analysis = TextBlob(clean_tweet(custom_tweet))

    
    if (analysis.sentiment.polarity == 0.0):
        neutral_dataset.append((dict([token, True] for token in custom_tokens), "Neutral"))
    
    else: 
        if classifier.classify(dict([token, True] for token in custom_token)) == "Positive":
            positive_dataset.append((dict([token, True] for token in custom_tokens), "Positive"))
        else:
            negative_dataset.append((dict([token, True] for token in custom_tokens), "Negative"))

# %%
len(positive_dataset)
# Out:
# 14751

# %%
negative_dataset
# Out:
# [({'hopeless': True, 'tmr': True, ':(': True}, 'Negative'),
#  ({'everything': True,
#    'kid': True,
#    'section': True,
#    'ikea': True,
#    'cute': True,
#    'shame': True,
#    "i'm": True,
#    'nearly': True,
#    '19': True,
#    '2': True,
#    'month': True,
#    ':(': True},
#   'Negative'),
#  ({'heart': True, 'slide': True, 'waste': True, 'basket': True, ':(': True},
#   'Negative'),
#  ({'“': True,
#    'hate': True,
#    'japanese': True,
#    'call': True,
#    'ban': True,
#    ':(': True,
#    '”': True},
#   'Negative'),
#  ({'dang': True,
#    'start': True,
#    'next': True,
#    'week': True,
#    'work': True,
#    ':(': True},
#   'Negative'),
#  ({'oh': True, 'god': True, 'baby': True, 'face': True, ':(': True},
#   'Negative'),
#  ({'make': True, 'smile': True, ':(': True}, 'Negative'),
#  ({'work': True,
#    'neighbour': True,
#    'motor': True,
#    'asked': True,
#    'say': True,
#    'hat': True,
#    'update': True,
#    'search': True,
#    ':(': True},
#   'Negative'),
#  ({':(': True, 'sialan': True}, 'Negative'),
#  ({'athabasca': True,
#    'glacier': True,
#    '#1948': True,
#    ':-(': True,
#    '#athabasca': True,
#    '#glacier': True,
#    '#jasper': True,
#    '#jaspernationalpark': True,
#    '#alberta': True,
#    '#explorealberta': True,
#    '…': True},
#   'Negative'),
#  ({'really': True,
#    'good': True,
#    'g': True,
#    'idea': True,
#    "i'm": True,
#    'never': True,
#    'go': True,
#    'meet': True,
#    ':(': True},
#   'Negative'),
#  ({'mare': True, 'ivan': True, ':(': True}, 'Negative'),
#  ({'happy': True,
#    'trip': True,
#    'keep': True,
#    'safe': True,
#    'see': True,
#    'soon': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True, 'tire': True, 'hahahah': True, ':(': True}, 'Negative'),
#  ({'knee': True,
#    'replacement': True,
#    'get': True,
#    'day': True,
#    ':-(': True,
#    'ouch': True},
#   'Negative'),
#  ({'relate': True,
#    'sweet': True,
#    'n': True,
#    'sour': True,
#    'kind': True,
#    'bi-polar': True,
#    'people': True,
#    'life': True,
#    '...': True,
#    'cuz': True,
#    'full': True,
#    ':(': True},
#   'Negative'),
#  ({'pleasse': True, ':(': True}, 'Negative'),
#  ({'im': True, 'sure': True, 'tho': True, ':(': True}, 'Negative'),
#  ({'feel': True,
#    'stupid': True,
#    "can't": True,
#    'seem': True,
#    'grasp': True,
#    'basic': True,
#    'digital': True,
#    'painting': True,
#    'nothing': True,
#    "i've": True,
#    'research': True,
#    'help': True,
#    ':(': True},
#   'Negative'),
#  ({'good': True, 'lord': True, ':(': True}, 'Negative'),
#  ({'feel': True,
#    'lonely': True,
#    'someone': True,
#    'talk': True,
#    'guy': True,
#    'girl': True,
#    ':(': True},
#   'Negative'),
#  ({'assignment': True, 'project': True, ':(': True, 'really': True, '😩': True},
#   'Negative'),
#  ({'want': True,
#    'play': True,
#    'video': True,
#    'game': True,
#    'watch': True,
#    'movie': True,
#    'someone': True,
#    ':(': True},
#   'Negative'),
#  ({'choreographing': True, 'hard': True}, 'Negative'),
#  ({'email': True,
#    'link': True,
#    'still': True,
#    'say': True,
#    'long': True,
#    'available': True,
#    ':(': True},
#   'Negative'),
#  ({'cry': True,
#    'bc': True,
#    'miss': True,
#    'mingming': True,
#    'much': True,
#    ':-(': True},
#   'Negative'),
#  ({'sorry': True, ':(': True}, 'Negative'),
#  ({'mom': True, 'far': True, 'away': True, ':(': True}, 'Negative'),
#  ({"we're": True,
#    'truly': True,
#    'sorry': True,
#    ':(': True,
#    'safe': True,
#    'flight': True},
#   'Negative'),
#  ({'friend': True, ':(': True}, 'Negative'),
#  ({'oh': True,
#    ':(': True,
#    'hate': True,
#    'happen': True,
#    'get': True,
#    'sad': True},
#   'Negative'),
#  ({'oh': True,
#    'dog': True,
#    'pee': True,
#    '’': True,
#    'bag': True,
#    ':-(': True,
#    'take': True,
#    '#newwine15': True},
#   'Negative'),
#  ({'doushite': True, ':(': True}, 'Negative'),
#  ({'late': True, ':(': True}, 'Negative'),
#  ({'suck': True,
#    'much': True,
#    'sick': True,
#    'plan': True,
#    'start': True,
#    'work': True,
#    'first': True,
#    'gundam': True,
#    'night': True,
#    'nope': True,
#    ':(': True},
#   'Negative'),
#  ({'2': True, 'dollar': True, ':(': True, '😭': True}, 'Negative'),
#  ({'listening': True,
#    'back': True,
#    'old': True,
#    'show': True,
#    'know': True,
#    "i'm": True,
#    'weird': True,
#    'get': True,
#    'u': True,
#    'leave': True,
#    'might': True,
#    'give': True,
#    'pale': True,
#    'imitation': True,
#    ':-(': True},
#   'Negative'),
#  ({'go': True,
#    'sea': True,
#    'massive': True,
#    'fucking': True,
#    'rash': True,
#    'body': True,
#    'painful': True,
#    'thing': True,
#    'ever': True,
#    'want': True,
#    'home': True,
#    ':(': True},
#   'Negative'),
#  ({'hi': True, 'absent': True, ':(': True}, 'Negative'),
#  ({'gran': True,
#    'tho': True,
#    'know': True,
#    'care': True,
#    'tell': True,
#    ':(': True},
#   'Negative'),
#  ({'cute': True,
#    'love': True,
#    'much': True,
#    'wish': True,
#    'would': True,
#    'sequel': True,
#    ':(': True},
#   'Negative'),
#  ({'busy': True,
#    'sa': True,
#    'school': True,
#    ':(': True,
#    'next': True,
#    'time': True,
#    'love': True,
#    'yah': True,
#    'xx': True},
#   'Negative'),
#  ({'ouucchhh': True,
#    'one': True,
#    'wisdom': True,
#    'teeth': True,
#    'come': True,
#    ':(': True},
#   'Negative'),
#  ({'frighten': True, 'case': True, 'really': True, 'get': True, ':(': True},
#   'Negative'),
#  ({'pret': True,
#    ':(': True,
#    'wkwkw': True,
#    'verfied': True,
#    'active': True,
#    'forget': True,
#    'follow': True,
#    'member': True,
#    'thanks': True,
#    'join': True,
#    'goodbye': True},
#   'Negative'),
#  ({'´': True,
#    'get': True,
#    'chain': True,
#    'love': True,
#    '—': True,
#    'sentir-se': True,
#    'incompleta': True},
#   'Negative'),
#  ({'okay': True, '..': True, ':(': True}, 'Negative'),
#  ({'go': True, 'wednesday': True, ':(': True}, 'Negative'),
#  ({'marvellous': True, 'thwarting': True, ':-(': True}, 'Negative'),
#  ({'awh': True,
#    "what's": True,
#    'chance': True,
#    '😩': True,
#    'u': True,
#    'zante': True,
#    'need': True,
#    'something': True,
#    ':-(': True,
#    'x': True},
#   'Negative'),
#  ({"when's": True, 'birthday': True, ':(': True}, 'Negative'),
#  ({'bad': True, 'part': True, 'still': True, 'feel': True, ':(': True},
#   'Negative'),
#  ({'audraesar': True,
#    'sushi': True,
#    'pic': True,
#    'tl': True,
#    'drive': True,
#    'craaaazzyy': True,
#    ':(': True},
#   'Negative'),
#  ({'really': True, 'want': True, ':(': True}, 'Negative'),
#  ({'popped': True,
#    'like': True,
#    'helium': True,
#    'balloon': True,
#    '..': True,
#    ':-(': True},
#   'Negative'),
#  ({'#climatechange': True,
#    '#cc': True,
#    "california's": True,
#    'powerful': True,
#    'influential': True,
#    'air': True,
#    'pollution': True,
#    'watchdog': True,
#    'califor': True,
#    '...': True,
#    '#uniteblue': True,
#    '#tcot': True,
#    ':-(': True},
#   'Negative'),
#  ({'sad': True,
#    'elhaida': True,
#    'rob': True,
#    'jury': True,
#    ':(': True,
#    'come': True,
#    '10th': True,
#    'televoting': True},
#   'Negative'),
#  ({'#climatechange': True,
#    '#cc': True,
#    'idaho': True,
#    'restrict': True,
#    'fish': True,
#    'despite': True,
#    'regional': True,
#    'drought-linked': True,
#    'die-of': True,
#    '...': True,
#    '#uniteblue': True,
#    '#tcot': True,
#    ':-(': True},
#   'Negative'),
#  ({'#climatechange': True,
#    '#cc': True,
#    'abrupt': True,
#    'climate': True,
#    'change': True,
#    'may': True,
#    'doom': True,
#    'mammoth': True,
#    'megafauna': True,
#    'sc': True,
#    '...': True,
#    '#uniteblue': True,
#    '#tcot': True,
#    ':-(': True},
#   'Negative'),
#  ({'#climatechange': True,
#    '#cc': True,
#    "australia's": True,
#    'dirtiest': True,
#    'power': True,
#    'station': True,
#    'considers': True,
#    'clean': True,
#    'energy': True,
#    'biomass': True,
#    '...': True,
#    '#uniteblue': True,
#    '#tcot': True,
#    ':-(': True},
#   'Negative'),
#  ({'#climatechange': True,
#    '#cc': True,
#    "ain't": True,
#    'easy': True,
#    'green': True,
#    'golf': True,
#    'course': True,
#    'california': True,
#    'ulti': True,
#    '...': True,
#    '#uniteblue': True,
#    '#tcot': True,
#    ':-(': True},
#   'Negative'),
#  ({'well': True,
#    'sure': True,
#    'work': True,
#    'day': True,
#    'mine': True,
#    ':(': True},
#   'Negative'),
#  ({'im': True,
#    'gonna': True,
#    'miss': True,
#    'u': True,
#    'sexy': True,
#    'prexy': True,
#    ':(': True},
#   'Negative'),
#  ({'miss': True, 'kindergarten': True, 'kid': True, ':(': True}, 'Negative'),
#  ({'hungry': True, ':-(': True}, 'Negative'),
#  ({'cant': True,
#    'find': True,
#    'book': True,
#    'keep': True,
#    'sane': True,
#    ':(': True},
#   'Negative'),
#  ({'literally': True,
#    'three': True,
#    'lounge': True,
#    'event': True,
#    ':-(': True,
#    'much': True,
#    'turn': True,
#    "i'm": True,
#    'sad': True},
#   'Negative'),
#  ({'miss': True, 'boss': True, ':(': True}, 'Negative'),
#  ({'love': True, 'hozier': True, ':-(': True}, 'Negative'),
#  ({"that's": True,
#    'true': True,
#    'want': True,
#    'soooooooner': True,
#    ':(': True},
#   'Negative'),
#  ({'ahh': True, 'fam': True, ':(': True, '#respectlost': True}, 'Negative'),
#  ({"i'm": True,
#    'sorry': True,
#    ':(': True,
#    'hypercholesteloremia': True,
#    'ok': True},
#   'Negative'),
#  ({'baby': True, 'still': True, 'look': True, 'tired': True, ':(': True},
#   'Negative'),
#  ({'someone': True, 'gift': True, 'calibraska': True, ':(': True}, 'Negative'),
#  ({'massive': True,
#    'shame': True,
#    'would': True,
#    'actually': True,
#    'genuine': True,
#    'contender': True,
#    'happen': True,
#    ':(': True},
#   'Negative'),
#  ({'head': True,
#    'always': True,
#    'hurt': True,
#    'stay': True,
#    'late': True,
#    'lmao': True,
#    ':(': True},
#   'Negative'),
#  ({'u': True, 'old': True, ':(': True}, 'Negative'),
#  ({'backed': True, ':(': True}, 'Negative'),
#  ({'u': True, 'sound': True, 'upset': True, ':(': True}, 'Negative'),
#  ({'much': True, 'miss': True, ':-(': True}, 'Negative'),
#  ({'miss': True, 'infinite': True, ':-(': True}, 'Negative'),
#  ({'aos': True,
#    'want': True,
#    'stick': True,
#    '8th': True,
#    'either': True,
#    ':(': True},
#   'Negative'),
#  ({'much': True, 'serious': True, 'yun': True, 'eh': True, ':(': True},
#   'Negative'),
#  ({'room': True, 'way': True, 'hot': True, ':-(': True}, 'Negative'),
#  ({'still': True,
#    'havent': True,
#    'find': True,
#    'handsome': True,
#    'jack': True,
#    'draw': True,
#    ':(': True},
#   'Negative'),
#  ({'shit': True, ':(': True}, 'Negative'),
#  ({'cut': True, 'encore': True, ':(': True, '#bad4thwin': True}, 'Negative'),
#  ({'wish': True, 'baymax': True, ':(': True}, 'Negative'),
#  ({'sick': True, ':(': True}, 'Negative'),
#  ({'french': True,
#    'mixer': True,
#    'miss': True,
#    'much': True,
#    ':(': True,
#    '💜': True},
#   'Negative'),
#  ({'wft': True,
#    '..': True,
#    "can't": True,
#    'watch': True,
#    'awesome': True,
#    'replay': True,
#    ':-(': True},
#   'Negative'),
#  ({'happen': True, ':(': True}, 'Negative'),
#  ({'party': True, 'promotion': True, ':(': True}, 'Negative'),
#  ({'music': True,
#    'bank': True,
#    'encore': True,
#    'always': True,
#    'short': True,
#    ':(': True},
#   'Negative'),
#  ({'baby': True, 'boy': True, ':(': True}, 'Negative'),
#  ({'order': True,
#    'receive': True,
#    'hub': True,
#    'near': True,
#    'look': True,
#    'like': True,
#    'deliver': True,
#    'today': True,
#    ':(': True,
#    '1/2': True},
#   'Negative'),
#  ({'mum': True, 'playing': True, 'music': True, 'loud': True, ':(': True},
#   'Negative'),
#  ({'finale': True,
#    'parasyte': True,
#    'fuck': True,
#    'feeling': True,
#    'alllllll': True,
#    'way': True,
#    ':(': True},
#   'Negative'),
#  ({'wish': True, ':(': True, '#zayniscomingbackonjuly26': True}, 'Negative'),
#  ({'good': True, 'bye': True, 'party': True, 'era': True, ':(': True},
#   'Negative'),
#  ({'。': True,
#    ':(': True,
#    '´': True,
#    'ω': True,
#    '」': True,
#    '∠': True,
#    '):': True},
#   'Negative'),
#  ({'nathann': True,
#    '💕': True,
#    'never': True,
#    'get': True,
#    'chance': True,
#    'take': True,
#    'pic': True,
#    ':(': True,
#    'hug': True,
#    'tho': True,
#    'next': True,
#    'time': True,
#    'see': True,
#    '😊': True},
#   'Negative'),
#  ({'girl': True,
#    'come': True,
#    'like': True,
#    'beautiful': True,
#    ':-(': True,
#    'want': True,
#    'dieididieieiei': True,
#    'cute': True},
#   'Negative'),
#  ({'party': True,
#    'goodbye': True,
#    'stage': True,
#    ':(': True,
#    'mean': True,
#    'hello': True,
#    'lion': True,
#    'heart': True,
#    'think': True},
#   'Negative'),
#  ({'tell': True,
#    'screw': True,
#    "i'm": True,
#    'gonna': True,
#    'netflix': True,
#    'chill': True,
#    'u': True,
#    'dis': True,
#    'ervin': True,
#    ':(': True},
#   'Negative'),
#  ({'ohh': True,
#    ':(': True,
#    'yeah': True,
#    'hope': True,
#    'come': True,
#    'back': True,
#    'soon': True},
#   'Negative'),
#  ({"i've": True,
#    'accept': True,
#    'offer': True,
#    '..': True,
#    'im': True,
#    'desperate': True,
#    'take': True,
#    'year': True,
#    ':(': True},
#   'Negative'),
#  ({'come': True, 'back': True, ':(': True}, 'Negative'),
#  ({'snapchat': True,
#    'amargolonnard': True,
#    '#snapchat': True,
#    '#kikhorny': True,
#    '#snapme': True,
#    '#tagsforlikes': True,
#    '#batalladelosgallos': True,
#    '#webcamsex': True,
#    ':(': True},
#   'Negative'),
#  ({'ugh': True,
#    'cant': True,
#    'stream': True,
#    'tmr': True,
#    'duty': True,
#    ':(': True},
#   'Negative'),
#  ({"u've": True, 'go': True, 'far': True, ':(': True}, 'Negative'),
#  ({'alien': True, 'thing': True, ':(': True}, 'Negative'),
#  ({'aww': True,
#    'really': True,
#    'wanna': True,
#    'get': True,
#    'hope': True,
#    'wish': True,
#    'would': True,
#    ':(': True},
#   'Negative'),
#  ({'sorka': True, ':(': True}, 'Negative'),
#  ({'know': True,
#    'u': True,
#    'would': True,
#    'sad': True,
#    ':(': True,
#    'funeral': True,
#    'gonna': True,
#    'text': True,
#    'phone': True},
#   'Negative'),
#  ({'sunny': True, ':(': True, 'feel': True, 'bad': True, '...': True},
#   'Negative'),
#  ({'nonexistent': True, 'wowza': True, ':(': True}, 'Negative'),
#  ({'back': True, 'fah': True, 'mine': True, ':-(': True}, 'Negative'),
#  ({'taylor': True, 'crop': True, ':(': True}, 'Negative'),
#  ({'boo': True, 'count': True, ':-(': True}, 'Negative'),
#  ({'new': True, 'guitar': True, ':(': True}, 'Negative'),
#  ({'get': True,
#    'jonghyun': True,
#    'hyung': True,
#    ':(': True,
#    'please': True,
#    'predict': True},
#   'Negative'),
#  ({'hope': True,
#    'sj': True,
#    'nominate': True,
#    'soon': True,
#    'vs': True,
#    'infinite': True,
#    'pls': True,
#    ':(': True},
#   'Negative'),
#  ({'yeah': True,
#    'dude': True,
#    'keep': True,
#    'calm': True,
#    'brace': True,
#    ':-(': True},
#   'Negative'),
#  ({'sir': True, 'plus': True, '4': True, 'please': True, ':(': True},
#   'Negative'),
#  ({'looked': True,
#    'shock': True,
#    'omgggg': True,
#    ':(': True,
#    'yall': True,
#    'deserve': True},
#   'Negative'),
#  ({'whenever': True,
#    'would': True,
#    'spend': True,
#    'night': True,
#    'smoke': True,
#    'watch': True,
#    'movie': True,
#    'always': True,
#    'end': True,
#    'fall': True,
#    'asleep': True,
#    ':(': True},
#   'Negative'),
#  ({'1': True,
#    'point': True,
#    'close': True,
#    'grand': True,
#    'final': True,
#    ':(': True,
#    'whyyy': True},
#   'Negative'),
#  ({':(': True, "that's": True, 'long': True, 'time': True}, 'Negative'),
#  ({'oh': True,
#    'must': True,
#    'annoying': True,
#    'evan': True,
#    ':(': True,
#    'text': True,
#    'give': True,
#    'option': True,
#    'opt': True},
#   'Negative'),
#  ({"who's": True,
#    'giveaway': True,
#    'muster': True,
#    'good': True,
#    ':(': True,
#    'merchs': True},
#   'Negative'),
#  ({'ah': True, 'bad': True, ':(': True}, 'Negative'),
#  ({'people': True,
#    'look': True,
#    'funny': True,
#    "i'm": True,
#    'drink': True,
#    'savanna': True,
#    'straw': True,
#    ':(': True},
#   'Negative'),
#  ({'good': True, 'bye': True, 'stage': True, ':(': True}, 'Negative'),
#  ({'ignore': True, 'yester': True, 'afternoon': True, ':(': True}, 'Negative'),
#  ({"can't": True, 'sleep': True, ':(': True, 'someone': True, 'talk': True},
#   'Negative'),
#  ({'yeah': True, ':(': True}, 'Negative'),
#  ({'yes': True, 'sadly': True, ':(': True}, 'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'whens': True, 'album': True, 'come': True, ':(': True}, 'Negative'),
#  ({'last': True, 'chocolate': True, 'consume': True, ':(': True}, 'Negative'),
#  ({'ugh': True, 'werk': True, 'morning': True, ':-(': True}, 'Negative'),
#  ({'foreals': True,
#    ':(': True,
#    'wesen': True,
#    'uwesiti': True,
#    'mj': True,
#    '😂': True,
#    '😩': True},
#   'Negative'),
#  ({'catch': True,
#    'online': True,
#    'long': True,
#    'enough': True,
#    'haha': True,
#    "he's": True,
#    'annoy': True,
#    ':(': True},
#   'Negative'),
#  ({'bosen': True, ':(': True}, 'Negative'),
#  ({'dying': True, 'egg': True, 'benny': True, ':(': True}, 'Negative'),
#  ({'sometimes': True, 'hate': True, ':(': True}, 'Negative'),
#  ({'baby': True, 'followback': True, 'huhu': True, ':(': True}, 'Negative'),
#  ({'one': True, 'cute': True, 'u': True, ':(': True}, 'Negative'),
#  ({'gonna': True,
#    'watch': True,
#    'shit': True,
#    'understand': True,
#    'badly': True,
#    'scar': True,
#    '>:(': True},
#   'Negative'),
#  ({'miss': True,
#    'al': True,
#    'katie': True,
#    'zaz': True,
#    'amy': True,
#    'lot': True,
#    ':(': True},
#   'Negative'),
#  ({'like': True, 'video': True, 'subs': True, 'plz': True, ':(': True},
#   'Negative'),
#  ({'u': True, 'make': True, 'diary': True, 'please': True, ':(': True},
#   'Negative'),
#  ({'sorry': True, ':(': True}, 'Negative'),
#  ({':-(': True,
#    'read': True,
#    'rehash': True,
#    'website': True,
#    'mushroom': True,
#    'good': True,
#    'piece': True,
#    'may': True,
#    'exception': True,
#    'reach': True,
#    'one': True,
#    'anyway': True},
#   'Negative'),
#  ({'yes': True, 'vicky': True, 'omg': True, ':-(': True}, 'Negative'),
#  ({'wtf': True,
#    'like': True,
#    'lips': True,
#    'still': True,
#    'virgin': True,
#    'omg': True,
#    'mom': True,
#    'get': True,
#    'life': True,
#    'youre': True,
#    '45': True,
#    'hahah': True},
#   'Negative'),
#  ({'ninasty': True,
#    'tsktsk': True,
#    'oppa': True,
#    'wont': True,
#    'like': True,
#    'u': True,
#    'call': True,
#    'dick': True,
#    'kawaii': True,
#    'manly': True,
#    '>:(': True},
#   'Negative'),
#  ({'lonely': True, ':(': True}, 'Negative'),
#  ({"can't": True, 'go': True, 'back': True, 'sleep': True, ':(': True},
#   'Negative'),
#  ({'wanna': True,
#    'go': True,
#    'xbox': True,
#    'netflix': True,
#    'already': True,
#    'comfy': True,
#    'bed': True,
#    ':(': True},
#   'Negative'),
#  ({'miss': True, 'youu': True, ':(': True}, 'Negative'),
#  ({'sigh': True, 'feel': True, 'bad': True, 'girl': True, ':(': True},
#   'Negative'),
#  ({'lol': True,
#    'love': True,
#    'sweet': True,
#    'potato': True,
#    'fry': True,
#    ':(': True},
#   'Negative'),
#  ({'guess': True,
#    "y'all": True,
#    'ugly': True,
#    'asf': True,
#    'huh': True,
#    ':(': True},
#   'Negative'),
#  ({'eish': True,
#    'ive': True,
#    'quit': True,
#    'know': True,
#    '...': True,
#    'lose': True,
#    'twitter': True,
#    'mojo': True,
#    'shame': True,
#    'n': True,
#    'dont': True,
#    'get': True,
#    'back': True,
#    ':(': True,
#    'mara': True,
#    'im': True,
#    'sure': True,
#    'help': True,
#    'neh': True},
#   'Negative'),
#  ({'aww': True,
#    "i've": True,
#    'get': True,
#    'fever': True,
#    ':(': True,
#    '#bad4thwin': True,
#    '<3': True},
#   'Negative'),
#  ({'poor': True, 'bb': True, ':(': True}, 'Negative'),
#  ({"i'm": True,
#    'able': True,
#    'go': True,
#    ':(': True,
#    'association': True,
#    'green': True,
#    'councillors': True,
#    'conference': True,
#    'weekend': True,
#    '...': True},
#   'Negative'),
#  ({'skype': True,
#    'account': True,
#    'order': True,
#    'think': True,
#    'hack': True,
#    'contact': True,
#    "i'm": True,
#    'sorry': True,
#    ':(': True,
#    'create': True,
#    'new': True,
#    'one': True,
#    'soon': True},
#   'Negative'),
#  ({'miss': True, 'tweet': True, 'spree': True, 'oh': True, ':(': True},
#   'Negative'),
#  ({'yes': True,
#    'na': True,
#    'sholong': True,
#    'reject': True,
#    'proposal': True,
#    ':(': True,
#    'gee': True,
#    'u': True,
#    'fly': True,
#    'go': True,
#    'gidi': True,
#    'way': True,
#    "i'm": True,
#    'pamper': True,
#    'lagos': True,
#    'ehn': True,
#    '...': True},
#   'Negative'),
#  ({'guess': True, 'im': True, 'arrest': True, 'girlfriend': True, ':(': True},
#   'Negative'),
#  ({'nice': True,
#    'person': True,
#    'idk': True,
#    'anybody': True,
#    'would': True,
#    'say': True,
#    ':(': True},
#   'Negative'),
#  ({'know': True,
#    'song': True,
#    'disappear': True,
#    'phone': True,
#    'itunes': True,
#    "i've": True,
#    'lose': True,
#    'dazed': True,
#    'confused': True,
#    ':(': True},
#   'Negative'),
#  ({'fever': True, ':-(': True}, 'Negative'),
#  ({'think': True,
#    'survive': True,
#    'well': True,
#    'find': True,
#    'miss': True,
#    'body': True,
#    'fragment': True,
#    "would've": True,
#    'nice': True,
#    ':(': True},
#   'Negative'),
#  ({'im': True, 'force': True, 'go': True, ':-(': True}, 'Negative'),
#  ({'horrible': True, 'weather': True, 'go': True, 'work': True, ':(': True},
#   'Negative'),
#  ({'wish': True, 'us': True, 'could': True, 'change': True, ':(': True},
#   'Negative'),
#  ({'walao': True,
#    'kbs': True,
#    'never': True,
#    'show': True,
#    'encore': True,
#    ':(': True},
#   'Negative'),
#  ({'sending': True, 'finally': True, ':(': True}, 'Negative'),
#  ({'ill': True, 'bad': True, ':(': True}, 'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'hope': True,
#    '#djderek': True,
#    'find': True,
#    'safe': True,
#    'well': True,
#    'many': True,
#    'fun': True,
#    'time': True,
#    'gig': True,
#    'absolute': True,
#    'legend': True,
#    ':(': True},
#   'Negative'),
#  ({'yeah': True,
#    'like': True,
#    'need': True,
#    'wait': True,
#    'till': True,
#    'saturday': True,
#    'give': True,
#    'us': True,
#    'homework': True,
#    'pa': True,
#    ':(': True,
#    'u': True,
#    'made': True,
#    'plans': True,
#    '4': True,
#    'da': True,
#    'weekend': True},
#   'Negative'),
#  ({'greek': True, 'tragedy': True, 'cute': True, 'song': True, ':(': True},
#   'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'raining': True,
#    'today': True,
#    ':(': True,
#    'gym': True,
#    '💪': True,
#    '🏻': True,
#    '🐒': True},
#   'Negative'),
#  ({'whats': True, 'wrong': True, ':(': True}, 'Negative'),
#  ({'oh': True,
#    'god': True,
#    "i'm": True,
#    'strucked': True,
#    'pain': True,
#    '...': True,
#    'cant': True,
#    'take': True,
#    'anymore': True,
#    ':(': True},
#   'Negative'),
#  ({'come': True, 'belgium': True, ':(': True}, 'Negative'),
#  ({'fabian': True, 'delph': True, 'fall': True, ':(': True}, 'Negative'),
#  ({'u': True, 'hiding': True, 'baby': True, ':(': True}, 'Negative'),
#  ({"i'm": True,
#    'draking': True,
#    'silently': True,
#    "can't": True,
#    'hear': True,
#    ':(': True},
#   'Negative'),
#  ({'rest': True, 'peace': True, 'mo': True, ':(': True}, 'Negative'),
#  ({'much': True,
#    'chance': True,
#    'game': True,
#    'tonight': True,
#    ':(': True,
#    '#t20blast': True},
#   'Negative'),
#  ({'ahhh': True, 'u': True, 'see': True, 'wake': True, ':(': True},
#   'Negative'),
#  ({'mumma': True, 'im': True, '7': True, ':(': True}, 'Negative'),
#  ({'hope': True, ':(': True}, 'Negative'),
#  ({"i'm": True, 'gonna': True, 'dead': True, 'tomorrow': True, ':(': True},
#   'Negative'),
#  ({':(': True, "i'll": True, 'high': True, 'low': True}, 'Negative'),
#  ({'sad': True, 'pray': True, ':(': True}, 'Negative'),
#  ({'appropriate': True, ':(': True}, 'Negative'),
#  ({'poor': True, '. . .': True, ':(': True}, 'Negative'),
#  ({"i'm": True, 'still': True, 'awake': True, ':(': True}, 'Negative'),
#  ({'woke': True, 'upp': True, 'cant': True, 'sleep': True, ':(': True},
#   'Negative'),
#  ({'one': True, 'help': True, ':(': True}, 'Negative'),
#  ({'know': True, ':(': True, 'happy': True}, 'Negative'),
#  ({'hi': True, 'dm': True, 'luke': True, 'please': True, ':(': True},
#   'Negative'),
#  ({'hey': True,
#    'babe': True,
#    'come': True,
#    'across': True,
#    'pic': True,
#    '..': True,
#    'cant': True,
#    'read': True,
#    'hindi': True,
#    ':(': True},
#   'Negative'),
#  ({'reaction': True, ':(': True}, 'Negative'),
#  ({'5s': True,
#    ':(': True,
#    'think': True,
#    'bc': True,
#    'im': True,
#    'run': True,
#    'space': True,
#    'tbh': True},
#   'Negative'),
#  ({'wish': True,
#    'could': True,
#    'come': True,
#    'see': True,
#    'disability': True,
#    'pension': True,
#    'ptsd': True,
#    'make': True,
#    'impossible': True,
#    'physically': True,
#    'financially': True,
#    ':(': True},
#   'Negative'),
#  ({'rain': True, ':(': True}, 'Negative'),
#  ({'nooo': True,
#    'break': True,
#    'soo': True,
#    'amazing': True,
#    'togheter': True,
#    ':(': True},
#   'Negative'),
#  ({'suck': True,
#    'mean': True,
#    'watch': True,
#    'play': True,
#    'around': True,
#    '1': True,
#    'p': True,
#    'time': True,
#    ':(': True},
#   'Negative'),
#  ({'like': True, ':(': True}, 'Negative'),
#  ({'cant': True,
#    'hold': True,
#    'another': True,
#    'week': True,
#    'september': True,
#    '21st': True,
#    ':-(': True},
#   'Negative'),
#  ({'cut': True,
#    'encore': True,
#    'wanna': True,
#    'see': True,
#    'snsd': True,
#    'infinite': True,
#    'interaction': True,
#    ':(': True},
#   'Negative'),
#  ({'miss': True,
#    'watch': True,
#    'anna': True,
#    'akana': True,
#    'video': True,
#    ':(': True},
#   'Negative'),
#  ({'askip': True, "t'existes": True, 'pas': True, ':(': True}, 'Negative'),
#  ({'sadly': True,
#    ':(': True,
#    'channel': True,
#    'owner': True,
#    'decides': True,
#    'region': True,
#    'broadcast': True,
#    'thanks': True,
#    'kei': True,
#    'please': True,
#    'rate': True,
#    'se': True,
#    '...': True},
#   'Negative'),
#  ({'dont': True,
#    'think': True,
#    'ever': True,
#    'notice': True,
#    ':(': True,
#    'still': True,
#    'exist': True},
#   'Negative'),
#  ({'traffic': True, 'terrible': True, ':(': True}, 'Negative'),
#  ({"i've": True,
#    'eye': True,
#    'small': True,
#    'kate': True,
#    'spade': True,
#    'bag': True,
#    'pero': True,
#    'walang': True,
#    'maganda': True,
#    ':(': True},
#   'Negative'),
#  ({'haha': True,
#    'aw': True,
#    'miss': True,
#    'see': True,
#    'agessss': True,
#    ':(': True},
#   'Negative'),
#  ({'sigh': True, '...': True, ':(': True}, 'Negative'),
#  ({'add': True,
#    'snapchat': True,
#    'corinehurleigh': True,
#    '#snapchat': True,
#    '#snapchatme': True,
#    '#instagram': True,
#    '#addmeonsnapchat': True,
#    '#sfs': True,
#    '#quote': True,
#    '#kiksexting': True,
#    ':(': True},
#   'Negative'),
#  ({'bum': True, 'zara': True, 'trouser': True, ':(': True}, 'Negative'),
#  ({'sushi': True,
#    'pic': True,
#    'tl': True,
#    'drive': True,
#    'craaaazzyy': True,
#    ':(': True},
#   'Negative'),
#  ({'effect': True, 'spanish': True, ':(': True}, 'Negative'),
#  ({'aww': True,
#    'poor': True,
#    'thing': True,
#    ':(': True,
#    'hope': True,
#    "it'okay": True,
#    'good': True,
#    'health': True,
#    'luckely': True,
#    'free': True,
#    'rocks': True,
#    '#orcalove': True},
#   'Negative'),
#  ({'first': True, 'try': True, 'result': True, ':(': True}, 'Negative'),
#  ({'want': True, 'brace': True, 'back': True, ':(': True}, 'Negative'),
#  ({'need': True,
#    'big': True,
#    'cuddle': True,
#    'lew': True,
#    'kiss': True,
#    'face': True,
#    ':(': True,
#    'want': True,
#    'go': True},
#   'Negative'),
#  ({'ems': True, 'haha': True, ':(': True}, 'Negative'),
#  ({'craving': True,
#    'banana': True,
#    'crumble': True,
#    'mcflurry': True,
#    'fries': True,
#    ':(': True},
#   'Negative'),
#  ({"we're": True,
#    'go': True,
#    'cable': True,
#    'car': True,
#    'brother': True,
#    'get': True,
#    'scared': True,
#    'want': True,
#    ':(': True},
#   'Negative'),
#  ({'miss': True,
#    'hello': True,
#    "venus's": True,
#    'old': True,
#    'concept': True,
#    'tbh': True,
#    'rly': True,
#    'like': True,
#    'want': True,
#    'tea': True,
#    ':(': True},
#   'Negative'),
#  ({'tagal': True, ':(': True}, 'Negative'),
#  ({"we've": True,
#    'lose': True,
#    'album': True,
#    'broadcast': True,
#    'point': True,
#    ':(': True},
#   'Negative'),
#  ({'awful': True,
#    'appointment': True,
#    'tomorrow': True,
#    "i'd": True,
#    'like': True,
#    'feel': True,
#    'ok': True,
#    'go': True,
#    'since': True,
#    '>:(': True},
#   'Negative'),
#  ({'suck': True, 'want': True, 'go': True, 'home': True, ':(': True},
#   'Negative'),
#  ({"there's": True, 'milk': True, 'leave': True, 'cereal': True, ':(': True},
#   'Negative'),
#  ({'huh': True, ':(': True, 'yes': True}, 'Negative'),
#  ({'lose': True, 'album': True, 'broadcast': True, ':(': True}, 'Negative'),
#  ({'sad': True, ':(': True, 'via': True}, 'Negative'),
#  ({'everything': True, ':(': True}, 'Negative'),
#  ({'follow': True, ':(': True}, 'Negative'),
#  ({'yeah': True,
#    'try': True,
#    'film': True,
#    'date': True,
#    'start': True,
#    'time': True,
#    '4': True,
#    'day': True,
#    'leave': True,
#    ':(': True},
#   'Negative'),
#  ({'get': True, 'one': True, 'think': True, 'previous': True, ':(': True},
#   'Negative'),
#  ({"can't": True, 'smile': True, ':(': True}, 'Negative'),
#  ({"i'm": True,
#    'follow': True,
#    '73': True,
#    'user': True,
#    'back': True,
#    ':(': True},
#   'Negative'),
#  ({'get': True, '7': True}, 'Negative'),
#  ({'seem': True, 'everywhere': True, 'today': True, ':(': True}, 'Negative'),
#  ({'fansign': True,
#    'take': True,
#    'photo': True,
#    'expensive': True,
#    ':(': True},
#   'Negative'),
#  ({'zzzzzz': True,
#    '...': True,
#    'please': True,
#    'let': True,
#    'sun': True,
#    'come': True,
#    'yet': True,
#    ':(': True},
#   'Negative'),
#  ({"bff's": True,
#    'extremely': True,
#    'stress': True,
#    "can't": True,
#    'anything': True,
#    'pray': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'ahh': True, 'win': True, 'goodbye': True, 'stage': True, ':(': True},
#   'Negative'),
#  ({'true': True,
#    "deosn't": True,
#    'help': True,
#    'liverpool': True,
#    'last': True,
#    'week': True,
#    'never': True,
#    'pool': True,
#    'though': True,
#    ':(': True},
#   'Negative'),
#  ({'yes': True,
#    'bro': True,
#    '..': True,
#    'lose': True,
#    'many': True,
#    ':(': True},
#   'Negative'),
#  ({'pray': True, 'sorry': True, 'happen': True}, 'Negative'),
#  ({'great': True,
#    'news': True,
#    'thanks': True,
#    'let': True,
#    'us': True,
#    'know': True,
#    ':(': True,
#    'hope': True,
#    'good': True,
#    'weekend': True},
#   'Negative'),
#  ({'fucked': True, ':(': True}, 'Negative'),
#  ({'self': True, 'esteem': True, 'low': True, ':(': True}, 'Negative'),
#  ({'feel': True,
#    'look': True,
#    'good': True,
#    'people': True,
#    "can't": True,
#    'see': True,
#    'tbh': True,
#    'tacky': True,
#    ':(': True},
#   'Negative'),
#  ({'take': True, 'say': True, ':(': True}, 'Negative'),
#  ({'man': True, 'get': True, 'lucky': True, 'charm': True, ':(': True},
#   'Negative'),
#  ({'#haaretz': True,
#    '#israel': True,
#    ':-(': True,
#    'syria': True,
#    'continue': True,
#    'develop': True,
#    'chemical': True,
#    'weapon': True,
#    'official': True,
#    'tell': True,
#    'wsj': True,
#    'rep': True,
#    '...': True,
#    '#uniteblue': True,
#    '#tcot': True},
#   'Negative'),
#  ({'want': True, 'bts': True, 'merchs': True, ':(': True}, 'Negative'),
#  ({'one': True, 'day': True, ':(': True}, 'Negative'),
#  ({'take': True,
#    'pic': True,
#    'mr': True,
#    'wong': True,
#    'confiscate': True,
#    'art': True,
#    'work': True,
#    ':(': True},
#   'Negative'),
#  ({'#bad4thwin': True, 'guy': True, 'omg': True, ':(': True}, 'Negative'),
#  ({'think': True,
#    'icepack': True,
#    'big': True,
#    'dos': True,
#    'pain': True,
#    'killer': True,
#    'board': True,
#    'feel': True,
#    'painful': True,
#    'already': True,
#    ':(': True,
#    'whimper': True},
#   'Negative'),
#  ({'okay': True, ':(': True}, 'Negative'),
#  ({'say': True, 'man': True, 'u': True, 'fan': True, ':(': True}, 'Negative'),
#  ({':(': True,
#    'wish': True,
#    'could': True,
#    'say': True,
#    'final': True,
#    'goodbye': True},
#   'Negative'),
#  ({'senpai': True, '>:(': True, 'look': True, 'buttsex': True}, 'Negative'),
#  ({'joke': True,
#    'headline': True,
#    'friend': True,
#    ':(': True,
#    'pls': True,
#    "dn't": True,
#    'brk': True,
#    'heart': True,
#    ":'(": True},
#   'Negative'),
#  ({'someone': True,
#    'hit': True,
#    'head': True,
#    'voice': True,
#    "i'm": True,
#    'like': True,
#    'would': True,
#    'sound': True,
#    'amazing': True,
#    'could': True,
#    '...': True,
#    'falsetto': True,
#    ':(': True},
#   'Negative'),
#  ({'notice': True, ':(': True}, 'Negative'),
#  ({'hate': True, 'time': True, 'zone': True, ':(': True}, 'Negative'),
#  ({'snapchat': True,
#    'leanneriner': True,
#    '19': True,
#    '#snapchat': True,
#    '#hornykik': True,
#    '#loveofmylife': True,
#    '#dmme': True,
#    '#pussy': True,
#    '#newmusic': True,
#    '#sexo': True,
#    ':(': True},
#   'Negative'),
#  ({'s2': True,
#    'air': True,
#    'spain': True,
#    'delay': True,
#    'kill': True,
#    'us': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'single': True, 'untruth': True, ':(': True}, 'Negative'),
#  ({'last': True,
#    'cross': True,
#    'country': True,
#    'ij': True,
#    'amaze': True,
#    '💥': True,
#    '✨': True,
#    '💫': True,
#    "can't": True,
#    'bear': True,
#    'leave': True,
#    ':-(': True},
#   'Negative'),
#  ({"can't": True, 'drive': True, ':(': True}, 'Negative'),
#  ({'little': True,
#    'apartment': True,
#    'like': True,
#    'someone': True,
#    'come': True,
#    'live': True,
#    ':-(': True},
#   'Negative'),
#  ({'soshi': True,
#    'didnt': True,
#    'win': True,
#    ':(': True,
#    'buttt': True,
#    'congrats': True,
#    'infinite': True,
#    '#bad4thwin': True},
#   'Negative'),
#  ({"i'm": True,
#    'work': True,
#    'saturday': True,
#    'sunday': True,
#    'friday': True,
#    'bad': True,
#    'day': True,
#    ':(': True},
#   'Negative'),
#  ({'go': True, 'home': True, 'soon': True, ':(': True}, 'Negative'),
#  ({'shoulda': True,
#    'move': True,
#    'away': True,
#    'w': True,
#    'boy': True,
#    'chance': True,
#    'cause': True,
#    "they're": True,
#    'people': True,
#    'want': True,
#    'time': True,
#    'like': True,
#    ':(': True},
#   'Negative'),
#  ({'heyyyyy': True,
#    'want': True,
#    'see': True,
#    'yeols': True,
#    'solo': True,
#    'danceeeeee': True,
#    ':(': True},
#   'Negative'),
#  ({'inter': True,
#    'offer': True,
#    'nemanja': True,
#    'vidic': True,
#    'roma': True,
#    '...': True,
#    'want': True,
#    'either': True,
#    ':(': True},
#   'Negative'),
#  ({"mom's": True,
#    'linguist': True,
#    "dad's": True,
#    'computer': True,
#    'scientist': True,
#    'dumb': True,
#    'one': True,
#    'family': True,
#    ':-(': True},
#   'Negative'),
#  ({'break': True,
#    ':(': True,
#    'really': True,
#    'want': True,
#    'morning': True,
#    'ice': True,
#    'cream': True,
#    'pouring': True,
#    'rain': True,
#    '...': True},
#   'Negative'),
#  ({'would': True,
#    'ever': True,
#    'consider': True,
#    'create': True,
#    'crash': True,
#    'course': True,
#    'video': True,
#    'computer': True,
#    'science': True,
#    'many': True,
#    'resource': True,
#    'school': True,
#    ':(': True},
#   'Negative'),
#  ({'ice': True, 'cream': True, 'vehicle': True, 'busy': True, ':(': True},
#   'Negative'),
#  ({'ate': True,
#    'ayex': True,
#    'eat': True,
#    'youre': True,
#    'sexy': True,
#    ':(': True,
#    '—': True,
#    'swear': True,
#    'lot': True,
#    'chill': True,
#    'lamon': True,
#    'haha': True},
#   'Negative'),
#  ({'weather': True,
#    'scroll': True,
#    'contact': True,
#    'people': True,
#    "i've": True,
#    'curve': True,
#    'hey': True,
#    '😉': True,
#    'sigh': True,
#    ':(': True},
#   'Negative'),
#  ({"i'll": True,
#    'get': True,
#    'cement': True,
#    'cast': True,
#    'tomorrow': True,
#    ':(': True},
#   'Negative'),
#  ({'shit': True, '10.3': True, 'k': True, ':(': True}, 'Negative'),
#  ({'sign': True, ':(': True}, 'Negative'),
#  ({'zayn': True, ':(': True}, 'Negative'),
#  ({'bot': True,
#    'follow': True,
#    'plz': True,
#    'send': True,
#    'mention': True,
#    "can't": True,
#    'notice': True,
#    ':(': True},
#   'Negative'),
#  ({'jmu': True,
#    'camp': True,
#    'tease': True,
#    'bc': True,
#    'wanna': True,
#    ':(': True},
#   'Negative'),
#  ({"that's": True,
#    'one': True,
#    'sweet': True,
#    'thing': True,
#    "i've": True,
#    'ever': True,
#    'say': True,
#    'awuna': True,
#    'mbulelo': True,
#    ':(': True},
#   'Negative'),
#  ({'fucking': True,
#    'bad': True,
#    'link': True,
#    'working': True,
#    "can't": True,
#    'watch': True,
#    'match': True,
#    ':(': True},
#   'Negative'),
#  ({'oh': True,
#    'mr': True,
#    'pigs': True,
#    'turn': True,
#    ':(': True,
#    'although': True,
#    "there's": True,
#    'weird': True,
#    'crackling': True,
#    'noise': True,
#    'plug': True,
#    'come': True,
#    "i'm": True,
#    'think': True,
#    'fuse': True},
#   'Negative'),
#  ({'dammit': True,
#    'tip': True,
#    'carlton': True,
#    ':(': True,
#    '#aflblueshawks': True},
#   'Negative'),
#  ({'miss': True, ':(': True}, 'Negative'),
#  ({'go': True, 'bed': True, ':(': True}, 'Negative'),
#  ({'want': True, 'go': True, "alex's": True, 'house': True, ':(': True},
#   'Negative'),
#  ({'true': True,
#    'part': True,
#    'motorsport': True,
#    'series': True,
#    'one': True,
#    'disc': True,
#    ':(': True},
#   'Negative'),
#  ({'want': True,
#    'right': True,
#    'follow': True,
#    'cheeky': True,
#    'j': True,
#    'instead': True,
#    "i've": True,
#    'get': True,
#    'seo': True,
#    'nls': True,
#    ':(': True},
#   'Negative'),
#  ({'sure': True, 'sorry': True, ':(': True, 'x': True}, 'Negative'),
#  ({'hey': True,
#    'bud': True,
#    'christy': True,
#    'really': True,
#    'sick': True,
#    "can't": True,
#    'leave': True,
#    '2': True,
#    'home': True,
#    ':(': True,
#    'xo': True,
#    'thanks': True,
#    'man': True},
#   'Negative'),
#  ({'niece': True, 'good': True, 'summer': True, ':(': True}, 'Negative'),
#  ({'want': True, 'bloody': True, 'sandwhich': True, ':(': True}, 'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'buset': True, ':(': True}, 'Negative'),
#  ({'#discrimination': True,
#    ':-(': True,
#    'five': True,
#    'thing': True,
#    'learn': True,
#    'pregnancy': True,
#    'discrimination': True,
#    'today': True,
#    'left': True,
#    'foot': True,
#    'f': True,
#    '...': True,
#    '#uniteblue': True,
#    '#tcot': True},
#   'Negative'),
#  ({'#discrimination': True,
#    ':-(': True,
#    'maternity': True,
#    'discrimination': True,
#    'need': True,
#    'bos': True,
#    'kick': True,
#    'teeth': True,
#    '...': True,
#    '#uniteblue': True,
#    '#tcot': True},
#   'Negative'),
#  ({'#domesticviolence': True,
#    ':(': True,
#    'proposed': True,
#    'new': True,
#    'law': True,
#    'help': True,
#    'domestic': True,
#    'violence': True,
#    'victims': True,
#    '98fm': True,
#    '...': True,
#    '#uniteblue': True,
#    '#vaw': True,
#    ':-(': True},
#   'Negative'),
#  ({'miss': True,
#    ':(': True,
#    'okay': True,
#    'lol': True,
#    'nothing': True,
#    '😂': True},
#   'Negative'),
#  ({'exactly': True, 'unfortunately': True, ':(': True}, 'Negative'),
#  ({'stressful': True,
#    'upsetting': True,
#    'day': True,
#    'yesterday': True,
#    'uk': True,
#    'government': True,
#    'suck': True,
#    ':(': True},
#   'Negative'),
#  ({'ugh': True,
#    'well': True,
#    'could': True,
#    'still': True,
#    'say': True,
#    "i'm": True,
#    'lucky': True,
#    'sapiosexual': True,
#    ':(': True},
#   'Negative'),
#  ({'aww': True, 'bad': True, ':(': True}, 'Negative'),
#  ({'ive': True,
#    'try': True,
#    'play': True,
#    'damn': True,
#    'beta': True,
#    'like': True,
#    '12': True,
#    'hour': True,
#    ':(': True},
#   'Negative'),
#  ({'want': True,
#    'world': True,
#    'hulk': True,
#    'hogan': True,
#    'scrub': True,
#    'wwe': True,
#    'history': True,
#    ':-(': True},
#   'Negative'),
#  ({'im': True, 'tired': True, ':(': True}, 'Negative'),
#  ({'weather': True,
#    'make': True,
#    'want': True,
#    'go': True,
#    'gym': True,
#    '...': True,
#    ':-(': True},
#   'Negative'),
#  ({'link': True, 'work': True, ':(': True}, 'Negative'),
#  ({'irene': True,
#    'seem': True,
#    'sad': True,
#    'make': True,
#    'mistake': True,
#    ':(': True},
#   'Negative'),
#  ({'naa': True, 'unfortunately': True, 'phone': True, ':(': True}, 'Negative'),
#  ({'sold': True, ':(': True}, 'Negative'),
#  ({'hate': True, 'u': True, '>:(': True, '#h_my_king': True}, 'Negative'),
#  ({'lose': True, ':(': True}, 'Negative'),
#  ({'valentine': True,
#    'et': True,
#    'al': True,
#    'find': True,
#    "r'ships": True,
#    'btwn': True,
#    'homo': True,
#    'biphobic': True,
#    'comment': True,
#    'certain': True,
#    'discipline': True,
#    'incl': True,
#    'european': True,
#    'langs': True,
#    'lit': True,
#    'education': True,
#    ':(': True,
#    '#fresherstofinals': True},
#   'Negative'),
#  ({'notice': True, ':(': True, "i'm": True, 'hopeless': True, '💔': True},
#   'Negative'),
#  ({'dream': True,
#    'gettin': True,
#    'realistic': True,
#    'liking': True,
#    'thx': True,
#    'cant': True,
#    'tell': True,
#    'whats': True,
#    'real': True,
#    'n': True,
#    'isnt': True,
#    ':(': True},
#   'Negative'),
#  ({'either': True,
#    'would': True,
#    'prefer': True,
#    'benzema': True,
#    'get': True,
#    'though': True,
#    ':(': True},
#   'Negative'),
#  ({'hahahahahaah': True,
#    'donno': True,
#    'korean': True,
#    'language': True,
#    ':(': True,
#    'russian': True,
#    'waaaaa': True},
#   'Negative'),
#  ({':(': True, '#eidwithgrofers': True}, 'Negative'),
#  ({'someone': True, 'talk': True, "i'm": True, 'boreddd': True, ':(': True},
#   'Negative'),
#  ({'hate': True,
#    'get': True,
#    'call': True,
#    'mug': True,
#    'piss': True,
#    '>:(': True},
#   'Negative'),
#  ({'miss': True, 'know': True, '’': True, 'care': True, ':(': True},
#   'Negative'),
#  ({"can't": True, 'option': True, 'phone': True, ':(': True}, 'Negative'),
#  ({'love': True,
#    'tiddler': True,
#    'really': True,
#    'silly': True,
#    ':(': True,
#    'least': True,
#    '’': True,
#    'get': True,
#    'real': True,
#    'new': True,
#    'card': True,
#    'like': True,
#    '1': True,
#    'hour': True,
#    '..': True},
#   'Negative'),
#  ({':(': True, 'well': True, 'suck': True}, 'Negative'),
#  ({'infinite': True, 'win': True, ':(': True}, 'Negative'),
#  ({'sure': True,
#    'chorong': True,
#    'leader': True,
#    '#에이핑크': True,
#    '#더쇼': True,
#    "can't": True,
#    'anymore': True,
#    ':(': True},
#   'Negative'),
#  ({'clan': True, 'slot': True, 'open': True, ':(': True}, 'Negative'),
#  ({'pffff': True,
#    'private': True,
#    '#bugbounty': True,
#    'find': True,
#    'self-xss': True,
#    'host': True,
#    'header': True,
#    'poison': True,
#    ':(': True,
#    'need': True,
#    'code': True,
#    'execution': True,
#    '#ktksbye': True},
#   'Negative'),
#  ({'connect': True, 'leave': True, 'company': True, 'alert': True, ':(': True},
#   'Negative'),
#  ({'cancel': True,
#    'ice': True,
#    'cream': True,
#    'uber': True,
#    'order': True,
#    'everyone': True,
#    'else': True,
#    'office': True,
#    'get': True,
#    ':(': True},
#   'Negative'),
#  ({'ahahah': True,
#    'consider': True,
#    'petite': True,
#    'love': True,
#    'hate': True,
#    'relationship': True,
#    'height': True,
#    ':(': True},
#   'Negative'),
#  ({'cost': True,
#    '600': True,
#    'k': True,
#    '£': True,
#    'get': True,
#    'security': True,
#    'alert': True,
#    'odoo': True,
#    '8': True,
#    'partner': True,
#    'far': True,
#    'community': True,
#    'spirit': True,
#    ':-(': True},
#   'Negative'),
#  ({'jgh': True, ':(': True, 'im': True, 'effin': True, 'tired': True},
#   'Negative'),
#  ({'facebook': True, 'u': True, 'work': True, ':(': True}, 'Negative'),
#  ({'one': True, ':(': True}, 'Negative'),
#  ({'unfortunately': True, ':(': True, 'sorry': True}, 'Negative'),
#  ({'anyone': True,
#    "else's": True,
#    'show': True,
#    'box': True,
#    'work': True,
#    ':(': True},
#   'Negative'),
#  ({'ap': True, 'anymore': True, ':-(': True}, 'Negative'),
#  ({'story': True,
#    'life': True,
#    '...': True,
#    'love': True,
#    'london': True,
#    "can't": True,
#    'imagine': True,
#    'living': True,
#    'elsewhere': True,
#    'gonna': True,
#    'happen': True,
#    'someday': True,
#    ':(': True,
#    'space': True},
#   'Negative'),
#  ({'oh': True,
#    'ben': True,
#    ':-(': True,
#    'terrible': True,
#    'please': True,
#    'provide': True,
#    'us': True,
#    'name': True,
#    'branch': True,
#    'visit': True,
#    'would': True,
#    'like': True,
#    'address': True,
#    'concern': True},
#   'Negative'),
#  ({'poor': True, 'guy': True, ':(': True}, 'Negative'),
#  ({'feel': True,
#    'pain': True,
#    'like': True,
#    'welsh': True,
#    'pod': True,
#    ':(': True},
#   'Negative'),
#  ({"can't": True, 'wait': True, 'movie': True, 'come': True, ':(': True},
#   'Negative'),
#  ({'hi': True,
#    'julie': True,
#    "i'm": True,
#    'sorry': True,
#    'feel': True,
#    'way': True,
#    ':(': True,
#    'whats': True,
#    'happen': True,
#    'laura': True},
#   'Negative'),
#  ({'cant': True,
#    ':-(': True,
#    'im': True,
#    'still': True,
#    'inside': True,
#    'train': True,
#    'station': True,
#    'wait': True,
#    'person': True,
#    'home': True,
#    'another': True,
#    'hour': True,
#    'away': True,
#    'd;': True},
#   'Negative'),
#  ({'anymore': True, ':(': True}, 'Negative'),
#  ({'people': True,
#    'need': True,
#    'talk-kama': True,
#    'hawako': True,
#    'around': True,
#    ':(': True,
#    'waa': True,
#    'kimaaaaaani': True,
#    'prisssss': True},
#   'Negative'),
#  ({'baggage': True,
#    'claim': True,
#    'final': True,
#    'goodbye': True,
#    'new': True,
#    'plane': True,
#    'friend': True,
#    ':(': True},
#   'Negative'),
#  ({'miss': True,
#    'niamh': True,
#    'havent': True,
#    'see': True,
#    'forever': True,
#    ':(': True},
#   'Negative'),
#  ({'yeah': True,
#    'screw': True,
#    ':-(': True,
#    'time': True,
#    'think': True,
#    'something': True,
#    'good': True},
#   'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'hmmm': True,
#    'always': True,
#    'much': True,
#    'sugar': True,
#    'rarely': True,
#    'make': True,
#    'sorry': True,
#    'help': True,
#    ':(': True},
#   'Negative'),
#  ({'literally': True,
#    'time': True,
#    'watch': True,
#    'paper': True,
#    'town': True,
#    ':(': True},
#   'Negative'),
#  ({"what's": True,
#    'score': True,
#    "i'm": True,
#    'stuck': True,
#    'work': True,
#    ':(': True},
#   'Negative'),
#  ({'agh': True,
#    'keep': True,
#    'cut': True,
#    'middle': True,
#    '#undercoverboss': True,
#    ':-(': True},
#   'Negative'),
#  ({'please': True,
#    'come': True,
#    'back': True,
#    'wwe': True,
#    ':(': True,
#    'تكفى': True},
#   'Negative'),
#  ({"i'll": True,
#    'around': True,
#    '10': True,
#    'train': True,
#    'delay': True,
#    ':(': True},
#   'Negative'),
#  ({'full': True,
#    'time': True,
#    'job': True,
#    'mean': True,
#    'gonna': True,
#    'part': True,
#    'fun': True,
#    ':(': True},
#   'Negative'),
#  ({'cat': True, 'forget': True, 'hate': True, ':(': True}, 'Negative'),
#  ({'know': True,
#    'long': True,
#    'play': True,
#    '15': True,
#    'hour': True,
#    ':(': True},
#   'Negative'),
#  ({'u': True, 'already': True, ':(': True}, 'Negative'),
#  ({'yep': True, ':(': True}, 'Negative'),
#  ({'must': True, 'video': True, 'stop': True, 'tho': True, ':(': True},
#   'Negative'),
#  ({'wisdom': True,
#    'teeth': True,
#    'give': True,
#    'much': True,
#    'ache': True,
#    ':(': True},
#   'Negative'),
#  ({'one': True, ':-(': True}, 'Negative'),
#  ({'wrist': True,
#    'feel': True,
#    'naked': True,
#    'bc': True,
#    'forget': True,
#    'watch': True,
#    'bracelet': True,
#    ':(': True},
#   'Negative'),
#  ({'ligo': True, 'na': True, ':(': True}, 'Negative'),
#  ({'day': True,
#    'dozen': True,
#    'parents': True,
#    'children': True,
#    'killed': True,
#    'baby': True,
#    'shark': True,
#    'selfie': True,
#    ':(': True},
#   'Negative'),
#  ({'heartache': True, ':(': True}, 'Negative'),
#  ({'think': True, ':(': True, '#zayniscomingback': True}, 'Negative'),
#  ({'little': True,
#    'mix': True,
#    'come': True,
#    'sweden': True,
#    'tomorrow': True,
#    "can't": True,
#    'see': True,
#    ':-(': True,
#    'im': True,
#    'sad': True},
#   'Negative'),
#  ({'heart': True,
#    'breathe': True,
#    'moment': True,
#    'time': True,
#    "i'll": True,
#    'find': True,
#    'word': True,
#    'say': True,
#    'leave': True,
#    'today': True,
#    ':(': True},
#   'Negative'),
#  ({'elmhurst': True,
#    'fc': True,
#    ':-(': True,
#    "i'll": True,
#    'always': True,
#    '#etid': True},
#   'Negative'),
#  ({'miss': True, "chillin'with": True, ':(': True}, 'Negative'),
#  ({'forget': True,
#    'job': True,
#    "i'm": True,
#    'sorry': True,
#    'father': True,
#    ':(': True},
#   'Negative'),
#  ({'istanya': True,
#    'go': True,
#    '2supply': True,
#    'extra': True,
#    'infrastructure': True,
#    'teacher': True,
#    'doctor': True,
#    'nurse': True,
#    'paramedic': True,
# ...
#  ({'nou': True, 'youre': True, ':-(': True, 'picture': True, 'adam': True},
#   'Negative'),
#  ({'sad': True, 'moment': True, ':(': True}, 'Negative'),
#  ({'right': True, ':(': True}, 'Negative'),
#  ({'ken': True,
#    'saras': True,
#    'waiting': True,
#    'sister': True,
#    'accident': True,
#    'poor': True,
#    ':(': True},
#   'Negative'),
#  ({'manage': True,
#    'sort': True,
#    'ticket': True,
#    'issue': True,
#    'mate': True,
#    'nobody': True,
#    'pick': True,
#    'ring': True,
#    'box': True,
#    'office': True,
#    ':(': True},
#   'Negative'),
#  ({'fk': True,
#    'freaking': True,
#    'word': True,
#    'describe': True,
#    '...': True,
#    'eric': True,
#    'prydz': True,
#    'like': True,
#    ':(': True,
#    'world': True},
#   'Negative'),
#  ({'12': True,
#    'hour': True,
#    'sister-in-law': True,
#    'instal': True,
#    'new': True,
#    'seat': True,
#    'buy': True,
#    'rear-ended': True,
#    "everyone's": True,
#    'fine': True,
#    'trash': True,
#    ':(': True},
#   'Negative'),
#  ({'first': True,
#    'time': True,
#    'life': True,
#    "i've": True,
#    'hold': True,
#    'boobs': True,
#    'whilst': True,
#    'run': True,
#    'stair': True,
#    'bra': True,
#    ':(': True},
#   'Negative'),
#  ({'like': True, 'paper': True, 'book': True, ':(': True}, 'Negative'),
#  ({'friend': True,
#    'love': True,
#    'eat': True,
#    'ice': True,
#    'cream': True,
#    'childhood': True,
#    'missing': True,
#    'day': True,
#    ':(': True,
#    '#toothsensitivity': True},
#   'Negative'),
#  ({':-(': True}, 'Negative'),
#  ({'stressful': True,
#    ':(': True,
#    'even': True,
#    'dress': True,
#    'size': True,
#    'ke': True,
#    'shem': True,
#    '..': True},
#   'Negative'),
#  ({'trust': True,
#    'well': True,
#    ':(': True,
#    'awell': True,
#    'long': True,
#    'drink': True,
#    'care': True,
#    '#weekendofmadness': True,
#    '🍹': True,
#    '🍸': True},
#   'Negative'),
#  ({'really': True,
#    'like': True,
#    'cb': True,
#    'outfit': True,
#    'time': True,
#    'bad': True,
#    ':(': True},
#   'Negative'),
#  ({'threaten': True, ':(': True}, 'Negative'),
#  ({'wanna': True,
#    'dancer': True,
#    'choregrapher': True,
#    'cant': True,
#    ':(': True,
#    'whyyyyyyyyyyyy': True,
#    'life': True,
#    'unfair': True},
#   'Negative'),
#  ({'happen': True, 'anymore': True, ':(': True}, 'Negative'),
#  ({'even': True,
#    'know': True,
#    'still': True,
#    'exist': True,
#    'haha': True,
#    'text': True,
#    ':(': True,
#    '626-430-8715': True},
#   'Negative'),
#  ({"i've": True,
#    'message': True,
#    'replied': True,
#    'dont': True,
#    'even': True,
#    'think': True,
#    'active': True,
#    'facebook': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True,
#    'work': True,
#    'hoe': True,
#    'xd': True,
#    "can't": True,
#    'even': True,
#    'look': True,
#    'bby': True,
#    'peace': True,
#    ':(': True},
#   'Negative'),
#  ({'us': True, ':(': True}, 'Negative'),
#  ({'well': True, 'seem': True, 'like': True, 'dream': True, ':(': True},
#   'Negative'),
#  ({'dream': True,
#    'team': True,
#    'record': True,
#    'today': True,
#    ':(': True,
#    'im': True,
#    'sad': True,
#    'xiu': True,
#    'make': True},
#   'Negative'),
#  ({'nk': True, 'gi': True, 'us': True, 'birthday': True, ':(': True},
#   'Negative'),
#  ({'awwwwww': True, "i'm": True, 'sorry': True, 'hear': True, ':(': True},
#   'Negative'),
#  ({'miss': True,
#    'much': True,
#    'ate': True,
#    'elisse': True,
#    ':(': True,
#    'u': True,
#    'still': True,
#    'remember': True,
#    '😭': True},
#   'Negative'),
#  ({'miss': True, 'much': True, ':(': True}, 'Negative'),
#  ({'ksoo': True, 'make': True, 'emo': True, ':(': True}, 'Negative'),
#  ({'wat': True,
#    'small': True,
#    'session': True,
#    'tat': True,
#    ':(': True,
#    '..': True,
#    'still': True,
#    'im': True,
#    'little': True,
#    'happy': True,
#    'bcoz': True,
#    'first': True,
#    'time': True,
#    'hear': True,
#    'name': True,
#    'short': True},
#   'Negative'),
#  ({'awwwww': True,
#    "i'm": True,
#    'sorry': True,
#    ':(': True,
#    'bet': True,
#    'look': True,
#    '<3': True,
#    '3': True},
#   'Negative'),
#  ({'matter': True,
#    'many': True,
#    'time': True,
#    'try': True,
#    'sleep': True,
#    '...': True,
#    "can't": True,
#    ':(': True},
#   'Negative'),
#  ({'“': True, 'paper': True, 'town': True, '”': True, 'sm': True, ':(': True},
#   'Negative'),
#  ({'go': True, ':(': True}, 'Negative'),
#  ({"i'm": True,
#    'go': True,
#    'miss': True,
#    'baby': True,
#    ':(': True,
#    'rancho': True,
#    'imperial': True,
#    'de': True,
#    'silang': True,
#    'subdivision': True},
#   'Negative'),
#  ({'traffic': True, ':-(': True}, 'Negative'),
#  ({'twitter': True,
#    'help': True,
#    'center': True,
#    '#39': True,
#    'follow': True,
#    'people': True,
#    'via': True,
#    'really': True,
#    'sorry': True,
#    'evry': True,
#    'one': True,
#    ':(': True},
#   'Negative'),
#  ({'hot': True,
#    'cornwall': True,
#    'veritably': True,
#    'cold': True,
#    ':(': True,
#    'great': True,
#    'prize': True,
#    'xx': True},
#   'Negative'),
#  ({'aww': True, ':(': True, 'thank': True, 'anyway': True}, 'Negative'),
#  ({'regular': True,
#    'gym': True,
#    'workout': True,
#    'boring': True,
#    'could': True,
#    'spin': True,
#    ':(': True},
#   'Negative'),
#  ({"can't": True,
#    'anymore': True,
#    'stress': True,
#    'body': True,
#    'yet': True,
#    'life': True,
#    'base': True,
#    'upon': True,
#    ':(': True},
#   'Negative'),
#  ({'see': True,
#    'penny': True,
#    '...': True,
#    ':-(': True,
#    'dm': True,
#    'email': True,
#    'address': True,
#    "i'll": True,
#    'send': True,
#    'ebook': True},
#   'Negative'),
#  ({'фотосет': True,
#    'addicted-to-analsex': True,
#    'sweetbj': True,
#    '#sweetbj': True,
#    '#blowjob': True,
#    'mhhh': True,
#    'want': True,
#    'make': True,
#    'man': True,
#    'happy': True,
#    ':(': True},
#   'Negative'),
#  ({'im': True,
#    'sed': True,
#    '..': True,
#    ':-(': True,
#    'person': True,
#    'meeting': True,
#    'late': True,
#    'end': True,
#    'sg': True,
#    'havent': True,
#    'take': True,
#    'dinner': True,
#    'yet': True,
#    'bless': True},
#   'Negative'),
#  ({'feel': True, 'leave': True, ':(': True}, 'Negative'),
#  ({'mention': True,
#    'mee': True,
#    'omg': True,
#    'envious': True,
#    'please': True,
#    'oppa': True,
#    'eonni': True,
#    'stop': True,
#    'lovey': True,
#    'dovey': True,
#    'front': True,
#    'poor': True,
#    'single': True,
#    'dongsaeng': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True,
#    'workin': True,
#    ':(': True,
#    'get': True,
#    'day': True,
#    'tuesday': True,
#    'tho': True,
#    'haha': True,
#    'x': True},
#   'Negative'),
#  ({'schade': True, ':(': True}, 'Negative'),
#  ({'gutted': True, 'never': True, 'g': True, 'belfast': True, ':(': True},
#   'Negative'),
#  ({'im': True,
#    'jealous': True,
#    '..': True,
#    ':(': True,
#    'follow': True,
#    'jacob': True},
#   'Negative'),
#  ({'isco': True, ':(': True}, 'Negative'),
#  ({'penis': True, 'small': True, ':(': True}, 'Negative'),
#  ({'omg': True,
#    'every': True,
#    'fuck': True,
#    'month': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'wish': True, 'dog': True, 'like': True, 'cuddle': True, ':(': True},
#   'Negative'),
#  ({'come': True, 'carlton': True, ':(': True}, 'Negative'),
#  ({'babe': True,
#    ':(': True,
#    'u': True,
#    'still': True,
#    'read': True,
#    'thru': True,
#    'conversation': True,
#    'ur': True,
#    'hush': True},
#   'Negative'),
#  ({'sometimes': True,
#    'wonder': True,
#    'go': True,
#    'wrong': True,
#    ':(': True,
#    'guess': True,
#    "i'll": True,
#    'never': True,
#    'know': True},
#   'Negative'),
#  ({'violence': True,
#    '...': True,
#    ':(': True,
#    'soul': True,
#    'sick': True,
#    'nation': True,
#    'pray': True,
#    'louisiana': True,
#    '#lafayette': True,
#    '#matteroftheheart': True,
#    '#peace': True},
#   'Negative'),
#  ({'waduh': True, '..': True, 'pant': True, ':(': True}, 'Negative'),
#  ({'know': True,
#    'actually': True,
#    'get': True,
#    'suspend': True,
#    'smoking': True,
#    'believe': True,
#    'teenage': True,
#    'fucking': True,
#    'cliche': True,
#    ':(': True},
#   'Negative'),
#  ({'already': True, 'miss': True, 'much': True, ':(': True}, 'Negative'),
#  ({'miss': True, 'youuuu': True, ':(': True}, 'Negative'),
#  ({'today': True, '#rma': True, 'jersey': True, ':(': True}, 'Negative'),
#  ({'fake': True, 'texted': True, ':(': True}, 'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'♥': True,
#    'eng': True,
#    "let's": True,
#    'talk': True,
#    'since': True,
#    "can't": True,
#    'stream': True,
#    'game': True,
#    ':(': True},
#   'Negative'),
#  ({'chance': True, ':(': True}, 'Negative'),
#  ({'snapchat': True,
#    'jaclintiler': True,
#    '#snapchat': True,
#    '#teens': True,
#    '#models': True,
#    '#likeforlike': True,
#    '#mpoints': True,
#    '#hotfmnoaidilforariana': True,
#    ':(': True},
#   'Negative'),
#  ({'hi': True, 'dm': True, 'luke': True, 'please': True, ':(': True},
#   'Negative'),
#  ({'really': True, 'want': True, 'run': True, 'time': True, ':(': True},
#   'Negative'),
#  ({'hate': True, 'wake': True, 'middle': True, 'sleep': True, ':(': True},
#   'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'fuckkk': True, 'wednesday': True, ':(': True}, 'Negative'),
#  ({'want': True,
#    'start': True,
#    'one': True,
#    'make': True,
#    'small': True,
#    'game': True,
#    'feel': True,
#    'like': True,
#    'need': True,
#    'get': True,
#    'jump': True,
#    'ask': True,
#    'support': True,
#    ':(': True},
#   'Negative'),
#  ({'justin': True, ':(': True}, 'Negative'),
#  ({':(': True, "i'm": True, 'gonna': True, 'cry': True}, 'Negative'),
#  ({"i'm": True,
#    'really': True,
#    'excite': True,
#    'also': True,
#    'sad': True,
#    'able': True,
#    'see': True,
#    ':(': True},
#   'Negative'),
#  ({"can't": True,
#    'finish': True,
#    'sanum': True,
#    'today': True,
#    ':(': True,
#    '#llaollao': True,
#    '#dessert': True,
#    'full': True},
#   'Negative'),
#  ({'want': True, 'foood': True, ':(': True}, 'Negative'),
#  ({'last': True, 'day': True, ':(': True}, 'Negative'),
#  ({'#ubericecream': True,
#    'super': True,
#    'didnt': True,
#    'get': True,
#    'glare': True,
#    ':(': True},
#   'Negative'),
#  ({'know': True, 'vine': True, ':(': True}, 'Negative'),
#  ({'tweetin': True,
#    'early': True,
#    'morning': True,
#    ':(': True,
#    'sad': True,
#    'mood': True,
#    'day': True},
#   'Negative'),
#  ({'sunggyu': True,
#    'plaster': True,
#    'elbow': True,
#    '...': True,
#    'fall': True,
#    ':-(': True},
#   'Negative'),
#  ({'middle': True,
#    'figure': True,
#    'choreo': True,
#    ':(': True,
#    'next': True,
#    'time': True,
#    'girl': True},
#   'Negative'),
#  ({'😭': True,
#    'think': True,
#    'well': True,
#    'offensive': True,
#    'laugh': True,
#    ':(': True},
#   'Negative'),
#  ({'love': True, '..': True, 'sad': True, 'front': True, ':(': True},
#   'Negative'),
#  ({'yeyy': True,
#    'finally': True,
#    'hd': True,
#    'brows': True,
#    'kit': True,
#    'break': True,
#    'slightly': True,
#    ':(': True},
#   'Negative'),
#  ({'monday': True,
#    'wednesday': True,
#    'g': True,
#    'na': True,
#    'girl': True,
#    ':(': True},
#   'Negative'),
#  ({'babe': True, ':(': True}, 'Negative'),
#  ({'miss': True,
#    'everyone': True,
#    'omg': True,
#    ':(': True,
#    'school': True,
#    'sux': True},
#   'Negative'),
#  ({'enjoy': True, ':(': True}, 'Negative'),
#  ({'add': True,
#    'kik': True,
#    'nothaveld': True,
#    '765': True,
#    '#kik': True,
#    '#hornykik': True,
#    '#edm': True,
#    '#sexy': True,
#    '#likeforfollow': True,
#    '#hannibal': True,
#    '#camsex': True,
#    ':(': True},
#   'Negative'),
#  ({'new': True, 'mosquitoe': True, 'bite': True, ':(': True}, 'Negative'),
#  ({'kinky': True,
#    'shit': True,
#    'hsould': True,
#    'justget': True,
#    'married': True,
#    'already': True},
#   'Negative'),
#  ({'really': True,
#    'dont': True,
#    'wanna': True,
#    'go': True,
#    'home': True,
#    'today': True,
#    ':(': True},
#   'Negative'),
#  ({'la': True, ':(': True}, 'Negative'),
#  ({'nothing': True,
#    'like': True,
#    'us': True,
#    'come': True,
#    'shuffle': True,
#    ':(': True},
#   'Negative'),
#  ({'hmm': True,
#    'think': True,
#    'get': True,
#    'one': True,
#    'might': True,
#    'inte': True,
#    'future': True,
#    'really': True,
#    'miss': True,
#    'buckle': True,
#    'spring': True,
#    ':(': True},
#   'Negative'),
#  ({'ah': True,
#    'millz': True,
#    'askies': True,
#    ':(': True,
#    'come': True,
#    'back': True,
#    'awusasho': True,
#    ":'(": True},
#   'Negative'),
#  ({'guy': True,
#    'really': True,
#    'unlucky': True,
#    'one': True,
#    'driver': True,
#    'briefly': True,
#    'check': True,
#    'egg': True,
#    'half': True,
#    'spot': True},
#   'Negative'),
#  ({'tired': True, ':(': True}, 'Negative'),
#  ({'im': True,
#    'greatful': True,
#    'still': True,
#    'see': True,
#    'u': True,
#    'despite': True,
#    '144p': True,
#    ':(': True},
#   'Negative'),
#  ({'love': True,
#    'brooke': True,
#    "i'm": True,
#    'concern': True,
#    'cause': True,
#    'face': True,
#    'cracked': True,
#    ':(': True},
#   'Negative'),
#  ({'＠': True,
#    'maverickgamer': True,
#    'july': True,
#    '24': True,
#    '2015': True,
#    '07:32': True,
#    'pm': True,
#    ':(': True},
#   'Negative'),
#  ({'＠': True,
#    'maverickgamer': True,
#    'july': True,
#    '24': True,
#    '2015': True,
#    '07:25': True,
#    'pm': True,
#    ':(': True},
#   'Negative'),
#  ({'bored': True, 'max': True, 'rn': True, ':(': True}, 'Negative'),
#  ({'sorry': True,
#    'manage': True,
#    'file': True,
#    'external': True,
#    'sd': True,
#    'card': True,
#    'via': True,
#    'airdroid': True,
#    'support': True,
#    'android': True,
#    '4.4+': True,
#    ':(': True,
#    'google': True,
#    'restrict': True},
#   'Negative'),
#  ({'u': True, 'cute': True, 'thank': True, ':(': True}, 'Negative'),
#  ({'alright': True, '...': True, 'cramp': True, 'kill': True, ':-(': True},
#   'Negative'),
#  ({'maybe': True,
#    'wrong': True,
#    'say': True,
#    'please': True,
#    'love': True,
#    '3': True,
#    ':(': True},
#   'Negative'),
#  ({'dont': True,
#    'unstan': True,
#    'tay': True,
#    ':(': True,
#    'never': True,
#    'please': True},
#   'Negative'),
#  ({'white': True,
#    'thing': True,
#    'ngeze': True,
#    'turn': True,
#    ':(': True,
#    'party': True,
#    "i've": True,
#    'nothing': True,
#    'cocktaily': True,
#    'classy': True,
#    '😭': True,
#    'stress': True},
#   'Negative'),
#  ({'love': True, ':(': True}, 'Negative'),
#  ({'＠': True,
#    'maverickgamer': True,
#    'july': True,
#    '24': True,
#    '2015': True,
#    '07:24': True,
#    'pm': True,
#    ':(': True},
#   'Negative'),
#  ({'want': True, 'stick': True, 'inside': True, 'day': True, ':(': True},
#   'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'come': True, 'crash': True, 'hurt': True, 'inside': True, ':(': True},
#   'Negative'),
#  ({'✈': True,
#    '️': True,
#    '2': True,
#    'day': True,
#    "i'm": True,
#    'back': True,
#    'rainy': True,
#    'uk': True,
#    ':-(': True,
#    '☔': True},
#   'Negative'),
#  ({'hi': True,
#    'peter': True,
#    "we've": True,
#    'pen': True,
#    '2': True,
#    'year': True,
#    "can't": True,
#    'get': True,
#    "there's": True,
#    'even': True,
#    'spar': True,
#    'office': True,
#    'anymore': True,
#    'either': True,
#    ':(': True},
#   'Negative'),
#  ({'get': True, 'delay': True, 'guest': True, 'sigh': True, ':(': True},
#   'Negative'),
#  ({'come': True,
#    'barcelona': True,
#    'year': True,
#    ':(': True,
#    'able': True,
#    'see': True,
#    'madrid': True,
#    'bilbao': True,
#    '...': True},
#   'Negative'),
#  ({'hate': True, 'japanese': True, 'call': True, 'ban': True, ':(': True},
#   'Negative'),
#  ({'wish': True, 'nice': True, 'booty': True, ':-(': True}, 'Negative'),
#  ({'next': True,
#    'oh': True,
#    'yeah': True,
#    'sharyl': True,
#    'currently': True,
#    'get': True,
#    '#shane': True,
#    'ta': True,
#    'call': True,
#    ':(': True},
#   'Negative'),
#  ({'favourite': True, 'people': True, 'deactivate': True, ':(': True},
#   'Negative'),
#  ({'want': True, 'dance': True, 'rn': True, ':(': True}, 'Negative'),
#  ({'im': True, 'still': True, 'giddy': True, 'd1': True, ':-(': True},
#   'Negative'),
#  ({'smile': True, 'beautiful': True, ':(': True}, 'Negative'),
#  ({'yes': True,
#    '11': True,
#    'day': True,
#    'broken': True,
#    'zipper': True,
#    'beyond': True,
#    'repair': True,
#    ':(': True},
#   'Negative'),
#  ...]

# %%
dataset = positive_dataset + negative_dataset + neutral_dataset

random.shuffle(dataset)

train_data = dataset[:25000]
test_data = dataset[25000:]

# %%
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.8992
# Most Informative Features
#                       :( = True           Negati : Positi =   7255.9 : 1.0
#               tommy_colc = True           Neutra : Positi =    498.9 : 1.0
#                       rt = True           Neutra : Negati =    451.4 : 1.0
#                       :) = True           Positi : Negati =    405.6 : 1.0
#               inequality = True           Neutra : Positi =    303.9 : 1.0
#                    claim = True           Neutra : Negati =    216.2 : 1.0
#                   thanks = True           Positi : Neutra =    185.2 : 1.0
#                    times = True           Neutra : Positi =    180.6 : 1.0
#                financial = True           Neutra : Negati =    174.2 : 1.0
#                   rather = True           Neutra : Negati =    167.3 : 1.0
# None

# %%
pickle.dump(classifier, open('tweets_text.sav', 'wb'))
